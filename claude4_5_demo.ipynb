# %% [markdown]
# <a href="https://colab.research.google.com/github/frank-morales2020/MLxDL/blob/main/claude4_5_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install anthropic -q
# !pip install colab-env -q
import colab_env

# %% [markdown]
# Model Name,Standard Claude API ID,Full API Version ID,Release Date
#
# Claude Opus 4.5,claude-opus-4-5,claude-opus-4-5-20251101,"November 24, 2025"
#
# Claude Sonnet 4.5,claude-sonnet-4-5,claude-sonnet-4-5-20250929,"September 29, 2025"
#
# Claude Haiku 4.5,claude-haiku-4-5,claude-haiku-4-5-20251001,"October 15, 2025"

# %% [markdown]
# Model Name, Primary Focus, Comparative Power
#
# Claude Opus 4.5, "Frontier Intelligence, Deep Reasoning, Complex Agentic Tasks, Best Coding", Most Powerful
#
# Claude Sonnet 4.5,"The Balanced Powerhouse, Faster throughput, Strong for code",Mid-Tier (Very high capability and efficiency)
#
# Claude Haiku 4.5,"Speed and Efficiency, Quick responses, Low latency",Fastest and Most Cost-Effective

# %%
import os
import anthropic # Make sure you have 'anthropic' library installed (pip install anthropic)

# Retrieve your API key securely from environment variables
# It's good practice to set this in your environment, e.g., in your shell:
# export CLAUDE3_API_KEY="sk-ant-..."
api_key = os.environ.get("CLAUDE3_API_KEY")

if not api_key:
    raise ValueError("CLAUDE3_API_KEY environment variable not set.")

# Initialize the Anthropic client with your API key
client = anthropic.Anthropic(api_key=api_key)

# Specify the Claude Opus 4 model
# Note: The model name you provided 'claude-opus-4-20250514' is specific.
# Always check Anthropic's official documentation for the most current and correct model names.
# For example, it might be 'claude-4-opus-20250514' or simply 'claude-4-opus'.
# I'll use the one you provided for this example, but keep this in mind!
model_name = "claude-opus-4-5-20251101"


def analyze_flight_scenario(
    flight_id: str,
    origin: str,
    destination: str,
    proposed_route: str,
    weather_forecast: str,
    notams: list,
    aircraft_type: str
):
    """
    Analyzes a complex flight scenario using Claude Opus 4, providing a risk assessment
    and potential recommendations.
    """
    user_prompt = f"""
    You are an expert aviation safety analyst. Please perform a detailed risk assessment for the following flight scenario and provide recommendations.

    **Flight Details:**
    - **Flight ID:** {flight_id}
    - **Origin:** {origin}
    - **Destination:** {destination}
    - **Proposed Route:** {proposed_route}
    - **Aircraft Type:** {aircraft_type}

    **Current Conditions:**
    - **Weather Forecast along Route:** {weather_forecast}
    - **Active NOTAMs (Notices to Airmen):**
        {chr(10).join(f"- {n}" for n in notams) if notams else "- None"}

    **Analysis Required:**
    1.  Identify all potential risks, categorized by severity (High, Medium, Low).
    2.  For each risk, explain why it's a concern in the context of the flight details.
    3.  Suggest concrete mitigation strategies or alternative actions.
    4.  Provide an overall go/no-go recommendation based on your assessment.
    5.  Be specific and detailed in your technical explanations.
    """

    try:
        message = client.messages.create(
            model=model_name,
            max_tokens=2000, # Adjust as needed for detailed output
            temperature=0.7, # A common setting for balanced creativity and adherence
            messages=[
                {"role": "user", "content": user_prompt}
            ]
        )
        print(f"\n--- Claude Opus 4 Analysis for Flight {flight_id} ---")
        print(message.content[0].text)

    except anthropic.APIError as e:
        print(f"Anthropic API Error: {e}")
        if e.status_code == 401:
            print("Please check if your CLAUDE3_API_KEY is correct and valid.")
        elif e.status_code == 400:
            print("Bad request, possibly incorrect model name or parameters.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# --- Example Usage ---
if __name__ == "__main__":
    test_flight_id = "UA876"
    test_origin = "KDEN (Denver International Airport)"
    test_destination = "PHNL (Daniel K. Inouye International Airport, Honolulu)"
    test_proposed_route = "DEN-SFO-HNL, traversing high-altitude Pacific airspaces."
    test_weather_forecast = (
        "Strong upper-level jet stream from the west (150-180 knots) over the Pacific, "
        "potential for clear-air turbulence (CAT) at FL350-FL410. "
        "Hawaii experiencing scattered showers and moderate trade winds."
    )
    test_notams = [
        "A1234/25 - CAT advisory over 140W longitude, FL350-FL410, until 260000Z MAY.",
        "R0005/25 - Military restricted airspace activated 100NM west of San Francisco until 260200Z MAY."
    ]
    test_aircraft_type = "Boeing 787-9 Dreamliner"

    analyze_flight_scenario(
        flight_id=test_flight_id,
        origin=test_origin,
        destination=test_destination,
        proposed_route=test_proposed_route,
        weather_forecast=test_weather_forecast,
        notams=test_notams,
        aircraft_type=test_aircraft_type
    )
# Out:
# --- Claude Opus 4 Analysis for Flight UA876 ---
# # Flight Risk Assessment Report
#
# ## Flight: UA876 | KDEN → PHNL
# **Aircraft:** Boeing 787-9 Dreamliner
# **Route:** DEN-SFO-HNL (Pacific Crossing)
# **Assessment Date:** Current
#
# ---
#
# ## 1. RISK IDENTIFICATION AND CATEGORIZATION
#
# ### 🔴 HIGH SEVERITY RISKS
#
# #### Risk H1: Clear Air Turbulence (CAT) Encounter
# | Parameter | Details |
# |-----------|---------|
# | **Location** | 140°W longitude, FL350-FL410 |
# | **Duration** | Active until 260000Z MAY |
# | **Source** | NOTAM A1234/25 + Jet Stream Analysis |
#
# **Technical Concern:**
# The 150-180 knot jet stream from the west creates significant wind shear at the boundaries of the jet core. The 787-9's optimal cruise altitude of FL390-FL430 places it directly within the CAT advisory zone. At these speeds, CAT can produce:
# - Vertical accelerations of +2.0g to -1.0g (moderate-severe)
# - Structural stress on airframe components
# - Passenger/crew injury potential
# - Fuel consumption increase of 3-8% due to altitude deviations
#
# The Pacific crossing segment (~2,400nm from SFO to HNL) means extended exposure time of approximately 4.5-5 hours within or near the affected region.
#
# ---
#
# #### Risk H2: Extended Overwater Operations (ETOPS)
# | Parameter | Details |
# |-----------|---------|
# | **Type** | ETOPS-330 operation required |
# | **Critical Phase** | Mid-Pacific segment |
# | **Nearest Diversion** | Limited options mid-route |
#
# **Technical Concern:**
# The SFO-HNL segment requires ETOPS certification (787-9 is ETOPS-330 approved). Critical considerations:
# - **Equal Time Point (ETP)** approximately 1,200nm from both SFO and HNL
# - Single-engine diversion time: ~180 minutes at ETP
# - Limited diversion airports: Midway Atoll (PMDY) - limited facilities, or return to mainland
# - Combined with CAT conditions, an emergency descent through turbulent layers adds complexity
# - Fuel reserve calculations must account for potential headwind component on diversion
#
# ---
#
# ### 🟠 MEDIUM SEVERITY RISKS
#
# #### Risk M1: Military Restricted Airspace (R-0005/25)
# | Parameter | Details |
# |-----------|---------|
# | **Location** | 100NM west of San Francisco |
# | **Duration** | Active until 260200Z MAY |
# | **Impact** | Route deviation required |
#
# **Technical Concern:**
# The filed route DEN-SFO-HNL likely uses the standard Pacific departure gates from the Bay Area. The restricted area 100nm west of SFO directly impacts:
# - PIRAT and PAINT departure routes commonly used for Hawaii traffic
# - Potential 50-80nm lateral deviation required
# - Additional flight time: 8-15 minutes
# - Additional fuel burn: 800-1,500 lbs
# - Possible ATC congestion as multiple flights reroute around the same airspace
#
# ---
#
# #### Risk M2: Jet Stream Headwind Component
# | Parameter | Details |
# |-----------|---------|
# | **Wind Speed** | 150-180 knots from the west |
# | **Impact** | Fuel consumption, flight time |
#
# **Technical Concern:**
# Westbound Pacific crossings against strong jet stream conditions present:
# - Effective headwind component: 120-160 knots (depending on track)
# - Increased block time: 45-75 minutes beyond standard
# - Additional fuel requirement: 8,000-15,000 lbs
# - 787-9 maximum fuel capacity: 223,673 lbs - adequate but margins reduced
# - Contingency fuel may be consumed for planned operations
#
# **Fuel Analysis:**
# - Standard KDEN-PHNL fuel load: ~95,000-105,000 lbs
# - Today's conditions: ~110,000-120,000 lbs required
# - Reserves must account for: CAT altitude changes, restricted airspace deviation, missed approach at HNL
#
# ---
#
# #### Risk M3: Destination Weather - Hawaii
# | Parameter | Details |
# |-----------|---------|
# | **Conditions** | Scattered showers, moderate trade winds |
# | **Impact** | Approach/landing phase |
#
# **Technical Concern:**
# Trade wind conditions at PHNL typically mean:
# - Runway 8L/8R in use (prevailing easterly winds)
# - Crosswind component: 10-20 knots possible
# - Visibility reduction in shower activity: 3-5SM temporarily
# - Windshear potential on final approach due to terrain effects from Ko'olau Range
# - The 787-9 crosswind limit is 38 knots (dry) - well within limits, but passenger comfort affected
#
# ---
#
# ### 🟢 LOW SEVERITY RISKS
#
# #### Risk L1: High-Altitude Operations at KDEN
# | Parameter | Details |
# |-----------|---------|
# | **Field Elevation** | 5,430 ft MSL |
# | **Impact** | Takeoff performance |
#
# **Technical Concern:**
# Denver's high elevation affects:
# - Reduced air density = longer takeoff roll
# - Reduced initial climb gradient
# - Higher true airspeed at rotation
# - Standard consideration for 787-9 operations; performance charts account for this
# - May require reduced payload if high temperatures coincide
#
# ---
#
# #### Risk L2: Crew Fatigue Considerations
# | Parameter | Details |
# |-----------|---------|
# | **Flight Time** | ~7-8 hours (extended due to headwinds) |
# | **Time Zone Change** | 4 hours (MDT to HST) |
#
# **Technical Concern:**
# - Extended duty day if delays occur
# - Circadian rhythm disruption (westbound)
# - Crew must be monitored for fatigue indicators
# - 787-9 automation reduces workload but vigilance required during turbulence
#
# ---
#
# ## 2. MITIGATION STRATEGIES
#
# ### For High Severity Risks:
#
# #### CAT Mitigation (H1):
# | Strategy | Implementation |
# |----------|----------------|
# | **Altitude Selection** | Request FL320 or FL330, below the primary CAT layer |
# | **Real-time Monitoring** | Utilize onboard weather radar (limited CAT detection) and ACARS PIREPs |
# | **Crew Coordination** | Brief cabin crew on expected turbulence windows; secure cabin 30 min prior to 140°W |
# | **Speed Adjustment** | Reduce to turbulence penetration speed (M.82 for 787) when encountering CAT |
# | **Passenger Safety** | Extended seatbelt sign; suspend service during CAT zone transit |
# | **Route Deviation** | Consider track 50-100nm south of standard to potentially avoid jet stream core |
#
# #### ETOPS Mitigation (H2):
# | Strategy | Implementation |
# |----------|----------------|
# | **Pre-flight Verification** | Confirm ETOPS MEL compliance; verify HF radio operation |
# | **Fuel Planning** | Upload additional 5,000 lbs contingency fuel |
# | **Diversion Briefing** | Pre-compute ETP, PNR, and diversion profiles to PMDY and return to SFO |
# | **Systems Monitoring** | Enhanced monitoring of engines, hydraulics, electrical through CAT zone |
# | **Satellite Communication** | Verify SATCOM and ADS-C functionality for oceanic tracking |
#
# ---
#
# ### For Medium Severity Risks:
#
# #### Restricted Airspace Mitigation (M1):
# | Strategy | Implementation |
# |----------|----------------|
# | **Pre-file Deviation** | File route via KAYEX or CINNY departures avoiding restricted area |
# | **ATC Coordination** | Contact Oakland Center (ZOA) for real-time routing options |
# | **Fuel Adjustment** | Add 2,000 lbs for deviation routing |
# | **Timing Option** | If departure can be delayed past 260200Z, restriction expires |
#
# #### Headwind Mitigation (M2):
# | Strategy | Implementation |
# |----------|----------------|
# | **Altitude Optimization** | Use wind-optimized altitude (may be lower than normal) |
# | **Cost Index Adjustment** | Reduce CI for fuel efficiency over speed |
# | **Track Flexibility** | Request PACOTS track favorable to win

# %%
import os
import anthropic # Make sure you have 'anthropic' library installed (pip install anthropic)

# Retrieve your API key securely from environment variables
api_key = os.environ.get("CLAUDE3_API_KEY")

if not api_key:
    raise ValueError("CLAUDE3_API_KEY environment variable not set.")

# Initialize the Anthropic client with your API key
client = anthropic.Anthropic(api_key=api_key)


def generate_quick_flight_summary(flight_data: dict):
    """
    Generates a concise and easy-to-read flight briefing summary using Claude Sonnet 4.
    """
    flight_number = flight_data.get("flight_number", "N/A")
    origin = flight_data.get("origin", "N/A")
    destination = flight_data.get("destination", "N/A")
    departure_time = flight_data.get("departure_time", "N/A")
    weather_summary = flight_data.get("weather_summary", "No specific weather summary provided.")
    relevant_notams = flight_data.get("relevant_notams", [])

    notams_text = "\n- ".join(relevant_notams) if relevant_notams else "None reported."

    user_prompt = f"""
    As an AI assistant for pilots, create a brief, actionable summary of the flight conditions for Flight {flight_number}.
    Focus on key weather impacts and critical NOTAMs (Notices to Airmen) relevant to the flight from {origin} to {destination}
    departing at {departure_time}.

    **Key Weather:**
    {weather_summary}

    **Critical NOTAMs:**
    {notams_text}

    The summary should be no more than 150 words and highlight immediate concerns.
    """

    try:
        message = client.messages.create(
            model=model_name,
            max_tokens=2048, # Sonnet is efficient, smaller max_tokens is often sufficient
            temperature=0.5, # Slightly lower for more direct, less creative summary
            messages=[
                {"role": "user", "content": user_prompt}
            ]
        )
        print(f"\n--- Claude Opus 4.5 Quick Flight Briefing for Flight {flight_number} ---")
        print(message.content[0].text)

    except anthropic.APIError as e:
        print(f"Anthropic API Error: {e}")
        if e.status_code == 401:
            print("Please check if your CLAUDE3_API_KEY is correct and valid.")
        elif e.status_code == 400:
            print("Bad request, possibly incorrect model name or parameters.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# --- Example Usage ---
if __name__ == "__main__":
    example_flight_data = {
        "flight_number": "ACA704",
        "origin": "CYUL (Montreal-Trudeau)",
        "destination": "KJFK (John F. Kennedy International)",
        "departure_time": "14:00 EDT",
        "weather_summary": (
            "Moderate turbulence expected over New England between FL250 and FL350 due to shear. "
            "Light rain and reduced visibility at KJFK on arrival, but conditions improving after 16:00 EDT."
        ),
        "relevant_notams": [
            "A0123/25 - KJFK Runway 22L/4R closed for maintenance until 17:00 EDT.",
            "B0456/25 - Airspace restriction over Washington D.C. area, check latest TFRs."
        ]
    }

    generate_quick_flight_summary(example_flight_data)
# Out:
# --- Claude Opus 4.5 Quick Flight Briefing for Flight ACA704 ---
# ## Flight ACA704 (CYUL → KJFK) - Conditions Summary
# **Departure: 14:00 EDT**
#
# ### ⚠️ Weather Concerns
# - **En Route:** Moderate turbulence FL250-FL350 over New England (wind shear) — consider altitude adjustments
# - **KJFK Arrival:** Light rain, reduced visibility; conditions improving after 16:00 EDT
#
# ### ⚠️ Critical NOTAMs
# - **A0123/25:** RWY 22L/4R CLOSED until 17:00 EDT — plan for alternate runway configuration (expect 31L/31R or 13L/13R)
# - **B0456/25:** Washington D.C. airspace restriction active — verify current TFRs before departure; ensure routing avoids restricted area
#
# ### Recommended Actions
# 1. Brief passengers on potential turbulence
# 2. Confirm runway assignment with ATC given 22L/4R closure
# 3. Review latest D.C. TFR boundaries for routing compliance
#
# **Conditions favorable for on-time arrival if departing as scheduled.**
