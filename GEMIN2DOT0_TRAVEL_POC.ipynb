# %% [markdown]
# <a href="https://colab.research.google.com/github/frank-morales2020/MLxDL/blob/main/GEMIN2DOT0_TRAVEL_POC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install colab-env --quiet
import colab_env

# %%
import google.generativeai as genai
from google.colab import userdata

# Retrieve API key from userdata
GOOGLE_API_KEY = userdata.get('GEMINI')

# Check if API key is retrieved successfully
if GOOGLE_API_KEY is None:
    raise ValueError("API key not found in userdata['GEMINI'].")

# Configure the client with the API key
genai.configure(api_key=GOOGLE_API_KEY)

# List available models and print their names
models = genai.list_models()
for model in models:
    print(model.name)

# Choose the appropriate Gemini 2.0 model from the list above
model = genai.GenerativeModel(model_name='models/gemini-2.0-flash-exp')

print()
# Example 1: Simple text generation with Gemini 2.0
prompt = "Write a short story about a cat who goes on an adventure in a hot air balloon."
response = model.generate_content(contents=[prompt])
print(response.text)

print()

# Example 2: Code generation with Gemini 2.0
prompt = "Write a Python function to calculate the factorial of a number."
response = model.generate_content(
    contents=[prompt],
)
print(response)

# %%
import google.generativeai as genai
from google.colab import userdata
import datetime
import calendar
import sqlite3
import json

# Retrieve API key from userdata
GOOGLE_API_KEY = userdata.get('GEMINI')

# Check if API key is retrieved successfully
if GOOGLE_API_KEY is None:
    raise ValueError("API key not found in userdata['GEMINI']. Please set it using `userdata.set('GEMINI', 'YOUR_API_KEY')`.")

# Configure the client with the API key
genai.configure(api_key=GOOGLE_API_KEY)

# Choose the appropriate Gemini 2.0 model
model = genai.GenerativeModel(model_name='models/gemini-2.0-flash-exp')

class MoME:
    """
    A MoME system using SQLite for persistence.
    """
    def __init__(self, db_file="mome.db"):
        self.db_file = db_file
        self.conn = sqlite3.connect(self.db_file)
        self.create_table()

    def create_table(self):
        """Creates the user_data table if it doesn't exist."""
        cursor = self.conn.cursor()
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS user_data (
                user_id TEXT PRIMARY KEY,
                data TEXT
            )
        ''')
        self.conn.commit()

    def get(self, user_id, key=None):
        """Retrieves data from the MoME system."""
        try:
            cursor = self.conn.cursor()
            cursor.execute("SELECT data FROM user_data WHERE user_id=?", (user_id,))
            row = cursor.fetchone()
            if row:
                # Correctly handle potential empty data
                if row[0] is None:
                    data = {}
                else:
                    data = json.loads(row[0])  # Use json.loads for deserialization
                if key:
                    return data.get(key)
                else:
                    return data
            else:
                return None
        except Exception as e:
            print(f"Error retrieving data from MoME: {e}")
            return None

    def save(self, user_id, key, value):
        """Saves data to the MoME system."""
        try:
            data = self.get(user_id)
            if data is None:
                data = {}
            data[key] = value
            cursor = self.conn.cursor()
            cursor.execute("INSERT OR REPLACE INTO user_data (user_id, data) VALUES (?, ?)", (user_id, json.dumps(data)))  # Use json.dumps for serialization
            self.conn.commit()
        except Exception as e:
            print(f"Error saving data to MoME: {e}")


class Agent:
    def __init__(self, model, mome):
        self.model = model
        self.mome = mome

    def get_gemini_response(self, prompt, user_id=None, context=None):
        """Generates a response using Gemini 2.0, incorporating context."""
        if context:
            prompt = f"Conversation history:\n{context}\n\nUser: {prompt}"
        response = self.model.generate_content(contents=[prompt])
        return response.text

    def search_flights(self, origin, destination, month):
        """Searches for flights (simulated)."""
        # Replace with actual flight search API call
        print(f"Searching for flights from {origin} to {destination} in {month} 2025...")
        return [
            {"airline": "Air Canada", "price": 350, "departure_time": "10:00 AM"},
            {"airline": "United", "price": 400, "departure_time": "12:00 PM"},
        ]

    def search_hotels(self, location, month, preferences=None):
        """Searches for hotels (simulated)."""
        # Replace with actual hotel search API call
        print(f"Searching for hotels in {location} in {month} 2025...")
        hotels = [
            {
                "name": "Hotel A",
                "price": 150,
                "rating": 4.5,
                "description": "Close to Central Park",
            },
            {
                "name": "Hotel B",
                "price": 200,
                "rating": 4.2,
                "description": "Near Times Square",
            },
        ]
        if preferences and "hotel_type" in preferences:
            hotels = [
                hotel
                for hotel in hotels
                if preferences["hotel_type"].lower() in hotel["description"].lower()
            ]
        return hotels

    def get_yankees_tickets(self, month):
        """Gets Yankees tickets (simulated)."""
        # Replace with actual ticket purchase API call
        print(f"Getting Yankees tickets for a game in {month} 2025...")
        return {"section": "Legends Suite", "price": 1500}

    def plan_trip(self, user_id, origin, destination, month, budget):
        """Plans a trip using Gemini and MoME."""
        context = ""

        # Get initial response from Gemini
        prompt = f"Plan a trip from {origin} to {destination} in {month} 2025 with a budget of ${budget}, including a Yankees game with Legends Suite seats."
        response = self.get_gemini_response(prompt, user_id, context)
        context += f"User: {prompt}\nAgent: {response}\n"
        print(f"Agent: {response}")

        # Search for flights
        flights = self.search_flights(origin, destination, month)
        flight_options = "\n".join(
            [
                f"{flight['airline']} - ${flight['price']} - {flight['departure_time']}"
                for flight in flights
            ]
        )
        prompt = f"Here are some flight options:\n{flight_options}\nWhich one do you prefer?"
        response = self.get_gemini_response(prompt, user_id, context)
        context += f"User: {prompt}\nAgent: {response}\n"
        print(f"Agent: {response}")

        # Search for hotels (consider preferences from MoME)
        preferences = self.mome.get(user_id, "preferences")
        hotels = self.search_hotels(destination, month, preferences)
        hotel_options = "\n".join(
            [
                f"{hotel['name']} - ${hotel['price']} - {hotel['rating']} stars - {hotel['description']}"
                for hotel in hotels
            ]
        )
        prompt = f"Here are some hotel options:\n{hotel_options}\nWhich one do you prefer?"
        response = self.get_gemini_response(prompt, user_id, context)
        context += f"User: {prompt}\nAgent: {response}\n"
        print(f"Agent: {response}")

        # Get Yankees tickets
        tickets = self.get_yankees_tickets(month)
        prompt = f"I found {tickets['section']} tickets for ${tickets['price']} each. Should I book them?"
        response = self.get_gemini_response(prompt, user_id, context)
        context += f"User: {prompt}\nAgent: {response}\n"
        print(f"Agent: {response}")

        # ... (Continue with other activities and suggestions)

        # Save trip details to MoME
        self.mome.save(user_id, "last_trip", {"destination": destination})

if __name__ == "__main__":
    user_id = "user123"
    origin = "Montreal"
    destination = "New York City"
    month = "May"
    budget = 5000

    # Initialize MoME and Agent (using SQLite)
    mome_system = MoME()
    agent = Agent(model, mome_system)

    agent.plan_trip(user_id, origin, destination, month, budget)
# Out:
# Agent: Okay, let's plan an awesome Montreal to New York City trip in May 2025, with a focus on luxury at a Yankees game with Legends Suite seats, all while staying within a $5000 budget! This will require careful planning and prioritization.
#
# **Trip Overview:**
#
# *   **Duration:** 5 days / 4 nights (adjust to your preference)
# *   **Travel:** Train from Montreal to NYC
# *   **Accommodation:** Mix of well-located mid-range and potentially a splurge night
# *   **Focus:** High-end Yankees experience, exploring key NYC attractions
# *   **Budget Breakdown:** (Estimates, will be adjusted based on actual prices)
#
#     *   Transportation: $300
#     *   Accommodation: $1500
#     *   Yankees Game (Legends Suite): $1500-$2000 (This is the biggest variable)
#     *   Food & Drinks: $700
#     *   Activities & Attractions: $500
#     *   Buffer: $200 - $700 (Always good to have some wiggle room!)
#
# **Itinerary Outline:**
#
# **Day 1: Montreal to NYC & Arrival**
#
# *   **Morning:** Take an early train from Montreal to NYC (Amtrak is a good option). Consider booking well in advance for best prices.
# *   **Afternoon:** Arrive at Penn Station, NYC. Take a taxi or subway to your hotel in a central area like Midtown or near Grand Central.
# *   **Afternoon:** Check into your hotel.
# *   **Evening:**  Casual dinner at a local restaurant or pizza place. Explore Times Square.
#
# **Day 2: Iconic NYC**
#
# *   **Morning:** Visit the Empire State Building or Top of the Rock for panoramic views.
# *   **Afternoon:** Explore Central Park, rent a bike or have a picnic.
# *   **Late Afternoon:** Stroll down 5th Avenue, window shop, and check out St. Patrick's Cathedral.
# *   **Evening:** Dinner in a good, but not super-expensive restaurant in the area. See a Broadway show (budget permitting, could be a matinee on another day).
#
# **Day 3: Game Day & Night Out**
#
# *   **Morning:** Explore a different neighborhood, such as Greenwich Village or SoHo.
# *   **Afternoon:** Head to Yankee Stadium early. Soak in the pre-game atmosphere.
# *   **Evening:** **Yankees Game!** Enjoy the luxurious experience of Legends Suite seats. This includes VIP access, premium food, and drinks.
# *   **Late Evening:** If energy allows, grab a late-night snack and drink nearby the hotel.
#
# **Day 4: Culture & Views**
#
# *   **Morning:** Visit the Statue of Liberty and Ellis Island (book ferry tickets in advance).
# *   **Afternoon:** Explore the 9/11 Memorial & Museum or the Financial District.
# *   **Late Afternoon:** Walk across the Brooklyn Bridge for amazing skyline views.
# *   **Evening:**  Dinner in Brooklyn. Perhaps enjoy live music in a bar or check out a local brewery.
#
# **Day 5: Departure**
#
# *   **Morning:** Enjoy a final NYC brunch.
# *   **Late Morning:** Do any last-minute souvenir shopping.
# *   **Afternoon:** Take the train from Penn Station back to Montreal.
#
# **Budget Breakdown & Tips:**
#
# **1. Transportation (Estimated $300):**
#
# *   **Train:** Round-trip Amtrak from Montreal to NYC should cost around $200-$250 if booked in advance.
# *   **Local Transport:** $50 for subway fares, a few taxi/rideshares if needed.
# *   **Tip:** Book your train tickets as soon as your dates are firm for the best prices. Consider buying a Metrocard for subway travel.
#
# **2. Accommodation (Estimated $1500):**
#
# *   **Budgeting:** Aim for mid-range hotels or well-rated Airbnb in central areas (~$250-$350/night). This might need to be adjusted if Legends Suite seats are very high.
# *   **Recommendation:** Look at hotels in Midtown or near Grand Central for accessibility. Consider hotels like:
#     *   The Evelyn (Near the Flatiron)
#     *   The Refinery Hotel (Midtown)
#     *   Hyatt Grand Central
# *   **Potential Splurge:** If the Yankees game comes in on the lower end of the price, you could allocate some more to upgrade one of your nights to a slightly more upscale hotel or add a stay in a boutique hotel.
# * **Tip:**  Book accommodations ahead of time (once your game date is confirmed), especially if you are going in early May which can be a popular travel time.
#
# **3. Yankees Game (Legends Suite - Estimated $1500-$2000):**
#
# *   **Booking:** Purchase tickets through reputable ticket sellers as soon as the May 2025 schedule is available (usually late fall or early winter prior). Do your research on the seats.
# *   **Expect:** High cost, but the experience includes access to premium lounges, upscale dining options, and premium seating locations. This may include in-seat waiter service. Be mindful that food is included within Legends Suite ticket price.
# *   **Tip:** Be flexible on your game day if possible. Weekday games may have slightly lower Legends Suite prices. Consider working with a concierge service or high-end ticket broker for guidance.
#
# **4. Food & Drinks (Estimated $700):**
#
# *   **Budgeting:** This can be managed. Focus on some affordable lunches like NYC-style pizza, deli sandwiches, or food truck fare.
# *   **Dinners:** Try mid-range restaurants that offer good value for money, while reserving one or two meals for nice locations (think Italian in Little Italy, something fun in Brooklyn).
# *   **Yankees Game:** The Legends Suite includes food, which should save you on one night of dining.
# *   **Tips:** Take advantage of hotel breakfasts where possible. Consider pre-planning where you might eat in each area and look for specials.
#
# **5. Activities & Attractions (Estimated $500):**
#
# *   **Prioritize:** Choose the attractions that are most important to you. NYC has lots to see.
# *   **Save:** Consider using CityPASS to combine top attractions and save on entry fees.
# *   **Free:** Enjoy free activities like walking the Brooklyn Bridge, exploring Central Park, or window-shopping.
# *  **Tip**:  Book any paid activities or tours in advance online, and look for discounts or combo packages.
#
# **6. Buffer (Estimated $200 - $700):**
#
# *   **Importance:** This extra fund is crucial to absorb unexpected expenses, potential overspend, and just make sure you are covered.
# *   **Use:** Be sure to have this available in case you want to purchase a few more souvenirs, a nicer meal than you planned, or in case prices increase more than expected.
#
# **Key Planning Steps:**
#
# 1.  **Decide on exact dates:** Research the Yankees schedule for May 2025.
# 2.  **Book Legends Suite Tickets:** Priority #1.  Secure the game and date.
# 3.  **Book train tickets:** Ensure the times work well with your game date.
# 4.  **Book accommodation:** Once you have your date and tickets, book your hotel.
# 5.  **Make preliminary bookings:** Think through a few key activities you wish to do and book ahead.
# 6.  **Research restaurants:** Have a few options in mind before you leave.
#
# **Important Notes:**
#
# *   **May in NYC:**  Can be lovely but prepare for potential weather variability. Pack layers.
# *   **Flexibility:** Be open to adjusting plans on the go based on your energy levels, and always be mindful of your budget!
# *   **Keep track:** Use a spreadsheet or travel app to keep tabs on all your bookings and spending.
#
# This plan should help you have an unforgettable trip to NYC with a luxurious Yankees experience within your budget. Remember that the Legends Suite seats will be the largest budget item, so adjust your hotel and other expenses as needed to accommodate this. Have a fantastic time! Let me know if you want to refine any specific aspect!
#
# Searching for flights from Montreal to New York City in May 2025...
# Agent: Okay, thanks for providing those flight options! Let's analyze them and see which one is the better fit for your trip.
#
# **Considerations:**
#
# *   **Price:** Air Canada is $50 cheaper than United.
# *   **Time:** Air Canada departs at 10:00 AM, while United departs at 12:00 PM. This is a 2-hour difference.
# *   **Overall Trip Goals:** Remember the goal of this trip is to experience luxury at a Yankees game and have an overall amazing experience.
# *   **Flexibility:** How important is it to get into NYC early? Is there a lot planned before heading to the hotel?
#
# **Analysis:**
#
# *   **Air Canada ($350, 10:00 AM):**
#     *   **Pros:** Lower cost, allows you to arrive in NYC earlier, giving you more time to get settled, possibly get a head start on sightseeing, and have flexibility to get to your hotel. You'd have more of the day open for your activities.
#     *   **Cons:** If your flight is early in the morning, you'll need to leave your Montreal hotel very early.
# *   **United ($400, 12:00 PM):**
#     *   **Pros:** A later departure may allow for a more relaxed morning in Montreal, or time to finish any work you may be trying to complete before your departure.
#     *   **Cons:** Higher cost, arrives in NYC 2 hours later, possibly giving less time for sightseeing on arrival day, depending on your goals.
#
# **Recommendation:**
#
# Given that we are looking at a trip where time and experience are valuable and to help keep the overall budget in check:
#
# *   **I would recommend choosing the Air Canada flight departing at 10:00 AM for $350.**
#
# **Reasoning:**
#
# 1.  **Cost Savings:** The $50 you save can be reallocated towards other activities or even a slightly nicer dinner in NYC.
# 2.  **Time Advantage:** Arriving in NYC earlier gives you more time on your arrival day to explore, get situated, or handle any unexpected travel issues. This is important as you get closer to your Yankees game.
# 3.  **Efficiency:** Since you have a pretty full itinerary and the goal of seeing the game, maximizing your time is a good move.
#
# **Action:**
#
# Since I'm an AI, I cannot make the actual bookings for you.
# Based on my analysis, you should book the Air Canada flight. You can then adjust the itinerary a bit for the first day. For example, you may choose to explore a bit of your neighborhood before getting some casual dinner.
#
# **Next Steps:**
#
# Once you've booked your flight, let me know and we can move on to booking the train tickets, and making sure we have all the details for the game.
#
# Does this recommendation work for you?
#
# Searching for hotels in New York City in May 2025...
# Agent: Okay, let's analyze these hotel options and see which one better suits your trip.
#
# **Considerations:**
#
# *   **Price:** Hotel A is $50 cheaper per night than Hotel B.
# *   **Rating:** Hotel A has a slightly higher rating (4.5 stars) than Hotel B (4.2 stars).
# *   **Location:** Hotel A is close to Central Park, while Hotel B is near Times Square.
# *   **Overall Trip Goals:** Remember the goal is a balance of luxury, a great Yankees experience, and seeing key NYC attractions.
# *   **Itinerary:** We need to consider how the hotel locations align with your daily plans.
# *   **Vibe:** Central Park offers a more relaxed feel, while Times Square is very energetic and bustling.
#
# **Analysis:**
#
# *   **Hotel A ($150/night, 4.5 stars, Close to Central Park):**
#     *   **Pros:** Lower cost, higher rating, quieter, more relaxed atmosphere, and easy access to Central Park, which is on your itinerary. It may be nicer to return to the hotel after a busy day.
#     *   **Cons:** Slightly less convenient access to the Times Square area (though still accessible).
# *   **Hotel B ($200/night, 4.2 stars, Near Times Square):**
#     *   **Pros:** Central location near Times Square, with easy access to Broadway theaters and shopping. Great to be in the heart of the action.
#     *   **Cons:** Higher cost, slightly lower rating, potentially louder and more crowded surroundings, may be a less peaceful place to return to after a busy day.
#
# **Recommendation:**
#
# Considering the need to balance cost, comfort, and strategic location:
#
# *   **I recommend choosing Hotel A (Close to Central Park) for $150 per night.**
#
# **Reasoning:**
#
# 1.  **Cost-Effectiveness:** The $50 per night savings can be used to enhance other areas of your trip, such as upgrading a meal, or adding to your buffer.
# 2.  **High Rating:** Despite the price difference, Hotel A offers a higher rating, indicating a potentially better experience for you.
# 3.  **Strategic Location:** While being near Times Square is exciting, Central Park is a key attraction on your itinerary, and being nearby allows you to easily enjoy the park. It's also a great place to stay if you're hoping for a more restful and relaxing hotel experience.
# 4.  **Flexibility:** You can easily reach Times Square and other areas of Manhattan using the subway, even if you're not staying directly in the area.
#
# **Additional Notes:**
#
# *   **Walkability:** Both locations are walkable, but Central Park is better for walks, while the Times Square area is ideal if you love being in the middle of the buzz.
# *   **Personal Preference:** Consider what kind of atmosphere you prefer. Do you want to be in the middle of the action? Or would you like to come back to a more peaceful setting at the end of the day?
#
# **Action:**
#
# Since I am an AI, I cannot make reservations. However, my recommendation is to book Hotel A, which will give you a great experience, save money, and is in a great location.
#
# **Next Steps:**
#
# Once you have booked Hotel A, let me know and we can move on to the next steps. This would include firming up your dates and game, then booking the train tickets, and finalizing any key activities.
#
# Does this recommendation work for you? Are there any other things you might need to consider in choosing between these two options?
#
# Getting Yankees tickets for a game in May 2025...
# Agent: Okay, $1500 each for Legends Suite tickets is definitely a significant investment. Let's analyze this carefully before making a decision.
#
# **Considerations:**
#
# *   **Budget:** Your initial budget was $5000 for the entire trip. Two Legends Suite tickets at $1500 each would immediately consume $3000 of that budget.
# *   **Value:** Legends Suite tickets offer a luxurious experience, including premium seating, upscale dining options, and access to exclusive lounges.
# *   **Alternatives:** Could you have an amazing trip with less expensive seats, potentially allowing for a more luxurious stay or other experiences?
# *   **Opportunity Cost:** Spending $3000 on tickets means you'll have less for accommodation, dining, activities, and buffer.
#
# **Analysis:**
#
# *   **High Cost:** $3000 for two tickets is a very large percentage of the $5000 budget.
# *   **Luxury Experience:** The Legends Suite offers an undeniably premium experience. This is a once-in-a-lifetime type of splurge that some fans really value.
# *   **Budget Impact:** This price will require adjustments in other areas to stay within your budget. You might need to consider less expensive accommodation or fewer activities.
# *   **Resale:** While possible, it's unlikely that you'd be able to resell these at or above face value.
# *   **Longer Trip vs. One-off Luxury:** We need to ask whether you'd rather have one ultra-luxurious experience or a longer trip with slightly more moderately priced items.
#
# **Recommendation:**
#
# Given all factors, and the fact that a key goal of this trip was a luxurious experience at the Yankees game:
#
# *   **Yes, I recommend booking the Legends Suite tickets for $1500 each.**
#
# **Reasoning:**
#
# 1.  **Primary Goal:** The initial plan was to prioritize the Legends Suite experience. This fulfills that core objective.
# 2.  **Value of the Experience:** The included amenities like premium dining, exclusive lounge access, and best-in-class seating provide an elevated and memorable experience.
# 3.  **Unique Opportunity:** For many, this is a one-time opportunity to enjoy this level of luxury at a sporting event, which is what you had in mind for this trip.
# 4.  **Budget Adjustments:** We can still have a great trip within the $5000 budget. We can adjust our hotel choices a bit, and we will keep an eye on other expenses.
# 5.  **Satisfaction:** Booking the Legends Suite seats ensures that you have the highest-level experience at your chosen game.
#
# **Action:**
#
# You should move to purchase the tickets as soon as possible, given that they are now available.
#
# **Next Steps:**
#
# Once you book these tickets, let me know. We will need to:
#
# 1.  **Lock in Dates:** Now that you've found a price you are happy with, firm up the exact dates you will travel.
# 2.  **Adjust Budget:** We need to readjust the budget based on this expenditure. We can adjust the hotel or other areas, as required.
# 3.  **Book Travel:** We need to book your train tickets to New York now that we have a date for the game.
# 4.  **Plan Activities:** We can continue to plan activities and dining, keeping in mind our adjusted budget.
#
# **Important Note:**
#
# Be absolutely certain that you are comfortable with the budget impact before proceeding with this purchase. While this will be a fantastic experience, it's good to know where you might have to compromise in other areas.
#
# Does this recommendation align with your thinking, and are you comfortable moving ahead with purchasing these tickets?

# %% [markdown]
# ## new version

# %%
import google.generativeai as genai
from google.colab import userdata
import datetime
import calendar
import sqlite3
import json

# Retrieve API key from userdata
GOOGLE_API_KEY = userdata.get('GEMINI')

# Check if API key is retrieved successfully
if GOOGLE_API_KEY is None:
    raise ValueError("API key not found in userdata['GEMINI'].")

# Configure the client with the API key
genai.configure(api_key=GOOGLE_API_KEY)

# Choose the appropriate Gemini 2.0 model
model = genai.GenerativeModel(model_name='models/gemini-2.0-flash-exp')

class MoME:
    """
    A MoME system using SQLite for persistence.
    """

    def __init__(self, db_file="mome.db"):
        self.db_file = db_file
        self.conn = sqlite3.connect(self.db_file)
        self.create_table()

    def create_table(self):
        """Creates the user_data table if it doesn't exist."""
        cursor = self.conn.cursor()
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS user_data (
                user_id TEXT PRIMARY KEY,
                data TEXT
            )
        ''')
        self.conn.commit()

    def get(self, user_id, key=None):
        """Retrieves data from the MoME system."""
        try:
            cursor = self.conn.cursor()
            cursor.execute("SELECT data FROM user_data WHERE user_id=?", (user_id,))
            row = cursor.fetchone()

            if row:
                # Correctly handle potential empty data
                if row[0] is None:
                    data = {}
                else:
                    data = json.loads(row[0])  # Use json.loads for deserialization
                if key:
                    return data.get(key)
                else:
                    return data
            else:
                return None
        except Exception as e:
            print(f"Error retrieving data from MoME: {e}")
            return None

    def save(self, user_id, key, value):
        """Saves data to the MoME system."""
        try:
            data = self.get(user_id)
            if data is None:
                data = {}
            data[key] = value
            cursor = self.conn.cursor()
            cursor.execute("INSERT OR REPLACE INTO user_data (user_id, data) VALUES (?, ?)", (user_id, json.dumps(data)))
            self.conn.commit()
        except Exception as e:
            print(f"Error saving data to MoME: {e}")

class Agent:
    def __init__(self, model, mome):
        self.model = model
        self.mome = mome

    def get_gemini_response(self, prompt, user_id=None, context=None):
        """Generates a response using Gemini 2.0, incorporating context."""
        if context:
            prompt = f"Conversation history:\n{context}\n\nUser: {prompt}"
        try:
            response = self.model.generate_content(contents=[prompt])
            return response.text
        except Exception as e:
            print(f"Error generating Gemini response: {e}")
            return "Sorry, I'm having trouble generating a response right now."

    def search_flights(self, origin, destination, month):
        """Searches for flights (simulated)."""

        # Replace with actual flight search API call
        print(f"Searching for flights from {origin} to {destination} in {month} 2025...")
        return [
            {"airline": "Air Canada", "price": 350, "departure_time": "10:00 AM"},
            {"airline": "United", "price": 400, "departure_time": "12:00 PM"},
        ]

    def search_hotels(self, location, month, preferences=None):
        """Searches for hotels (simulated)."""

        # Replace with actual hotel search API call
        print(f"Searching for hotels in {location} in {month} 2025...")
        hotels = [
            {
                "name": "Hotel A",
                "price": 150,
                "rating": 4.5,
                "description": "Close to Central Park",
            },
            {
                "name": "Hotel B",
                "price": 200,
                "rating": 4.2,
                "description": "Near Times Square",
            },
        ]

        if preferences and "hotel_type" in preferences:
            hotels = [
                hotel
                for hotel in hotels
                if preferences["hotel_type"].lower() in hotel["description"].lower()
            ]

        return hotels

    def get_yankees_tickets(self, month):
        """Gets Yankees tickets (simulated)."""

        # Replace with actual ticket purchase API call
        print(f"Getting Yankees tickets for a game in {month} 2025...")
        return {"section": "Legends Suite", "price": 1500}

    def plan_trip(self, user_id, origin, destination, month, budget):
        """Plans a trip using Gemini and MoME."""
        context = ""

        # Get initial response from Gemini
        prompt = f"Plan a trip from {origin} to {destination} in {month} 2025 with a budget of ${budget}."
        response = self.get_gemini_response(prompt, user_id, context)
        context += f"User: {prompt}\nAgent: {response}\n"
        print(f"Agent: {response}")

        # Search for flights
        flights = self.search_flights(origin, destination, month)
        flight_options = "\n".join(
            [
                f"{flight['airline']} ${flight['price']} {flight['departure_time']}"
                for flight in flights
            ]
        )
        prompt = f"Here are some flight options:\n{flight_options}\nWhich one should I choose?"
        response = self.get_gemini_response(prompt, user_id, context)
        context += f"User: {prompt}\nAgent: {response}\n"
        print(f"Agent: {response}")

        # Search for hotels (consider preferences from MoME)
        preferences = self.mome.get(user_id, "preferences")
        hotels = self.search_hotels(destination, month, preferences)
        hotel_options = "\n".join(
            [
                f"{hotel['name']} ${hotel['price']} {hotel['rating']}"
                for hotel in hotels
            ]
        )
        prompt = f"Here are some hotel options:\n{hotel_options}\nWhich one should I choose?"
        response = self.get_gemini_response(prompt, user_id, context)
        context += f"User: {prompt}\nAgent: {response}\n"
        print(f"Agent: {response}")

        # Get Yankees tickets
        tickets = self.get_yankees_tickets(month)
        prompt = f"I found {tickets['section']} tickets for ${tickets['price']} each. Should I buy them?"
        response = self.get_gemini_response(prompt, user_id, context)
        context += f"User: {prompt}\nAgent: {response}\n"
        print(f"Agent: {response}")

        # (Continue with other activities and suggestions)

        # Save trip details to MoME
        self.mome.save(user_id, "last_trip", {"destination": destination})

if __name__ == "__main__":
    user_id = "user123"
    origin = "Montreal"
    destination = "New York City"
    month = "May"
    budget = 5000

    # Initialize MoME and Agent (using SQLite for MoME)
    mome_system = MoME()
    agent = Agent(model, mome_system)
    agent.plan_trip(user_id, origin, destination, month, budget)
# Out:
# Agent: Okay, let's plan a fantastic trip from Montreal to New York City in May 2025 with a budget of $5000! This plan will focus on a balance of enjoyable experiences, comfortable accommodation, and reasonable transportation costs. We'll assume a trip duration of approximately 7 days, allowing for travel days.
#
# **Assumptions & Clarifications:**
#
# *   **Travelers:** This plan is based on a solo traveler or a couple. Adjustments might be needed for larger groups.
# *   **Travel Style:** We'll aim for a mix of cultural experiences, some relaxation, and good food, with a moderate pace.
# *   **Flexibility:** Prices can fluctuate. This plan is an estimate, and you'll need to confirm prices closer to your travel date and potentially adjust based on your personal preferences.
# *   **Currency:**  All prices are in USD, but convert from CAD to USD closer to the date, as exchange rates fluctuate.
# *   **Dates:**  We'll assume mid-May to avoid peak Memorial Day crowds, but you can adjust the specific week based on your preferences and potential event schedules.
# *   **Flight/Train:** We'll assume one-way transportation from Montreal to NYC.
#
# **Estimated Budget Breakdown:**
#
# | Category              | Estimated Cost (USD) | Notes                                                                                                                                   |
# | ---------------------- | -------------------- | ------------------------------------------------------------------------------------------------------------------------------------- |
# | Transportation        | $500                 | Train or flight from Montreal to NYC, and local transportation within NYC                                                            |
# | Accommodation         | $2000                 | Mid-range hotels/Airbnb for 6 nights                                                                                             |
# | Food                  | $1000                | Mixture of casual eateries, some nice restaurants, snacks, and coffee                                                                 |
# | Activities & Entry Fees | $1000                 | Museums, attractions, Broadway show, activities                                                                                                 |
# | Shopping & Souvenirs   | $200                | Optional spending for souvenirs, gifts                                                                                               |
# | Contingency          | $300                 |  For unexpected expenses or adjustments                                                                                                 |
# | **Total**             | **$5000**              |                                                                                                                                     |
#
# **Detailed Trip Plan:**
#
# **Day 1: Travel to NYC & Settling In**
#
# *   **Morning:**
#     *   Check out of your accommodation in Montreal.
#     *   Travel to Montreal Central Station or Trudeau Airport.
#     *   Take a Train (Amtrak) or Flight to NYC (LaGuardia (LGA), JFK or Newark (EWR)). Trains are often scenic and more affordable but take longer, while flights are quicker.
#         *   **Estimated cost:** $150 - $250. Check prices on Amtrak, Expedia, or Kayak.
#     *   Upon arrival, take public transit (subway or AirTrain) or a taxi to your accommodation in NYC.
#         *   **Estimated cost:** $20 - $50.
# *   **Afternoon:**
#     *   Check in to your hotel/Airbnb in a central location like Midtown, the Lower East Side, or Greenwich Village.
#         *   **Estimated cost:** $250 - $350 per night.
#     *   Settle in, take a short break.
# *   **Evening:**
#     *   Have a casual dinner in a local neighborhood.
#         *   **Estimated cost:** $30 - $40 per person.
#     *   Explore your neighborhood on foot.
#         *   **Free**
#
# **Day 2: Iconic NYC Landmarks**
#
# *   **Morning:**
#     *   Start with breakfast at a local diner.
#         *   **Estimated cost:** $15 - $25.
#     *   Head to Times Square for the iconic experience.
#         *   **Free**
#     *   Walk down to the New York Public Library and Grand Central Terminal.
#         *   **Free**
# *   **Afternoon:**
#     *   Visit the top of the Empire State Building or Top of the Rock for panoramic views.
#         *   **Estimated cost:** $40 - $50 per person.
#     *   Lunch in the area.
#         *   **Estimated cost:** $25 - $35 per person.
# *   **Evening:**
#     *   Enjoy a nice dinner at a restaurant in the Theater District or a restaurant of your choice.
#         *   **Estimated cost:** $50 - $80 per person.
#
# **Day 3: Museums and Central Park**
#
# *   **Morning:**
#     *   Head to the Upper East Side to explore Museum Mile.
#     *   Choose a museum based on your interests: The Metropolitan Museum of Art (The Met), The Museum of Modern Art (MoMA), or the American Museum of Natural History.
#         *   **Estimated cost:** $25 - $30 per person per museum.
#     *   Have a quick lunch near the museum.
#         *   **Estimated cost:** $20 - $30.
# *   **Afternoon:**
#     *   Spend the afternoon exploring Central Park.
#     *   Rent a bike, take a walk, or have a picnic.
#         *   **Estimated cost:** $15 - $30 for bike rental.
# *   **Evening:**
#     *   Enjoy a relaxing dinner in a restaurant near Central Park or your accommodation.
#        * **Estimated cost:** $40 - $60 per person.
#
# **Day 4: Downtown & History**
#
# *   **Morning:**
#     *   Take the subway downtown to explore the Financial District.
#     *   Visit the 9/11 Memorial & Museum.
#         *   **Estimated cost:** $26 per person.
#     *   See Wall Street and the Charging Bull statue.
#         *   **Free**
# *   **Afternoon:**
#     *   Take a ferry to Staten Island for a FREE view of the Statue of Liberty and the Manhattan Skyline.
#        * **Free**
#     *   Lunch in the area.
#          * **Estimated cost:** $20 - $30 per person
# *   **Evening:**
#     *   Have dinner in a trendy restaurant in the Lower Manhattan area.
#         *   **Estimated cost:** $50 - $70 per person.
#
# **Day 5: Greenwich Village & a Broadway Show**
#
# *   **Morning:**
#     *   Explore Greenwich Village.
#     *   Browse independent bookstores, cafes, and shops.
#         *   **Free (unless you purchase something!)**
#     *   Have lunch at a cafe in the village.
#         *  **Estimated cost:** $20 - $30 per person.
# *   **Afternoon:**
#     *   Relax, get ready for an evening out.
# *  **Evening:**
#     *  Enjoy a Broadway Show.
#          *  **Estimated cost:** $100 - $200 per person (depending on the show and seats). Book in advance!
#     *   Have a late dinner in the Theater District.
#         *   **Estimated cost:** $30 - $50 per person.
#
# **Day 6: Brooklyn Exploration**
#
# *   **Morning:**
#     *   Take the subway to Brooklyn.
#     *   Explore the trendy neighborhood of Williamsburg.
#     *   Walk or bike across the Brooklyn Bridge for great views of the Manhattan skyline.
#         *   **Free (but bike rental $15-$30)**
# *   **Afternoon:**
#     *   Explore DUMBO (Down Under the Manhattan Bridge Overpass) with its charming cobblestone streets, art galleries, and waterfront views.
#     *   Have a casual lunch in Brooklyn.
#         *   **Estimated cost:** $20 - $30 per person.
# *   **Evening:**
#     *   Have a relaxed dinner in Brooklyn.
#         *   **Estimated cost:** $30 - $50 per person.
#     *   Consider catching some live music at a venue in Brooklyn.
#
# **Day 7: Departure**
#
# *   **Morning:**
#     *   Enjoy a final breakfast in NYC.
#         *   **Estimated cost:** $15 - $25.
#     *   Depending on your flight/train departure time, you could squeeze in one last activity or some souvenir shopping.
#     *   Check out of your accommodation.
#     *   Travel to the airport (LGA, JFK, or EWR) or Penn Station for your departure.
#         *   **Estimated cost:** $20 - $50.
#
# **Tips for Saving Money:**
#
# *   **Travel in the Shoulder Season:** May is a good time to travel, but consider going mid-week for better prices and slightly fewer crowds.
# *   **Accommodation:** Consider staying slightly outside the main tourist areas for more affordable options, or explore hostels.
# *   **Free Activities:** NYC has many free activities including walking around neighborhoods, visiting parks, and seeing free sights.
# *   **Food:**  Eat at more casual restaurants and markets, and take advantage of lunch specials.
# *   **Transportation:** Walk or use the subway as much as possible. A 7-day unlimited MetroCard may be a good investment if you plan on using the subway heavily.
# *   **City Pass:** Consider a city pass that provides discounts on many attractions if you plan to do many paid activities.
# *   **Look for deals:**  Check websites like Groupon, LivingSocial and others for deals on shows or experiences.
#
# **Next Steps:**
#
# 1.  **Confirm Your Dates:** Decide on the exact dates you'll travel in May 2025.
# 2.  **Book Flights/Train:** Secure your transportation in advance to potentially get the best prices.
# 3.  **Book Accommodation:**  Reserve your hotel or Airbnb soon after booking transport.
# 4.  **Research Activities:** Plan your daily itinerary, booking any tickets for popular attractions in advance.
# 5.  **Purchase a MetroCard:** Research transportation options and purchase an unlimited metrocard.
# 6.  **Start a list of food places to try:** Start planning what restaurants and local eats to try.
#
# This is a flexible itinerary, so feel free to adjust it based on your interests, desired activities and budget. Have an incredible time in NYC!
#
# Searching for flights from Montreal to New York City in May 2025...
# Agent: Okay, let's analyze those flight options to help you make the best choice for your trip.
#
# **Factors to Consider:**
#
# *   **Price:** Air Canada is $50 cheaper than United.
# *   **Time:** Air Canada departs at 10:00 AM, while United departs at 12:00 PM.
# *   **Personal Preference:** Do you have a preference for either airline? Are you in a rush to arrive or would you prefer a later start?
# *   **Arrival Time:** We'll need to consider what the arrival time would be and if either of them impacts your first day in NYC
# *   **Airport:** Which airport in NYC are these flights going to?
#
# **Analysis:**
#
# 1.  **Price:** The $50 difference is a notable saving. If your budget is a primary concern, Air Canada is the more economical choice.
# 2.  **Time:**
#     *   **Air Canada (10:00 AM):** A 10:00 AM departure gets you to NYC a bit earlier in the day, allowing for potentially more time to settle in and start exploring on your arrival day. Depending on the flight duration, you could arrive in NYC mid-afternoon.
#     *  **United (12:00 PM):** A 12:00 PM departure would get you into NYC a bit later in the afternoon, shortening your first day in terms of exploring. Depending on the flight duration you might arrive late afternoon or early evening.
# 3.  **Airline Preference:** If you have a history or preference with either airline, it could sway your decision. Check reviews for both airlines if you are unsure.
# 4. **Arrival Time:** You'll need to know which NYC airport each flight arrives at, and the flight duration, in order to get a better picture of when you'll arrive in NYC.
#
# **Recommendations:**
#
# *   **If Budget is a Top Priority:** **Choose Air Canada.** The $50 saving can be put towards other activities during your trip.
# *   **If you want to maximize time on your first day in NYC:** **Choose Air Canada.** An earlier arrival will allow for more time to settle in, have a meal, and see some of the city.
# *   **If you prefer a slightly later start:** **Choose United.** If you don't mind arriving later, the later flight might suit your personal preference better.
# *   **Check Flight Duration and Arrival Airport:** Check what the actual flight times are as well as which airport in NYC each flight arrives at before booking either.
#
# **Before You Make a Final Decision:**
#
# 1.  **Double-Check the Details:** Before booking, confirm that the flight times and prices are as advertised.
# 2.  **Check Airport Arrival:** Verify which New York airport each flight arrives at (LGA, JFK, or EWR) and which is most convenient for you.
# 3.  **Consider Baggage Fees:** Check the baggage policies of both airlines as this can add cost to your flight if not included in the quoted flight price.
#
# **My Recommendation (with the information I have):**
#
# Based solely on the information provided, I would **lean towards Air Canada**. The earlier flight and $50 savings, for me, are both beneficial, as long as the airport arrival works for you.
#
# **Next Steps:**
#
# 1.  **Confirm Airport:** Find out the NYC arrival airport for both flights.
# 2.  **Check Flight Duration:** Find out how long the flights are to make an informed decision based on arrival time.
# 3.  **Make Your Choice:** Choose the flight that best fits your needs.
# 4.  **Book!** Once you've chosen, book the flight as soon as you can to secure your price.
#
# Let me know if you find out the arrival airports and duration and I can give you an even more specific recommendation!
#
# Searching for hotels in New York City in May 2025...
# Agent: Okay, let's analyze these hotel options to determine which might be the better fit for your trip, considering both price and rating.
#
# **Factors to Consider:**
#
# *   **Price:** Hotel A is $50 cheaper per night than Hotel B.
# *   **Rating:** Hotel A has a 4.5-star rating, while Hotel B has a 4.2-star rating.
# *   **Location:** We don't have the location of either hotel. Location is extremely important in NYC. A lower rated but more conveniently located hotel may be preferable to a higher rated hotel in a less desirable area.
# *   **Amenities:** We don't know what amenities each hotel has. Some amenities might be more important to you than others.
# *   **Reviews:** The star rating is an overall measure but may be based on many reviews that may not match your specific needs or preferences.
#
# **Analysis:**
#
# 1.  **Price:** The $50 per night difference can add up over a 6-night stay. Hotel A would save you $300 on accommodation, allowing you to put that money towards food, activities, or other aspects of your trip.
# 2.  **Rating:**
#     *   **Hotel A (4.5 Stars):** A 4.5-star rating is considered very good, suggesting a high level of guest satisfaction, good service, and overall quality.
#     *   **Hotel B (4.2 Stars):** A 4.2-star rating is still good, but it indicates that it may have slightly more drawbacks or inconsistencies compared to Hotel A. However, a 4.2 might still be a wonderful hotel.
# 3.  **Location:** This is a crucial piece of information. A hotel that is well-located for your trip may be more valuable than a hotel with a slightly higher rating but in a location that is inconvenient for you. In NYC, being close to the subway and/or the specific areas you plan to visit is very important.
# 4.  **Amenities:** The amenities can be a factor, if the hotel with the slightly lower rating has amenities that are more valuable to you than the hotel with the higher rating, it may be worth sacrificing the rating. Examples: Free breakfast, gym, etc.
# 5. **Reviews:** Individual reviews may reveal if there are specifics that impact your decision. If Hotel B has lower reviews because of something that doesn't bother you, it may still be a good choice.
#
# **Recommendations:**
#
# *   **Based on Price and Rating Alone:** **Hotel A is the slightly better option.** It offers a higher rating for a lower price.
# *   **However, Location is Very Important:** Before you finalize your choice, you **MUST** consider the location of both hotels.
# *   **If a Specific Amenity is Important to You:** If either hotel has a specific amenity that is important to you (e.g. free breakfast, etc) that may sway your decision.
#
# **Before You Make a Final Decision:**
#
# 1.  **Find the Locations:** Determine the locations of both Hotel A and Hotel B. Check their proximity to subway lines, the areas you plan to visit, etc.
# 2.  **Read Detailed Reviews:** Go to sites like TripAdvisor, Booking.com, or Google Reviews, and read some of the detailed reviews from recent guests to gain a more nuanced view of both hotels. Look for reviews that mention the specific things that are important to you (ex. cleanliness, noise levels, bed comfort, etc).
# 3. **Check Amenities:** Make sure that Hotel A and B have the amenities that you require (ex. Wifi, air conditioning, etc).
#
# **My Recommendation (with the information I have):**
#
# Based solely on the price and rating, **Hotel A seems to be the slightly better option.** But, the **location of both hotels must be determined** before you can make an informed choice.
#
# **Next Steps:**
#
# 1.  **Find the Locations:** Find the exact locations of both hotels.
# 2.  **Read Reviews:** Read detailed reviews of both hotels.
# 3.  **Check Amenities:** Check what amenities each hotel has.
# 4.  **Make Your Choice:** Choose the hotel that best fits your needs based on all of this information.
# 5.  **Book!** Once you've chosen, book your hotel as soon as you can to secure your preferred dates.
#
# Let me know what the locations are, as well as any additional information about amenities or specific reviews, and I can give you a more specific recommendation!
#
# Getting Yankees tickets for a game in May 2025...
# Agent: Okay, let's analyze whether purchasing Legends Suite tickets for $1500 each is a good decision for your trip to New York City in May 2025. This is a significant expense, so we need to consider it carefully.
#
# **What are Legends Suite Tickets?**
#
# Before we proceed, let's make sure we're on the same page. Generally, Legends Suite tickets typically refer to premium seating options at sports stadiums or entertainment venues. They usually include:
#
# *   **Premium Seating:** Often in a prime location with excellent views.
# *   **Exclusive Amenities:** This might include access to a private lounge, upscale food and beverage options, private restrooms, and other perks.
# *   **High Cost:** Because of the premium experience, Legends Suite tickets are typically very expensive.
#
# **Factors to Consider:**
#
# 1.  **Your Budget:**
#     *   Your total trip budget is $5000.
#     *   Legends Suite tickets at $1500 each (assuming one ticket) would consume a significant portion (30%) of your total budget.
# 2.  **What is the Event?**
#     *   Is it a sporting event, a concert, or something else? Your decision should be influenced by how important this specific event is to you.
# 3.  **How Much Do You Value the Experience?**
#     *   Are you someone who highly values premium experiences, and are willing to spend a lot more for them?
#     *   Would you prefer to allocate the $1500 towards multiple other activities and experiences?
# 4.  **Opportunity Cost:**
#     *   What else could you do with $1500? You could use it for multiple Broadway shows, exceptional dining experiences, shopping, and other things.
# 5. **Is it a Once in a Lifetime Opportunity?**
#     * If it's a once-in-a-lifetime opportunity it may be worth the price.
# 6. **Is it a Must-See?**
#      * Is the event a "must-see" on your trip, or would you be okay skipping it?
# 7. **Is there a Cheaper Alternative?**
#      * Are there cheaper alternatives that would still give you a good experience?
#
# **Analysis:**
#
# 1.  **Budget Impact:** Spending $1500 on a single ticket will significantly reduce your budget for other activities, dining, and potentially even accommodation. It might force you to make sacrifices elsewhere in your trip.
# 2.  **Value:** Only you can truly determine if the value of the Legends Suite experience justifies the cost. If it's a dream experience, it might be worth it. But if you are just looking for a way to catch a game or a concert, cheaper alternatives might make more sense.
# 3.  **Alternatives:** Consider if there are cheaper seats, or other events that would give you a similar level of enjoyment but at a more reasonable price. In the case of a Broadway Show, there are much cheaper alternatives that still give you an enjoyable theater experience.
# 4. **Event Type:** Is this for a sport, or a concert? You might want to look into other options for either type of event based on your preference.
# 5. **Must-See:** If the event is not a must-see on your list, or there are alternatives, you might want to skip it to stay within your budget.
#
# **Recommendations:**
#
# *   **If Budget is a Top Priority:** **Do NOT buy the Legends Suite Tickets.** A $1500 ticket for a single event is an extremely high cost within a $5000 total trip budget.
# *   **If You Value the Experience Extremely Highly:** **Consider it,** but only if it's a once-in-a-lifetime opportunity and you are certain it won't detract from the rest of your trip. You'll need to be prepared to significantly reduce spending in other areas.
# *   **If You are on the Fence:** **Look for cheaper alternatives**. This may include cheaper seating at the same event, or going to a different event.
# *   **If You are Unsure:** **Consider Skipping it.** If you are unsure, you may want to skip the event, so that you don't regret spending that amount of money.
#
# **Before You Make a Final Decision:**
#
# 1.  **Clarify the Event:** Confirm the specifics of the event: what type of event it is, when and where, what specific amenities are included, and if there are any other less expensive seating options available.
# 2.  **Reassess Your Budget:** Confirm if you are willing to allocate this amount of your total trip budget to this one event.
# 3.  **Explore Alternatives:** Consider what other activities you could do with $1500 and if you'd be happier allocating funds in that way instead.
# 4.  **Consider Cheaper Tickets:** Explore the possibility of buying less expensive tickets for the same event, or similar events.
#
# **My Recommendation (with the information I have):**
#
# Based on the information available, I would **recommend AGAINST buying the Legends Suite tickets.** Spending $1500 on a single ticket will take up 30% of your budget and severely restrict your ability to enjoy other aspects of your trip. Unless it is a truly once-in-a-lifetime opportunity, that price is not justified.
#
# **Next Steps:**
#
# 1.  **Provide more information:** Tell me what event these tickets are for and if there are alternatives.
# 2.  **Reassess your budget:** Reassess if you are comfortable with spending that amount of money on a single ticket.
# 3.  **Make your decision:** Make the best decision for your particular preferences.
#
# Let me know if you want to explore some alternatives!
