# %% [markdown]
# <a href="https://colab.research.google.com/github/frank-morales2020/MLxDL/blob/main/AGI_GEMINI3_DEMO_GOOGLE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import re
import pytz
from datetime import datetime
# Attempt to import Colab specific user data functionality
try:
    from google.colab import userdata
except ImportError:
    # Define a dummy object for non-Colab environments
    class MockUserdata:
        def get(self, key, default=None):
            return default
    userdata = MockUserdata()

import google.generativeai as genai
from google.generativeai import types

# --- MOCK CLIENT FALLBACK (Defined as per the reference notebook) ---
class MockGeminiClient:
    """Simulates Gemini 3 Pro for successful single-shot execution when API/file setup fails."""
    def __init__(self):
        self.iteration = 0
        self.is_mock = True
    def generate_content(self, contents, **kwargs):
        self.iteration += 1
        # Simulates the successful, constraint-adherent output seen in the reference log
        mock_content = (
            "### RADIOLOGICAL CLINICAL REPORT\n\n1. Perception/Fact Extraction: Colonic "
            "distention, mural thickening, and pericolonic fat stranding were observed.\n\n2. "
            "Diagnosis & Plan: Most Likely Diagnosis: Stercoral Colitis. Acute Management: Endoscopic "
            "removal (flexible sigmoidoscopy). Long-Term: Pelvic-Floor Physical Therapy, Anorectal "
            "Manometry, and Biofeedback. Potential Complications: Focal-Pressure Necrosis and Perforation."
        )
        return type('MockResponse', (object,), {'text': mock_content})()

# --- GEMINI CLIENT SETUP (Strictly following the reference's logic) ---
GEMINI_MODEL_ID = 'gemini-3-pro-preview'
GEMINI_API_KEY = None
gemini_model = None

try:
    # 1. PRIORITY 1: Retrieve API key from Colab Secrets using key 'GEMINI' (as per reference)
    GEMINI_API_KEY = userdata.get('GEMINI')

    # 2. PRIORITY 2: Fallback to environment variable 'GEMINI_API_KEY'
    if not GEMINI_API_KEY:
        GEMINI_API_KEY = os.getenv('GEMINI_API_KEY')

    if not GEMINI_API_KEY:
        # If no key is found, raise an error to trigger the mock fallback
        raise ValueError("API key not found via Colab Secrets ('GEMINI') or environment variable ('GEMINI_API_KEY').")

    genai.configure(api_key=GEMINI_API_KEY)
    gemini_model = genai.GenerativeModel(GEMINI_MODEL_ID)
    print(f"Gemini client successfully configured for model: {GEMINI_MODEL_ID}.")

    # --- Utility Function: Load Image for Gemini API ---
    def load_image_part(file_path):
        """Loads and uploads the local file, returning the File object."""
        if not os.path.exists(file_path):
             # Return None if file is missing, allowing the main loop to handle it
             print(f"Image file not found at {file_path}. The agent will attempt to proceed but may fail without multimodal input.")
             return None

        uploaded_file = genai.upload_file(file_path)
        print(f"File uploaded to Gemini API: {uploaded_file.name}")
        return uploaded_file

except Exception as e:
    # This block executes if the API key setup failed, triggering the Mock Client
    print(f"FATAL ERROR during Gemini setup. Using Mock Client: {e}")
    gemini_model = MockGeminiClient()
    GEMINI_MODEL_ID = "MOCK_GEMINI_3_PRO"
    print("Switched to Mock Client.")


# --- 1. Image Analysis Agent (Gemini 3 Pro) ---
class ImageAnalysisAgent:
    """The Gemini 3 Pro Reasoning Engine, handling both perception and diagnosis."""
    def __init__(self, model_instance):
        self.model = model_instance

    def analyze_image_and_diagnose(self, prompt, image_part):
        """Sends the prompt and image directly to Gemini for a combined output."""
        if hasattr(self.model, 'is_mock'):
             return self.model.generate_content(contents=prompt).text

        # The core multimodal API call
        contents = [prompt]
        if image_part:
            contents.append(image_part)

        response = self.model.generate_content(
            contents=contents
        )
        return response.text.strip()


# --- 2. Validation Agent (Constraint and Safety Enforcement) ---
class ValidationAgent:
    """Pillars 3 & 4: Constraint and Safety Enforcement"""
    def __init__(self):
        self.expected_patterns = {
            "diagnosis": [r"stercoral\s+colitis"],
            "acute_procedure": [r"endoscopic\s+(?:removal|disimpaction|evacuation|sigmoidoscopy)"],
            "long_term_dx": [r"anorectal\s+manometry", r"puborectalis\s+dysfunction"],
            "long_term_tx": [r"pelvic-floor\s+physical\s+therapy", r"biofeedback"],
            "complications": [r"perforation", r"necrosis", r"ischemia"]
        }

    def validate_output(self, model_output):
        issues = []
        lower_output = model_output.lower()

        if not any(re.search(pattern, lower_output) for pattern in self.expected_patterns["diagnosis"]):
            issues.append("Diagnosis is missing the precise medical term 'Stercoral Colitis'.")
        if not any(re.search(pattern, lower_output) for pattern in self.expected_patterns["acute_procedure"]):
            issues.append("The acute intervention plan lacks specific mention of endoscopic methods for evacuation.")
        if not any(re.search(pattern, lower_output) for pattern in self.expected_patterns["long_term_dx"]):
            issues.append("Long-term management is incomplete; assessment (e.g., anorectal manometry) is missing.")
        if not any(re.search(pattern, lower_output) for pattern in self.expected_patterns["long_term_tx"]):
            issues.append("Long-term therapy is incomplete; must explicitly include 'pelvic-floor physical therapy' or 'biofeedback.'")
        if not any(re.search(pattern, lower_output) for pattern in self.expected_patterns["complications"]):
            issues.append("Potential complications such as necrosis or perforation are not explicitly noted.")

        return issues if issues else ["Output aligns with expected clinical criteria."]


# --- 3. Prompt Engineer Agent (Adaptive Steering and Workflow Management) ---
class PromptEngineerAgent:
    """Pillar 5: Adaptive Steering and Workflow Management"""
    def __init__(self):
        self.base_prompt = (
            "You are a specialist radiologist. Analyze the provided multi-slice CT scan images. "
            "Patient: 23-year-old male with autism and chronic constipation, presenting with acute abdominal pain. "
            "You MUST perform two tasks:\n"
            "1. **Perception/Fact Extraction:** First, explicitly list the raw, verifiable radiological signs (e.g., colonic distention, mural thickening, fat stranding) you observe.\n"
            "2. **Diagnosis & Plan:** Based on these facts and the patient history, provide the **most likely diagnosis** and a detailed management plan. Your plan MUST adhere to the following clinical constraints for a high-risk case:\n"
            "   - Explicitly use the term **Stercoral Colitis** if the findings support it.\n"
            "   - **Acute Management** MUST include **endoscopic removal** (e.g., sigmoidoscopy).\n"
            "   - Explicitly note the risk of **perforation or necrosis**.\n"
            "   - **Long-Term Management** MUST include assessment (e.g., anorectal manometry) and therapy (e.g., pelvic-floor physical therapy or biofeedback).\n"
            "Provide your final output in a clean clinical report format."
        )
        self.iteration = 0

    def refine_prompt(self, validation_feedback):
        self.iteration += 1
        refined_prompt = self.base_prompt

        if validation_feedback and "Output aligns" not in validation_feedback[0]:
            refinement_instruction = (
                f" **CRITICAL REFINEMENT (Iteration {self.iteration}):** The previous response failed to meet specific "
                f"clinical requirements. You MUST now ensure the corrected output adheres to **ALL** the original constraints. "
                f"Specifically, address the following deficiencies: {', '.join(validation_feedback)}. Re-evaluate your previous "
                f"analysis and integrate these missing elements."
            )
            refined_prompt += refinement_instruction

        return refined_prompt


# --- 4. Main Execution Loop (The Orchestrator) ---
def run_multi_agent_experiment_gemini():
    timezone = pytz.timezone('EST')
    start_time = datetime.now(timezone).strftime('%I:%M %p %Z on %B %d, %Y')
    print(f"\n--- Gemini 3 Pro Agent Experiment Started at {start_time} ---")

    # Initialize agents
    prompt_engineer = PromptEngineerAgent()
    image_analyzer = ImageAnalysisAgent(gemini_model)
    validator = ValidationAgent()

    # NOTE: Path as specified in the reference notebook
    image_path = "/content/drive/MyDrive/datasetsmedical/image.png"

    try:
        if not hasattr(gemini_model, 'is_mock'):
            # Attempt to load and upload the image file for live calls
            image_part = load_image_part(image_path)
        else:
            image_part = None
            print("Running in Mock Mode. Image part ignored.")
    except Exception as e:
        print(f"FATAL ERROR: Could not load image file from Drive. {e}")
        # The model is already the MockClient at this point if the API key failed.
        # If the key succeeded but file failed, we continue with an image-less call.
        image_part = None


    # Step 1: Initialize Prompt and Loop
    max_iterations = 5
    current_iteration = 0
    validation_result = []

    refined_prompt = prompt_engineer.refine_prompt(validation_result)

    # --- ENHANCED LOGGING ---
    print("\n--- PROMPT ENGINEER AGENT: Initial Steering Command ---")
    print(f"Goal: Achieve a single-shot clinically accurate diagnosis and plan.")
    print(f"Model: {GEMINI_MODEL_ID}")
    print(f"--- Full Initial Prompt ---")
    print(refined_prompt)
    print("---------------------------------------------------------")
    # --------------------------

    model_output = ""
    while current_iteration < max_iterations:
        print(f"\n--- Iteration {current_iteration + 1} ({GEMINI_MODEL_ID}) ---")

        # Step 2: Call the single Gemini model for analysis and diagnosis
        try:
            model_output = image_analyzer.analyze_image_and_diagnose(refined_prompt, image_part)
        except Exception as e:
            print(f"\n[EXCEPTION CAUGHT] Error during Gemini inference: {e}")
            break

        # Display truncated output for log clarity
        print(f"Gemini Analysis Result: {model_output[:80].replace('\n', ' ') + '...'}")

        # Step 3: Validate Output (Constraint Check)
        validation_result = validator.validate_output(model_output)
        print(f"Validation Agent Feedback: {validation_result}")

        # Step 4: Check for Convergence
        if "Output aligns" in validation_result[0]:
            print("\n**AGENTS CONVERGED: Validation criteria met. Stopping iteration.**")
            break

        # If validation fails, prepare the prompt for the next loop
        refined_prompt = prompt_engineer.refine_prompt(validation_result)
        current_iteration += 1

    if current_iteration == max_iterations and (not model_output or "Output aligns" not in validation_result[0]):
        print("\nMaximum iterations reached without convergence.")

    # Display the final full output
    if model_output:
        print("\n--- Final Clinically Validated Report ---")
        print(model_output)


# Execute the experiment
if __name__ == "__main__":
    run_multi_agent_experiment_gemini()
# Out:
# Gemini client successfully configured for model: gemini-3-pro-preview.
#
# --- Gemini 3 Pro Agent Experiment Started at 02:52 AM EST on November 27, 2025 ---
# File uploaded to Gemini API: files/5tu8eu6lsosh
#
# --- PROMPT ENGINEER AGENT: Initial Steering Command ---
# Goal: Achieve a single-shot clinically accurate diagnosis and plan.
# Model: gemini-3-pro-preview
# --- Full Initial Prompt ---
# You are a specialist radiologist. Analyze the provided multi-slice CT scan images. Patient: 23-year-old male with autism and chronic constipation, presenting with acute abdominal pain. You MUST perform two tasks:
# 1. **Perception/Fact Extraction:** First, explicitly list the raw, verifiable radiological signs (e.g., colonic distention, mural thickening, fat stranding) you observe.
# 2. **Diagnosis & Plan:** Based on these facts and the patient history, provide the **most likely diagnosis** and a detailed management plan. Your plan MUST adhere to the following clinical constraints for a high-risk case:
#    - Explicitly use the term **Stercoral Colitis** if the findings support it.
#    - **Acute Management** MUST include **endoscopic removal** (e.g., sigmoidoscopy).
#    - Explicitly note the risk of **perforation or necrosis**.
#    - **Long-Term Management** MUST include assessment (e.g., anorectal manometry) and therapy (e.g., pelvic-floor physical therapy or biofeedback).
# Provide your final output in a clean clinical report format.
# ---------------------------------------------------------
#
# --- Iteration 1 (gemini-3-pro-preview) ---
# Gemini Analysis Result: **RADIOLOGICAL REPORT**  **Patient:** 23-year-old male **History:** Autism, chro...
# Validation Agent Feedback: ['Output aligns with expected clinical criteria.']
#
# **AGENTS CONVERGED: Validation criteria met. Stopping iteration.**
#
# --- Final Clinically Validated Report ---
# **RADIOLOGICAL REPORT**
#
# **Patient:** 23-year-old male
# **History:** Autism, chronic constipation, acute abdominal pain.
# **Modality:** Multi-slice CT Abdomen/Pelvis (Coronal, Sagittal, Axial views).
#
# ### 1. Perception & Fact Extraction
# Based on the provided multi-planar CT images, the following radiological signs are observed:
#
# *   **Massive Colonic Distention:** There is marked dilation of the rectosigmoid colon (megarectum/megasigmoid).
# *   **Fecal Impaction (Fecaloma):** The dilated bowel lumen is completely occluded by a large volume of heterogeneous, particulate material consistent with impacted feces.
# *   **Mural Thickening:** As indicated by the white arrows in images A and B, and yellow arrows in image C, there is circumferential thickening of the colonic and rectal walls.
# *   **Pericolonic/Perirectal Fat Stranding:** Particularly visible in the axial view (Image C) and surrounding the sigmoid in the coronal view (Image A), there is increased attenuation of the surrounding mesenteric fat. This indicates extraluminal inflammation.
# *   **Mass Effect:** The distended bowel is exerting significant mass effect, displacing surrounding pelvic and abdominal structures.
#
# ---
#
# ### 2. Diagnosis & Management Plan
#
# **Most Likely Diagnosis: Stercoral Colitis**
# The presence of a massive fecaloma causing colonic distention combined with radiological signs of wall inflammation (mural thickening and fat stranding) confirms a diagnosis of **Stercoral Colitis**. This is a life-threatening complication of chronic constipation where increased intraluminal pressure from the fecal mass causes compression of the bowel wall capillary beds, leading to ischemia and inflammation.
#
# **Clinical Alert:**
# There is an imminent and high risk of **bowel necrosis and perforation**. The wall thickening and fat stranding suggest the mucosa is already compromised. If perforation occurs, mortality rates are significantly high due to feculent peritonitis.
#
# **Management Plan:**
#
# **A. Acute Management (Immediate Intervention)**
# 1.  **Aggressive Disimpaction:** Oral laxatives are likely insufficient and potentially dangerous given the degree of obstruction. The primary goal is immediate decompression to reduce intraluminal pressure and restore localized blood flow.
# 2.  **Endoscopic Removal:** Urgent consultation for **flexible sigmoidoscopy** is required. This allows for:
#     *   Mechanical breakdown and removal of the fecaloma.
#     *   Direct visualization of the colonic mucosa to assess for ischemia or ulceration (stercoral ulcers).
#     *   Placement of a rectal tube to aid in ongoing decompression and irrigation.
# 3.  **Surgical Consult:** A surgical team must be on standby. If endoscopy fails, or if there is evidence of full-thickness necrosis or frank perforation (pneumoperitoneum), an emergency Hartmann’s procedure (resection with colostomy) may be required.
# 4.  **Supportive Care:** IV fluids for hydration, correction of electrolyte imbalances, and broad-spectrum antibiotics due to the risk of bacterial translocation across the compromised bowel wall.
#
# **B. Long-Term Management (Prevention of Recurrence)**
# Once the acute phase resolves, the underlying etiology of the patient's severe constipation must be addressed to prevent recurrence:
# 1.  **Functional Assessment:** The patient requires referral for **anorectal manometry** to evaluate for dyssynergic defecation (paradoxical contraction of the pelvic floor during defecation), which is common in patients with neurodevelopmental disorders.
# 2.  **Therapeutic Intervention:** Based on manometry findings, the patient should undergo **pelvic-floor physical therapy and biofeedback training** to retrain the defecation mechanism.
# 3.  **Bowel Regimen:** Establishment of a rigorous maintenance bowel regimen (osmotic laxatives, scheduled toileting) is essential.
