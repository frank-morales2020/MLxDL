# %% [markdown]
# <a href="https://colab.research.google.com/github/frank-morales2020/MLxDL/blob/main/FlightDM_OPENAI_AGENT_DEMO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://github.com/openai/openai-python
#
# https://openai.github.io/openai-agents-python/

# %%
# !pip install openai -q
# !pip install colab_env -q
# !pip install openai-agents -q
import openai
import colab_env

# %% [markdown]
# ## Agents

# %%
import sqlite3
import datetime
from agents import Agent, Runner  # Corrected import - already present

#1. Flight Data
flight_data = [
    ("N12345", "B737", "SYD", "MEL", 1535, 1700, 160, "219", "213"),
    ("N12345", "B737", "MEL", "ADL", 1755, 1900, 150, "264", "245"),
    ("N12345", "B737", "ADL", "SYD", 2120, 2230, 140, "275", "295"),
    ("C67890", "A320", "SYD", "MEL", 1740, 1845, 170, "363", "211"),
    ("A90123", "E190", "MEL", "SYD", 1720, 1830, 95, "263", "245"),
    ("A90123", "E190", "SYD", "00L", 1955, 2100, 85, "224", "280"),
    ("B34567", "B787", "SYD", "MEL", 1530, 1705, 250, "221", "210"),
    ("B34567", "B787", "MEL", "PER", 1850, 2110, 240, "286", "300"),
    ("D89012", "A330", "SYD", "MEL", 1500, 1615, 300, "307", "186"),
    ("D89012", "A330", "MEL", "ADL", 1750, 1900, 280, "298", "255"),
    ("D89012", "A330", "ADL", "MEL", 1955, 2100, 260, "268", "170"),
    ("E23456", "DH8D", "HTI", "BNE", 1520, 1555, 70, "383", "157"),
    ("E23456", "DH8D", "BNE", "SYD", 1725, 1800, 65, "349", "180"),
    ("E23456", "DH8D", "SYD", "DRW", 1935, 40, 60, "402", "188"),
    ("F67890", "A320", "SYD", "MEL", 1735, 1830, 175, "220", "165"),
    ("G90123", "E190", "CBR", "MEL", 1620, 1725, 105, "327", "145"),
    ("G90123", "E190", "MEL", "SYD", 1800, 1925, 100, "328", "166"),
    ("G90123", "E190", "SYD", "CBR", 2000, 2100, 90, "329", "57"),
    ("H34567", "B737", "SYD", "MEL", 1500, 1625, 155, "218", "180"),
    ("H34567", "B737", "MEL", "ADL", 1730, 1905, 145, "225", "136"),
    ("H34567", "B737", "ADL", "PER", 1940, 2035, 135, "266", "141"),
    ("H34567", "B737", "PER", "ADL", 2115, 2315, 125, "282", "175"),
    ("189012", "A330", "PER", "MEL", 1230, 1800, 290, "286", "177"),
    ("189012", "A330", "MEL", "BNE", 1910, 2120, 270, "348", "167"),
    ("J23456", "B737", "00L", "MEL", 1410, 1630, 165, "337", "180"),
    ("J23456", "B737", "MEL", "SYD", 1745, 1910, 155, "309", "160"),
    ("J23456", "B737", "SYD", "MTCE", 2000, 2135, 145, "229", "123")
]

#2. Database Operations
def create_and_populate_db(db_name="flight_data.db", data=flight_data):
    """
    Creates an SQLite database and populates it with flight data.

    Args:
        db_name (str, optional): The name of the database file.
                              Defaults to "flight_data.db".
        data (list, optional): The flight data to insert into the database.
                              Defaults to the flight_data list defined above.
    """
    conn = sqlite3.connect(db_name)
    cursor = conn.cursor()

    # Drop the existing table if it exists to ensure a fresh start
    cursor.execute("DROP TABLE IF EXISTS Flights")

    # Create the table with a unique constraint
    cursor.execute("""
        CREATE TABLE IF NOT EXISTS Flights (
            AC_Tail TEXT,
            AC_Type TEXT,
            Origin TEXT,
            Destination TEXT,
            Departure_Time INTEGER,
            Arrival_Time INTEGER,
            Number_of_Passengers INTEGER,
            CAP TEXT,
            FO TEXT,
            Flight_Type TEXT,
            Status TEXT,  -- Added for disruption management
            UNIQUE(AC_Tail, Origin, Destination)
        )
    """)
    print("Table created successfully")

    # Insert data using a loop and individual execute statements
    for row in data:
        try:
            # Calculate FTI
            departure_time = row[4]
            arrival_time = row[5]
            if arrival_time > departure_time:
                flight_time_interval = arrival_time - departure_time
            else:
                flight_time_interval = (arrival_time + 2400) - departure_time

            flight_type = "Long-haul" if flight_time_interval >= 300 else "Short-haul"

            # Initialize flight status as "Scheduled"
            status = "Scheduled"

            print(f"Inserting data: {row[0]}, {row[1]}, {row[2]}, {row[3]}")
            cursor.execute(f"""
                INSERT INTO Flights (AC_Tail, AC_Type, Origin, Destination,
                Departure_Time, Arrival_Time, Number_of_Passengers, CAP, FO, Flight_Type, Status)
                VALUES ('{row[0]}', '{row[1]}', '{row[2]}', '{row[3]}', {row[4]},
                {row[5]}, {row[6]}, '{row[7]}', '{row[8]}', '{flight_type}', '{status}')
            """)
        except sqlite3.IntegrityError:
            # Ignore duplicate rows
            pass

    conn.commit()
    conn.close()
    print(f"Database '{db_name}' created and data inserted successfully.")

#3. Query Execution
def execute_query(db_name="flight_data.db", query="SELECT * FROM Flights"):
    """
    Executes an SQL query against the database and prints the results.

    Args:
        db_name (str, optional): The name of the database file.
                              Defaults to "flight_data.db".
        query (str, optional): The SQL query to execute.
                             Defaults to a simple SELECT query.
    """
    conn = sqlite3.connect(db_name)
    cursor = conn.cursor()

    print(f"Executing query: {query}")
    cursor.execute(query)
    results = cursor.fetchall()
    print(f"Query results: {results}")  # Print the results

    print("\nQuery Results:")
    for row in results:
        print(row)

    conn.close()

#4. Example Queries (Analytics)
def run_analytics(db_name="flight_data.db"):
    """
    Executes and prints the results of several analytical SQL queries.

    Args:
        db_name (str, optional): The name of the database file.
                              Defaults to "flight_data.db".
    """
    print("\n--- Running Analytics ---")

    queries = {
        "Count of Flights by Aircraft Type":
            """
            SELECT AC_Type, COUNT(*) AS Flight_Count
            FROM Flights
            GROUP BY AC_Type;
            """,
        "Flights Originating from SYD":
            """
            SELECT * FROM Flights
            WHERE Origin = 'SYD';
            """,
        "Avg. Passengers by Aircraft Type":
            """
            SELECT AC_Type, AVG(Number_of_Passengers) AS AveragePassengers
            FROM Flights
            GROUP BY AC_Type;
            """,
        "Earliest Departure Time":
            """
            SELECT * FROM Flights
            ORDER BY Departure_Time ASC
            LIMIT 1;
            """,
        "Latest Departure Time":
            """
            SELECT * FROM Flights
            ORDER BY Departure_Time DESC
            LIMIT 1;
            """,
        "CAP/FO Details":
            """
            SELECT AC_Tail, Origin, Destination, CAP, FO, Flight_Type, Status
            FROM Flights;
            """,
        "Number of Unique Aircraft":
            """
            SELECT DISTINCT AC_Tail, AC_Type AS UniqueAircraftCount
            FROM Flights;
            """
    }

    for analysis, query in queries.items():
        print(f"\n--- {analysis} ---")
        execute_query(db_name, query)

#5. Disruption Simulation
def simulate_disruption(db_name="flight_data.db", disruption_start=1700, disruption_end=1900, affected_airport="MEL"):
    """
    Simulates a weather disruption at a given airport and adjusts flight statuses.

    Args:
        db_name (str, optional): The name of the database file.
                              Defaults to "flight_data.db".
        disruption_start (int, optional): The start time of the disruption (e.g., 1700 for 5 PM).
                                   Defaults to 1700.
        disruption_end (int, optional): The end time of the disruption (e.g., 1900 for 7 PM).
                                 Defaults to 1900.
        affected_airport (str, optional): The airport affected by the disruption.
                                   Defaults to "MEL".
    """
    conn = sqlite3.connect(db_name)
    cursor = conn.cursor()

    print(f"\n--- Simulating Disruption at {affected_airport} from {disruption_start} to {disruption_end} ---")

    # Identify affected flights
    affected_flights_query = f"""
        SELECT AC_Tail, Origin, Destination, Departure_Time, Arrival_Time
        FROM Flights
        WHERE (Origin = '{affected_airport}' AND Departure_Time >= {disruption_start} AND Departure_Time <= {disruption_end})
        OR (Destination = '{affected_airport}' AND Arrival_Time >= {disruption_start} AND Arrival_Time <= {disruption_end})
    """
    cursor.execute(affected_flights_query)
    affected_flights = cursor.fetchall()

    print("\nAffected Flights:")
    for flight in affected_flights:
        print(flight)

    # Update flight statuses
    for flight in affected_flights:
        ac_tail = flight[0]
        origin = flight[1]
        destination = flight[2]

        # For simplicity, let's just mark these flights as "Delayed"
        update_status_query = f"""
            UPDATE Flights
            SET Status = 'Delayed'
            WHERE AC_Tail = '{ac_tail}' AND Origin = '{origin}' AND Destination = '{destination}'
        """
        cursor.execute(update_status_query)
        print(f"    Updated status for flight {ac_tail} from {origin} to {destination} to Delayed")

    conn.commit()  # Ensure changes are committed
    conn.close()

    # Re-establish connection for the final query (important!)
    conn = sqlite3.connect(db_name)
    cursor = conn.cursor()

    print("\nDisruption simulation completed.")


# --- 6. FleetAgent Implementation ---
class FleetAgent(Agent):
    def __init__(self, name="FleetAgent", instructions="Manage and recover flight disruptions", db_name="flight_data.db"):
        super().__init__(name=name, instructions=instructions)  # Initialize the Agent superclass
        self.db_name = db_name
        self.conn = sqlite3.connect(self.db_name)
        self.cursor = self.conn.cursor()

    def analyze_state(self):
        """Retrieves current flight information from the database."""
        query = "SELECT AC_Tail, Origin, Destination, Departure_Time, Arrival_Time, Status FROM Flights"
        self.cursor.execute(query)
        flight_info = self.cursor.fetchall()
        return flight_info

    def assess_impact(self, flight_info):
        """Analyzes flight data to identify delays or other issues and estimates the cost."""
        impact = {"delayed_count": 0, "disruption_cost": 0}  # Add disruption_cost
        for flight in flight_info:
            if flight[5] == "Delayed":
                impact["delayed_count"] += 1
                impact["disruption_cost"] += self.estimate_delay_cost(flight)  # Calculate cost
        return impact

    def estimate_delay_cost(self, flight):
        """Estimates the cost of a flight delay (placeholder for a more complex model)."""
        # **[REPLACE WITH YOUR COST ESTIMATION LOGIC]**
        # This is a very basic example - you would need a more realistic cost model
        # based on factors like delay duration, aircraft type, passenger count, etc.
        delay_cost = 1000  # Assume a fixed cost of $1000 per delayed flight
        return delay_cost

    def strategize_recovery(self, impact):
        """Develops and executes a recovery strategy."""
        if impact["delayed_count"] > 0:
            print("\n  Strategy: Reschedule Delayed Flights")
            self.retime_flights()  # Call the rescheduling function
        else:
            print("\n  Strategy: No immediate action needed.")

    def retime_flights(self):
        """Reschedules delayed flights (basic implementation)."""
        # Get delayed flights
        self.cursor.execute("SELECT AC_Tail, Origin, Destination, Departure_Time FROM Flights WHERE Status = 'Delayed'")
        delayed_flights = self.cursor.fetchall()

        for flight in delayed_flights:
            ac_tail, origin, destination, departure_time = flight

            # **[REPLACE WITH YOUR RESCHEDULING LOGIC]**
            # This is a simplified example, adding 1 hour (100 in this time format)
            # to the departure time.
            new_departure_time = departure_time + 100

            # Update the database with the new departure time and status
            update_query = f"UPDATE Flights SET Status = 'Rescheduled', Departure_Time = {new_departure_time} " \
                           f"WHERE AC_Tail = '{ac_tail}' AND Origin = '{origin}' AND Destination = '{destination}'"
            self.cursor.execute(update_query)

        self.conn.commit()
        print("  Delayed flights rescheduled (Departure Time + 100).")



import nest_asyncio
nest_asyncio.apply()

# 6. Main Execution
if __name__ == "__main__":
    create_and_populate_db()  # Create the database and insert data
    run_analytics()           # Execute and display analytics queries

    # Simulate the disruption
    simulate_disruption()  # Defaults to MEL, 1700-1900, but you can change these

    # Show the updated flight information
    print("\n--- Flight Data After Disruption ---")
    execute_query(query="SELECT AC_Tail, Origin, Destination, Departure_Time, Arrival_Time, Status FROM Flights")

    # --- Using the FleetAgent with Runner (run_sync) ---
    print("\n--- FleetAgent in Action (with Runner) ---")

    # Instantiate the FleetAgent
    fleet_agent = FleetAgent()

    # Using run_sync for agent interaction
    result = Runner.run_sync(fleet_agent, "Analyze the current flight state and strategize recovery.")

    # print the final output if available (e.g., result.final_output)
    print(result.final_output) if result.final_output else None



    print('\n\n')




     # 1. Analyze the current state
    flight_info = fleet_agent.analyze_state()
    print("\nFlight Information (from Agent):")
    for flight in flight_info:
        print(flight)

    # 2. Assess the impact of disruptions
    impact = fleet_agent.assess_impact(flight_info)
    print("\nDisruption Impact (from Agent):")
    print(impact)

    # Print the total disruption cost
    total_cost = impact["disruption_cost"]
    print(f"\nTotal Disruption Cost: {total_cost}")


    # 3. Strategize and execute recovery (basic example)
    fleet_agent.strategize_recovery(impact) # This will call retime_flights() internally

    # 4. Show updated flight data after agent actions
    print("\n--- Flight Data After Agent Recovery ---")
    execute_query(query="SELECT AC_Tail, Origin, Destination, Departure_Time, Arrival_Time, Status FROM Flights")
# Out:
# Table created successfully
# Inserting data: N12345, B737, SYD, MEL
# Inserting data: N12345, B737, MEL, ADL
# Inserting data: N12345, B737, ADL, SYD
# Inserting data: C67890, A320, SYD, MEL
# Inserting data: A90123, E190, MEL, SYD
# Inserting data: A90123, E190, SYD, 00L
# Inserting data: B34567, B787, SYD, MEL
# Inserting data: B34567, B787, MEL, PER
# Inserting data: D89012, A330, SYD, MEL
# Inserting data: D89012, A330, MEL, ADL
# Inserting data: D89012, A330, ADL, MEL
# Inserting data: E23456, DH8D, HTI, BNE
# Inserting data: E23456, DH8D, BNE, SYD
# Inserting data: E23456, DH8D, SYD, DRW
# Inserting data: F67890, A320, SYD, MEL
# Inserting data: G90123, E190, CBR, MEL
# Inserting data: G90123, E190, MEL, SYD
# Inserting data: G90123, E190, SYD, CBR
# Inserting data: H34567, B737, SYD, MEL
# Inserting data: H34567, B737, MEL, ADL
# Inserting data: H34567, B737, ADL, PER
# Inserting data: H34567, B737, PER, ADL
# Inserting data: 189012, A330, PER, MEL
# Inserting data: 189012, A330, MEL, BNE
# Inserting data: J23456, B737, 00L, MEL
# Inserting data: J23456, B737, MEL, SYD
# Inserting data: J23456, B737, SYD, MTCE
# Database 'flight_data.db' created and data inserted successfully.
#
# --- Running Analytics ---
#
# --- Count of Flights by Aircraft Type ---
# Executing query:
#             SELECT AC_Type, COUNT(*) AS Flight_Count
#             FROM Flights
#             GROUP BY AC_Type;
#
# Query results: [('A320', 2), ('A330', 5), ('B737', 10), ('B787', 2), ('DH8D', 3), ('E190', 5)]
#
# Query Results:
# ('A320', 2)
# ('A330', 5)
# ('B737', 10)
# ('B787', 2)
# ('DH8D', 3)
# ('E190', 5)
#
# --- Flights Originating from SYD ---
# Executing query:
#             SELECT * FROM Flights
#             WHERE Origin = 'SYD';
#
# Query results: [('N12345', 'B737', 'SYD', 'MEL', 1535, 1700, 160, '219', '213', 'Short-haul', 'Scheduled'), ('C67890', 'A320', 'SYD', 'MEL', 1740, 1845, 170, '363', '211', 'Short-haul', 'Scheduled'), ('A90123', 'E190', 'SYD', '00L', 1955, 2100, 85, '224', '280', 'Short-haul', 'Scheduled'), ('B34567', 'B787', 'SYD', 'MEL', 1530, 1705, 250, '221', '210', 'Short-haul', 'Scheduled'), ('D89012', 'A330', 'SYD', 'MEL', 1500, 1615, 300, '307', '186', 'Short-haul', 'Scheduled'), ('E23456', 'DH8D', 'SYD', 'DRW', 1935, 40, 60, '402', '188', 'Long-haul', 'Scheduled'), ('F67890', 'A320', 'SYD', 'MEL', 1735, 1830, 175, '220', '165', 'Short-haul', 'Scheduled'), ('G90123', 'E190', 'SYD', 'CBR', 2000, 2100, 90, '329', '57', 'Short-haul', 'Scheduled'), ('H34567', 'B737', 'SYD', 'MEL', 1500, 1625, 155, '218', '180', 'Short-haul', 'Scheduled'), ('J23456', 'B737', 'SYD', 'MTCE', 2000, 2135, 145, '229', '123', 'Short-haul', 'Scheduled')]
#
# Query Results:
# ('N12345', 'B737', 'SYD', 'MEL', 1535, 1700, 160, '219', '213', 'Short-haul', 'Scheduled')
# ('C67890', 'A320', 'SYD', 'MEL', 1740, 1845, 170, '363', '211', 'Short-haul', 'Scheduled')
# ('A90123', 'E190', 'SYD', '00L', 1955, 2100, 85, '224', '280', 'Short-haul', 'Scheduled')
# ('B34567', 'B787', 'SYD', 'MEL', 1530, 1705, 250, '221', '210', 'Short-haul', 'Scheduled')
# ('D89012', 'A330', 'SYD', 'MEL', 1500, 1615, 300, '307', '186', 'Short-haul', 'Scheduled')
# ('E23456', 'DH8D', 'SYD', 'DRW', 1935, 40, 60, '402', '188', 'Long-haul', 'Scheduled')
# ('F67890', 'A320', 'SYD', 'MEL', 1735, 1830, 175, '220', '165', 'Short-haul', 'Scheduled')
# ('G90123', 'E190', 'SYD', 'CBR', 2000, 2100, 90, '329', '57', 'Short-haul', 'Scheduled')
# ('H34567', 'B737', 'SYD', 'MEL', 1500, 1625, 155, '218', '180', 'Short-haul', 'Scheduled')
# ('J23456', 'B737', 'SYD', 'MTCE', 2000, 2135, 145, '229', '123', 'Short-haul', 'Scheduled')
#
# --- Avg. Passengers by Aircraft Type ---
# Executing query:
#             SELECT AC_Type, AVG(Number_of_Passengers) AS AveragePassengers
#             FROM Flights
#             GROUP BY AC_Type;
#
# Query results: [('A320', 172.5), ('A330', 280.0), ('B737', 147.5), ('B787', 245.0), ('DH8D', 65.0), ('E190', 95.0)]
#
# Query Results:
# ('A320', 172.5)
# ('A330', 280.0)
# ('B737', 147.5)
# ('B787', 245.0)
# ('DH8D', 65.0)
# ('E190', 95.0)
#
# --- Earliest Departure Time ---
# Executing query:
#             SELECT * FROM Flights
#             ORDER BY Departure_Time ASC
#             LIMIT 1;
#
# Query results: [('189012', 'A330', 'PER', 'MEL', 1230, 1800, 290, '286', '177', 'Long-haul', 'Scheduled')]
#
# Query Results:
# ('189012', 'A330', 'PER', 'MEL', 1230, 1800, 290, '286', '177', 'Long-haul', 'Scheduled')
#
# --- Latest Departure Time ---
# Executing query:
#             SELECT * FROM Flights
#             ORDER BY Departure_Time DESC
#             LIMIT 1;
#
# Query results: [('N12345', 'B737', 'ADL', 'SYD', 2120, 2230, 140, '275', '295', 'Short-haul', 'Scheduled')]
#
# Query Results:
# ('N12345', 'B737', 'ADL', 'SYD', 2120, 2230, 140, '275', '295', 'Short-haul', 'Scheduled')
#
# --- CAP/FO Details ---
# Executing query:
#             SELECT AC_Tail, Origin, Destination, CAP, FO, Flight_Type, Status
#             FROM Flights;
#
# Query results: [('N12345', 'SYD', 'MEL', '219', '213', 'Short-haul', 'Scheduled'), ('N12345', 'MEL', 'ADL', '264', '245', 'Short-haul', 'Scheduled'), ('N12345', 'ADL', 'SYD', '275', '295', 'Short-haul', 'Scheduled'), ('C67890', 'SYD', 'MEL', '363', '211', 'Short-haul', 'Scheduled'), ('A90123', 'MEL', 'SYD', '263', '245', 'Short-haul', 'Scheduled'), ('A90123', 'SYD', '00L', '224', '280', 'Short-haul', 'Scheduled'), ('B34567', 'SYD', 'MEL', '221', '210', 'Short-haul', 'Scheduled'), ('B34567', 'MEL', 'PER', '286', '300', 'Short-haul', 'Scheduled'), ('D89012', 'SYD', 'MEL', '307', '186', 'Short-haul', 'Scheduled'), ('D89012', 'MEL', 'ADL', '298', '255', 'Short-haul', 'Scheduled'), ('D89012', 'ADL', 'MEL', '268', '170', 'Short-haul', 'Scheduled'), ('E23456', 'HTI', 'BNE', '383', '157', 'Short-haul', 'Scheduled'), ('E23456', 'BNE', 'SYD', '349', '180', 'Short-haul', 'Scheduled'), ('E23456', 'SYD', 'DRW', '402', '188', 'Long-haul', 'Scheduled'), ('F67890', 'SYD', 'MEL', '220', '165', 'Short-haul', 'Scheduled'), ('G90123', 'CBR', 'MEL', '327', '145', 'Short-haul', 'Scheduled'), ('G90123', 'MEL', 'SYD', '328', '166', 'Short-haul', 'Scheduled'), ('G90123', 'SYD', 'CBR', '329', '57', 'Short-haul', 'Scheduled'), ('H34567', 'SYD', 'MEL', '218', '180', 'Short-haul', 'Scheduled'), ('H34567', 'MEL', 'ADL', '225', '136', 'Short-haul', 'Scheduled'), ('H34567', 'ADL', 'PER', '266', '141', 'Short-haul', 'Scheduled'), ('H34567', 'PER', 'ADL', '282', '175', 'Short-haul', 'Scheduled'), ('189012', 'PER', 'MEL', '286', '177', 'Long-haul', 'Scheduled'), ('189012', 'MEL', 'BNE', '348', '167', 'Short-haul', 'Scheduled'), ('J23456', '00L', 'MEL', '337', '180', 'Short-haul', 'Scheduled'), ('J23456', 'MEL', 'SYD', '309', '160', 'Short-haul', 'Scheduled'), ('J23456', 'SYD', 'MTCE', '229', '123', 'Short-haul', 'Scheduled')]
#
# Query Results:
# ('N12345', 'SYD', 'MEL', '219', '213', 'Short-haul', 'Scheduled')
# ('N12345', 'MEL', 'ADL', '264', '245', 'Short-haul', 'Scheduled')
# ('N12345', 'ADL', 'SYD', '275', '295', 'Short-haul', 'Scheduled')
# ('C67890', 'SYD', 'MEL', '363', '211', 'Short-haul', 'Scheduled')
# ('A90123', 'MEL', 'SYD', '263', '245', 'Short-haul', 'Scheduled')
# ('A90123', 'SYD', '00L', '224', '280', 'Short-haul', 'Scheduled')
# ('B34567', 'SYD', 'MEL', '221', '210', 'Short-haul', 'Scheduled')
# ('B34567', 'MEL', 'PER', '286', '300', 'Short-haul', 'Scheduled')
# ('D89012', 'SYD', 'MEL', '307', '186', 'Short-haul', 'Scheduled')
# ('D89012', 'MEL', 'ADL', '298', '255', 'Short-haul', 'Scheduled')
# ('D89012', 'ADL', 'MEL', '268', '170', 'Short-haul', 'Scheduled')
# ('E23456', 'HTI', 'BNE', '383', '157', 'Short-haul', 'Scheduled')
# ('E23456', 'BNE', 'SYD', '349', '180', 'Short-haul', 'Scheduled')
# ('E23456', 'SYD', 'DRW', '402', '188', 'Long-haul', 'Scheduled')
# ('F67890', 'SYD', 'MEL', '220', '165', 'Short-haul', 'Scheduled')
# ('G90123', 'CBR', 'MEL', '327', '145', 'Short-haul', 'Scheduled')
# ('G90123', 'MEL', 'SYD', '328', '166', 'Short-haul', 'Scheduled')
# ('G90123', 'SYD', 'CBR', '329', '57', 'Short-haul', 'Scheduled')
# ('H34567', 'SYD', 'MEL', '218', '180', 'Short-haul', 'Scheduled')
# ('H34567', 'MEL', 'ADL', '225', '136', 'Short-haul', 'Scheduled')
# ('H34567', 'ADL', 'PER', '266', '141', 'Short-haul', 'Scheduled')
# ('H34567', 'PER', 'ADL', '282', '175', 'Short-haul', 'Scheduled')
# ('189012', 'PER', 'MEL', '286', '177', 'Long-haul', 'Scheduled')
# ('189012', 'MEL', 'BNE', '348', '167', 'Short-haul', 'Scheduled')
# ('J23456', '00L', 'MEL', '337', '180', 'Short-haul', 'Scheduled')
# ('J23456', 'MEL', 'SYD', '309', '160', 'Short-haul', 'Scheduled')
# ('J23456', 'SYD', 'MTCE', '229', '123', 'Short-haul', 'Scheduled')
#
# --- Number of Unique Aircraft ---
# Executing query:
#             SELECT DISTINCT AC_Tail, AC_Type AS UniqueAircraftCount
#             FROM Flights;
#
# Query results: [('189012', 'A330'), ('A90123', 'E190'), ('B34567', 'B787'), ('C67890', 'A320'), ('D89012', 'A330'), ('E23456', 'DH8D'), ('F67890', 'A320'), ('G90123', 'E190'), ('H34567', 'B737'), ('J23456', 'B737'), ('N12345', 'B737')]
#
# Query Results:
# ('189012', 'A330')
# ('A90123', 'E190')
# ('B34567', 'B787')
# ('C67890', 'A320')
# ('D89012', 'A330')
# ('E23456', 'DH8D')
# ('F67890', 'A320')
# ('G90123', 'E190')
# ('H34567', 'B737')
# ('J23456', 'B737')
# ('N12345', 'B737')
#
# --- Simulating Disruption at MEL from 1700 to 1900 ---
#
# Affected Flights:
# ('N12345', 'SYD', 'MEL', 1535, 1700)
# ('N12345', 'MEL', 'ADL', 1755, 1900)
# ('C67890', 'SYD', 'MEL', 1740, 1845)
# ('A90123', 'MEL', 'SYD', 1720, 1830)
# ('B34567', 'SYD', 'MEL', 1530, 1705)
# ('B34567', 'MEL', 'PER', 1850, 2110)
# ('D89012', 'MEL', 'ADL', 1750, 1900)
# ('F67890', 'SYD', 'MEL', 1735, 1830)
# ('G90123', 'CBR', 'MEL', 1620, 1725)
# ('G90123', 'MEL', 'SYD', 1800, 1925)
# ('H34567', 'MEL', 'ADL', 1730, 1905)
# ('189012', 'PER', 'MEL', 1230, 1800)
# ('J23456', 'MEL', 'SYD', 1745, 1910)
#     Updated status for flight N12345 from SYD to MEL to Delayed
#     Updated status for flight N12345 from MEL to ADL to Delayed
#     Updated status for flight C67890 from SYD to MEL to Delayed
#     Updated status for flight A90123 from MEL to SYD to Delayed
#     Updated status for flight B34567 from SYD to MEL to Delayed
#     Updated status for flight B34567 from MEL to PER to Delayed
#     Updated status for flight D89012 from MEL to ADL to Delayed
#     Updated status for flight F67890 from SYD to MEL to Delayed
#     Updated status for flight G90123 from CBR to MEL to Delayed
#     Updated status for flight G90123 from MEL to SYD to Delayed
#     Updated status for flight H34567 from MEL to ADL to Delayed
#     Updated status for flight 189012 from PER to MEL to Delayed
#     Updated status for flight J23456 from MEL to SYD to Delayed
#
# Disruption simulation completed.
#
# --- Flight Data After Disruption ---
# Executing query: SELECT AC_Tail, Origin, Destination, Departure_Time, Arrival_Time, Status FROM Flights
# Query results: [('N12345', 'SYD', 'MEL', 1535, 1700, 'Delayed'), ('N12345', 'MEL', 'ADL', 1755, 1900, 'Delayed'), ('N12345', 'ADL', 'SYD', 2120, 2230, 'Scheduled'), ('C67890', 'SYD', 'MEL', 1740, 1845, 'Delayed'), ('A90123', 'MEL', 'SYD', 1720, 1830, 'Delayed'), ('A90123', 'SYD', '00L', 1955, 2100, 'Scheduled'), ('B34567', 'SYD', 'MEL', 1530, 1705, 'Delayed'), ('B34567', 'MEL', 'PER', 1850, 2110, 'Delayed'), ('D89012', 'SYD', 'MEL', 1500, 1615, 'Scheduled'), ('D89012', 'MEL', 'ADL', 1750, 1900, 'Delayed'), ('D89012', 'ADL', 'MEL', 1955, 2100, 'Scheduled'), ('E23456', 'HTI', 'BNE', 1520, 1555, 'Scheduled'), ('E23456', 'BNE', 'SYD', 1725, 1800, 'Scheduled'), ('E23456', 'SYD', 'DRW', 1935, 40, 'Scheduled'), ('F67890', 'SYD', 'MEL', 1735, 1830, 'Delayed'), ('G90123', 'CBR', 'MEL', 1620, 1725, 'Delayed'), ('G90123', 'MEL', 'SYD', 1800, 1925, 'Delayed'), ('G90123', 'SYD', 'CBR', 2000, 2100, 'Scheduled'), ('H34567', 'SYD', 'MEL', 1500, 1625, 'Scheduled'), ('H34567', 'MEL', 'ADL', 1730, 1905, 'Delayed'), ('H34567', 'ADL', 'PER', 1940, 2035, 'Scheduled'), ('H34567', 'PER', 'ADL', 2115, 2315, 'Scheduled'), ('189012', 'PER', 'MEL', 1230, 1800, 'Delayed'), ('189012', 'MEL', 'BNE', 1910, 2120, 'Scheduled'), ('J23456', '00L', 'MEL', 1410, 1630, 'Scheduled'), ('J23456', 'MEL', 'SYD', 1745, 1910, 'Delayed'), ('J23456', 'SYD', 'MTCE', 2000, 2135, 'Scheduled')]
#
# Query Results:
# ('N12345', 'SYD', 'MEL', 1535, 1700, 'Delayed')
# ('N12345', 'MEL', 'ADL', 1755, 1900, 'Delayed')
# ('N12345', 'ADL', 'SYD', 2120, 2230, 'Scheduled')
# ('C67890', 'SYD', 'MEL', 1740, 1845, 'Delayed')
# ('A90123', 'MEL', 'SYD', 1720, 1830, 'Delayed')
# ('A90123', 'SYD', '00L', 1955, 2100, 'Scheduled')
# ('B34567', 'SYD', 'MEL', 1530, 1705, 'Delayed')
# ('B34567', 'MEL', 'PER', 1850, 2110, 'Delayed')
# ('D89012', 'SYD', 'MEL', 1500, 1615, 'Scheduled')
# ('D89012', 'MEL', 'ADL', 1750, 1900, 'Delayed')
# ('D89012', 'ADL', 'MEL', 1955, 2100, 'Scheduled')
# ('E23456', 'HTI', 'BNE', 1520, 1555, 'Scheduled')
# ('E23456', 'BNE', 'SYD', 1725, 1800, 'Scheduled')
# ('E23456', 'SYD', 'DRW', 1935, 40, 'Scheduled')
# ('F67890', 'SYD', 'MEL', 1735, 1830, 'Delayed')
# ('G90123', 'CBR', 'MEL', 1620, 1725, 'Delayed')
# ('G90123', 'MEL', 'SYD', 1800, 1925, 'Delayed')
# ('G90123', 'SYD', 'CBR', 2000, 2100, 'Scheduled')
# ('H34567', 'SYD', 'MEL', 1500, 1625, 'Scheduled')
# ('H34567', 'MEL', 'ADL', 1730, 1905, 'Delayed')
# ('H34567', 'ADL', 'PER', 1940, 2035, 'Scheduled')
# ('H34567', 'PER', 'ADL', 2115, 2315, 'Scheduled')
# ('189012', 'PER', 'MEL', 1230, 1800, 'Delayed')
# ('189012', 'MEL', 'BNE', 1910, 2120, 'Scheduled')
# ('J23456', '00L', 'MEL', 1410, 1630, 'Scheduled')
# ('J23456', 'MEL', 'SYD', 1745, 1910, 'Delayed')
# ('J23456', 'SYD', 'MTCE', 2000, 2135, 'Scheduled')
#
# --- FleetAgent in Action (with Runner) ---
# To effectively analyze the current flight state and strategize recovery, follow these steps:
#
# ### 1. Situation Assessment
# - **Collect Real-Time Data**: Gather information on all affected flights, including delayed, canceled, or rerouted flights.
# - **Identify Causes**: Determine the reasons for disruptions (weather, technical issues, staffing shortages, etc.).
# - **Priority Flights**: Identify high-priority flights (e.g., international flights, flights with many connections).
#
# ### 2. Communication
# - **Notify Passengers**: Use multiple channels to inform passengers about delays or changes, offering digital updates, emails, and SMS.
# - **Customer Support**: Increase staffing for customer support teams to manage increased inquiries and complaints.
# - **Staff Briefings**: Update staff regularly on the situation and recovery strategies.
#
# ### 3. Resource Allocation
# - **Crew Management**: Reassign crew members as needed, ensuring compliance with legal rest requirements.
# - **Aircraft Re-positioning**: Prioritize aircraft availability and consider alternate aircraft if needed.
# - **Logistics Coordination**: Ensure ground services, fueling, and catering are prepared for rescheduled flights.
#
# ### 4. Recovery Strategy
# - **Rebooking**: Use automated systems to rebook passengers on alternative flights. Collaborate with partner airlines if necessary.
# - **Hub Management**: Manage connecting flights at hubs to minimize passenger inconvenience.
# - **Compensation Plans**: Implement compensation strategies for affected passengers as per company policy.
#
# ### 5. Monitoring and Adjustment
# - **Monitor Weather Patterns**: Continuously monitor changes and adjust strategies accordingly.
# - **Feedback Channels**: Encourage feedback from passengers to identify pain points and improve future strategies.
# - **Post-Event Analysis**: Analyze the disruption to identify areas for improvement in disaster recovery plans.
#
# ### 6. Long-term Improvements
# - **Invest in Technology**: Use predictive analytics and AI for better disruption management forecasting.
# - **Training Programs**: Regularly train staff on emergency protocols and customer service excellence during disruptions.
# - **Policy Updates**: Review and update company policies regarding disruptions and compensations.
#
# By following these steps, you can efficiently manage and recover from flight disruptions, minimizing inconvenience to passengers and maintaining operational effectiveness.
#
#
#
#
# Flight Information (from Agent):
# ('N12345', 'SYD', 'MEL', 1535, 1700, 'Delayed')
# ('N12345', 'MEL', 'ADL', 1755, 1900, 'Delayed')
# ('N12345', 'ADL', 'SYD', 2120, 2230, 'Scheduled')
# ('C67890', 'SYD', 'MEL', 1740, 1845, 'Delayed')
# ('A90123', 'MEL', 'SYD', 1720, 1830, 'Delayed')
# ('A90123', 'SYD', '00L', 1955, 2100, 'Scheduled')
# ('B34567', 'SYD', 'MEL', 1530, 1705, 'Delayed')
# ('B34567', 'MEL', 'PER', 1850, 2110, 'Delayed')
# ('D89012', 'SYD', 'MEL', 1500, 1615, 'Scheduled')
# ('D89012', 'MEL', 'ADL', 1750, 1900, 'Delayed')
# ('D89012', 'ADL', 'MEL', 1955, 2100, 'Scheduled')
# ('E23456', 'HTI', 'BNE', 1520, 1555, 'Scheduled')
# ('E23456', 'BNE', 'SYD', 1725, 1800, 'Scheduled')
# ('E23456', 'SYD', 'DRW', 1935, 40, 'Scheduled')
# ('F67890', 'SYD', 'MEL', 1735, 1830, 'Delayed')
# ('G90123', 'CBR', 'MEL', 1620, 1725, 'Delayed')
# ('G90123', 'MEL', 'SYD', 1800, 1925, 'Delayed')
# ('G90123', 'SYD', 'CBR', 2000, 2100, 'Scheduled')
# ('H34567', 'SYD', 'MEL', 1500, 1625, 'Scheduled')
# ('H34567', 'MEL', 'ADL', 1730, 1905, 'Delayed')
# ('H34567', 'ADL', 'PER', 1940, 2035, 'Scheduled')
# ('H34567', 'PER', 'ADL', 2115, 2315, 'Scheduled')
# ('189012', 'PER', 'MEL', 1230, 1800, 'Delayed')
# ('189012', 'MEL', 'BNE', 1910, 2120, 'Scheduled')
# ('J23456', '00L', 'MEL', 1410, 1630, 'Scheduled')
# ('J23456', 'MEL', 'SYD', 1745, 1910, 'Delayed')
# ('J23456', 'SYD', 'MTCE', 2000, 2135, 'Scheduled')
#
# Disruption Impact (from Agent):
# {'delayed_count': 13, 'disruption_cost': 13000}
#
# Total Disruption Cost: 13000
#
#   Strategy: Reschedule Delayed Flights
#   Delayed flights rescheduled (Departure Time + 100).
#
# --- Flight Data After Agent Recovery ---
# Executing query: SELECT AC_Tail, Origin, Destination, Departure_Time, Arrival_Time, Status FROM Flights
# Query results: [('N12345', 'SYD', 'MEL', 1635, 1700, 'Rescheduled'), ('N12345', 'MEL', 'ADL', 1855, 1900, 'Rescheduled'), ('N12345', 'ADL', 'SYD', 2120, 2230, 'Scheduled'), ('C67890', 'SYD', 'MEL', 1840, 1845, 'Rescheduled'), ('A90123', 'MEL', 'SYD', 1820, 1830, 'Rescheduled'), ('A90123', 'SYD', '00L', 1955, 2100, 'Scheduled'), ('B34567', 'SYD', 'MEL', 1630, 1705, 'Rescheduled'), ('B34567', 'MEL', 'PER', 1950, 2110, 'Rescheduled'), ('D89012', 'SYD', 'MEL', 1500, 1615, 'Scheduled'), ('D89012', 'MEL', 'ADL', 1850, 1900, 'Rescheduled'), ('D89012', 'ADL', 'MEL', 1955, 2100, 'Scheduled'), ('E23456', 'HTI', 'BNE', 1520, 1555, 'Scheduled'), ('E23456', 'BNE', 'SYD', 1725, 1800, 'Scheduled'), ('E23456', 'SYD', 'DRW', 1935, 40, 'Scheduled'), ('F67890', 'SYD', 'MEL', 1835, 1830, 'Rescheduled'), ('G90123', 'CBR', 'MEL', 1720, 1725, 'Rescheduled'), ('G90123', 'MEL', 'SYD', 1900, 1925, 'Rescheduled'), ('G90123', 'SYD', 'CBR', 2000, 2100, 'Scheduled'), ('H34567', 'SYD', 'MEL', 1500, 1625, 'Scheduled'), ('H34567', 'MEL', 'ADL', 1830, 1905, 'Rescheduled'), ('H34567', 'ADL', 'PER', 1940, 2035, 'Scheduled'), ('H34567', 'PER', 'ADL', 2115, 2315, 'Scheduled'), ('189012', 'PER', 'MEL', 1330, 1800, 'Rescheduled'), ('189012', 'MEL', 'BNE', 1910, 2120, 'Scheduled'), ('J23456', '00L', 'MEL', 1410, 1630, 'Scheduled'), ('J23456', 'MEL', 'SYD', 1845, 1910, 'Rescheduled'), ('J23456', 'SYD', 'MTCE', 2000, 2135, 'Scheduled')]
#
# Query Results:
# ('N12345', 'SYD', 'MEL', 1635, 1700, 'Rescheduled')
# ('N12345', 'MEL', 'ADL', 1855, 1900, 'Rescheduled')
# ('N12345', 'ADL', 'SYD', 2120, 2230, 'Scheduled')
# ('C67890', 'SYD', 'MEL', 1840, 1845, 'Rescheduled')
# ('A90123', 'MEL', 'SYD', 1820, 1830, 'Rescheduled')
# ('A90123', 'SYD', '00L', 1955, 2100, 'Scheduled')
# ('B34567', 'SYD', 'MEL', 1630, 1705, 'Rescheduled')
# ('B34567', 'MEL', 'PER', 1950, 2110, 'Rescheduled')
# ('D89012', 'SYD', 'MEL', 1500, 1615, 'Scheduled')
# ('D89012', 'MEL', 'ADL', 1850, 1900, 'Rescheduled')
# ('D89012', 'ADL', 'MEL', 1955, 2100, 'Scheduled')
# ('E23456', 'HTI', 'BNE', 1520, 1555, 'Scheduled')
# ('E23456', 'BNE', 'SYD', 1725, 1800, 'Scheduled')
# ('E23456', 'SYD', 'DRW', 1935, 40, 'Scheduled')
# ('F67890', 'SYD', 'MEL', 1835, 1830, 'Rescheduled')
# ('G90123', 'CBR', 'MEL', 1720, 1725, 'Rescheduled')
# ('G90123', 'MEL', 'SYD', 1900, 1925, 'Rescheduled')
# ('G90123', 'SYD', 'CBR', 2000, 2100, 'Scheduled')
# ('H34567', 'SYD', 'MEL', 1500, 1625, 'Scheduled')
# ('H34567', 'MEL', 'ADL', 1830, 1905, 'Rescheduled')
# ('H34567', 'ADL', 'PER', 1940, 2035, 'Scheduled')
# ('H34567', 'PER', 'ADL', 2115, 2315, 'Scheduled')
# ('189012', 'PER', 'MEL', 1330, 1800, 'Rescheduled')
# ('189012', 'MEL', 'BNE', 1910, 2120, 'Scheduled')
# ('J23456', '00L', 'MEL', 1410, 1630, 'Scheduled')
# ('J23456', 'MEL', 'SYD', 1845, 1910, 'Rescheduled')
# ('J23456', 'SYD', 'MTCE', 2000, 2135, 'Scheduled')
