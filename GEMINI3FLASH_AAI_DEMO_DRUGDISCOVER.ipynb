# %% [markdown]
# <a href="https://colab.research.google.com/github/frank-morales2020/MLxDL/blob/main/GEMINI3FLASH_AAI_DEMO_DRUGDISCOVER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U google-genai
from google import genai
from google.genai import types
from google.colab import userdata

# --- 1. CORE SETUP & GEMINI 3 CONFIGURATION ---
MODEL_NAME = "gemini-3-flash-preview"
client = genai.Client(api_key=userdata.get('GEMINI'))

def get_thinking_config(level):
    """
    Returns a Gemini 3 config.
    Levels: 'minimal', 'low', 'medium', 'high'
    """
    return types.GenerateContentConfig(
        thinking_config=types.ThinkingConfig(
            include_thoughts=True,
            thinking_level=level
        ),
        temperature=1.0  # Required for consistent reasoning in Gemini 3
    )

# --- 2. DRUG DISCOVERY AGENT (HIGH THINKING) ---
class DrugDiscoveryAgent:
    def __init__(self):
        self.config = get_thinking_config("high")

    def run_discovery_task(self, task):
        print(f"\n[DRUG DISCOVERY] Task: {task}")
        response = client.models.generate_content(
            model=MODEL_NAME, config=self.config, contents=f"Develop a drug discovery plan for: {task}"
        )
        return response.text

# --- 3. DEMENTIA DETECTION AGENT (HIGH THINKING) ---
class DementiaDetectionAgent:
    def __init__(self):
        # 'high' used for analytical precision in medical classification
        self.config = get_thinking_config("high")

    def analyze(self, notes):
        print(f"\n[DEMENTIA AGENT] Analyzing: {notes}")
        response = client.models.generate_content(
            model=MODEL_NAME, config=self.config, contents=f"Identify dementia markers in: {notes}"
        )
        return response.text

# --- 4. OCEAN AI AGENT (LOW THINKING + THOUGHT SIGNATURES) ---
class OceanAIAgent:
    def __init__(self):
        self.config = get_thinking_config("low") # Fast for conversation
        self.history = [] # Stores full Content objects including thought_signatures

    def respond_to_user(self, user_input):
        # Build user message with single string part
        user_message = types.Content(
            role="user",
            parts=[types.Part.from_text(text=user_input)]
        )
        self.history.append(user_message)

        # Call model - pass back history to include previous thought signatures
        response = client.models.generate_content(
            model=MODEL_NAME,
            config=self.config,
            contents=self.history
        )

        # CRITICAL: Append full candidate content (with its signature) to history
        self.history.append(response.candidates[0].content)

        print(f"\n[WHALE]: {response.text}")
        return response.text

# --- MAIN EXECUTION ---
if __name__ == "__main__":
    try:
        # 1. Scientific Planning (High Reasoning)
        science_agent = DrugDiscoveryAgent()
        print(science_agent.run_discovery_task("Neuro-protective ADMET compounds")[:100] + "...")

        # 2. Clinical Analysis (High Reasoning)
        clinic_agent = DementiaDetectionAgent()
        print(clinic_agent.analyze("The sun is... uh... bright.")[:100] + "...")

        # 3. Empathetic Dialogue (Low Reasoning + State Management)
        whale = OceanAIAgent()
        whale.respond_to_user("How does plastic affect you?")
        whale.respond_to_user("What's the best way for me to help?")

    except Exception as e:
        print(f"Error: {e}")
# Out:
# [DRUG DISCOVERY] Task: Neuro-protective ADMET compounds
# Developing neuroprotective drugs is one of the most challenging areas of drug discovery due to the c...
#
# [DEMENTIA AGENT] Analyzing: The sun is... uh... bright.
# In linguistic analysis for cognitive decline, the sentence **"The sun is... uh... bright"** contains...
#
# [WHALE]: Plastic affects you in ways that are both highly visible and completely invisible. While plastic has made modern life more convenient and has been vital for medical advancements, its long-term impact on human health and the environment is significant.
#
# Here is a breakdown of how plastic affects you directly and indirectly:
#
# ### 1. Direct Health Impacts (Microplastics)
# Microplastics are tiny plastic particles (less than 5mm) that result from the breakdown of larger products or are shed from synthetic fabrics and tires.
# *   **Ingestion:** You likely consume a significant amount of microplastics every week. They have been found in tap water, bottled water, salt, beer, and seafood.
# *   **Inhalation:** Plastic fibers float in the air, especially indoors (from carpets and synthetic clothing). When inhaled, these can lodge in lung tissue.
# *   **Presence in the Body:** Recent studies have detected microplastics in **human blood, lungs, placentas, and even breast milk.** Scientists are still researching the long-term health consequences, but there are concerns about inflammation and cellular damage.
#
# ### 2. Chemical Exposure (Endocrine Disruption)
# Plastics are not just "plastic"; they contain additives to make them flexible, colorful, or fire-resistant. Many of these chemicals leak out into your food and drink.
# *   **BPA (Bisphenol A):** Used in many hard plastics and the lining of metal cans. It mimics the hormone estrogen and has been linked to reproductive issues, heart disease, and type 2 diabetes.
# *   **Phthalates:** Used to make plastics flexible (like in IV tubes or food packaging). These are known **endocrine disruptors** that can interfere with hormones, potentially leading to developmental issues in children and fertility problems in adults.
# *   **PFAS ("Forever Chemicals"):** Often used in grease-resistant food packaging. They do not break down in the body and are linked to cancer and immune system suppression.
#
# ### 3. Food Chain Contamination
# Plastic affects the food you eat before it even reaches your plate.
# *   **Bioaccumulation:** Small marine animals eat microplastics; larger fish eat those animals. Because plastic absorbs toxins like pesticides and heavy metals from the ocean water, these poisons become concentrated as they move up the food chain, eventually ending up in humans who eat seafood.
#
# ### 4. Air Quality and Environment
# *   **Toxic Fumes:** In many parts of the world, plastic waste is burned to get rid of it. This releases dioxins and particulate matter into the air, which can cause respiratory issues and increase cancer risks for nearby populations.
# *   **Water Quality:** Plastic waste clogs drainage systems, leading to stagnant water that can become a breeding ground for disease-carrying mosquitoes (like those carrying Malaria or Zika).
#
# ### 5. Economic Costs
# Plastic affects your wallet and the economy.
# *   **Waste Management:** A significant portion of your local taxes goes toward managing plastic waste and cleaning up litter in public spaces.
# *   **Healthcare Costs:** The health complications linked to plastic-related chemicals (like endocrine disruption) place a multi-billion dollar burden on global healthcare systems.
#
# ### The Paradox: How it *Helps* You
# It is important to note that plastic also protects you:
# *   **Medicine:** Sterile syringes, heart valves, IV bags, and prosthetic limbs are all made of plastic.
# *   **Safety:** Helmets, seatbelts, and airbags rely on plastic.
# *   **Food Safety:** Plastic packaging prevents food spoilage and reduces the spread of foodborne illnesses.
#
# ### How to Reduce Your Exposure
# Since you cannot avoid plastic entirely, you can minimize its impact by:
# 1.  **Avoiding heating plastic:** Never microwave food in plastic containers; heat transfers chemicals into food.
# 2.  **Filtering water:** Using a high-quality water filter can reduce microplastic intake from tap water.
# 3.  **Choosing natural fibers:** Wear cotton, wool, or linen to reduce the shedding of synthetic microfibers in your home.
# 4.  **Ditching "single-use":** Using glass or stainless steel containers for food and water significantly reduces direct chemical leaching.
#
# [WHALE]: The "best" way to help is to move beyond just recycling and focus on **stopping plastic at the source.** While individual habits matter, the most significant impact comes from a combination of personal lifestyle changes and systemic advocacy.
#
# Here is a tiered approach to how you can help effectively:
#
# ### 1. The Power of "Refuse" (High Impact)
# The old "3 Rs" (Reduce, Reuse, Recycle) are missing the most important one: **Refuse.**
# *   **The "Big Four":** Stop using plastic bags, water bottles, straws, and coffee cups. These are the most common items found in nature. Carry a reusable version of each.
# *   **Avoid "Wish-cycling":** Most plastic is not actually recyclable (only about 9% globally). Putting non-recyclable plastic in the bin actually contaminates the batch, making it all trash. If in doubt, find out exactly what your local facility accepts.
# *   **Choose "Naked" Produce:** Buy fruits and vegetables that aren't wrapped in plastic. Bring your own mesh bags for loose items.
#
# ### 2. Change Your Household Habits
# Small changes in your daily routine significantly reduce the amount of microplastics you release into the environment.
# *   **Wash synthetic clothes less often:** Synthetic fabrics (polyester, nylon, acrylic) shed millions of microfibers. Use a "Cora Ball" or a "Guppyfriend" bag in your washing machine to catch these fibers before they reach the ocean.
# *   **Switch to "Plastic-Free" Personal Care:** Use bar soap, bar shampoo, and bamboo toothbrushes. Avoid exfoliating scrubs that contain "microbeads" (though these are banned in many countries, they still exist in some markets).
# *   **Buy in Bulk:** Use your own glass jars at bulk stores to get grains, nuts, and oils. This eliminates the "packaging footprint" entirely.
#
# ### 3. Vote with Your Wallet
# Corporations track consumer trends. When you stop buying plastic-heavy products, companies change their packaging to keep your business.
# *   **Support "Circular" Brands:** Buy from companies that offer refills (like Blueland for cleaning supplies or Loop for groceries).
# *   **Avoid Fast Fashion:** Cheap clothing is essentially made of oil (polyester). Buy high-quality natural fibers (cotton, wool, hemp, linen) or buy second-hand.
# *   **Dine-In or Plastic-Free Takeout:** Ask your favorite local restaurants to switch to compostable containers, or bring your own container when you pick up food.
#
# ### 4. Push for Systemic Change (Highest Impact)
# Individual action is great, but **policy** forces the largest polluters to change.
# *   **Support Extended Producer Responsibility (EPR) Laws:** Support legislation that holds companies responsible for the entire lifecycle of their packaging. If a company has to pay for the cleanup of their bottles, they will design better bottles.
# *   **Support Plastic Bans:** Get involved in local movements to ban single-use plastics (like bags or polystyrene) in your city or state.
# *   **Hold Brands Accountable:** Use social media to tag companies using excessive packaging. Public pressure often forces a response from corporate sustainability departments.
#
# ### 5. Community Action
# *   **Join a Cleanup:** Participating in a beach or park cleanup is eye-opening. It helps you see exactly which brands and items are polluting your specific area.
# *   **Educate Without Shaming:** Share what you’ve learned with friends and family. Most people want to help but feel overwhelmed by where to start.
#
# ### The "One Thing" Rule
# If you feel overwhelmed, **pick just one thing this month.** For example: "This month, I will not buy a single plastic water bottle." Once that becomes a habit, pick a second thing. Total perfection is impossible, but 1,000 people doing it "imperfectly" is much better than 10 people doing it perfectly.
