# %% [markdown]
# <a href="https://colab.research.google.com/github/frank-morales2020/MLxDL/blob/main/MISTRAL_TUTORIAL_a100gpuVt4gpu-A100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MISTRAL TUTORIAL

# %%
from pathlib import Path

code_path = "/content/mistral-src/"  # codebase
data_path = Path("/content/gdrive/MyDrive/datasets/mistral/mistral-7B-v0.1/Symptom2Disease.csv")  # dataset downloaded from Kaggle
model_path = Path("/content/gdrive/MyDrive/datasets/mistral/mistral-7B-v0.1/")  # model and tokenizer location

#!pip install -q -U mistral-src

# !pip install colab-env --upgrade
import colab_env

# !git clone https://github.com/mistralai/mistral-src.git
# %cd /content/mistral-src
# !pip install -r /content/mistral-src/requirements.txt
# Out:
# Collecting colab-env
#   Downloading colab-env-0.2.0.tar.gz (4.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting python-dotenv<1.0,>=0.10.0 (from colab-env)
#   Downloading python_dotenv-0.21.1-py3-none-any.whl (19 kB)
# Building wheels for collected packages: colab-env
#   Building wheel for colab-env (setup.py) ... done
#   Created wheel for colab-env: filename=colab_env-0.2.0-py3-none-any.whl size=3805 sha256=dcf775b7eca59bd4d90ac2433c8b6f12b812048c7188ddeeb24591ffe16f8897
#   Stored in directory: /root/.cache/pip/wheels/ae/36/4f/466c2cd4db5d08f317893a920c4a0f58a81459ee3bdb136d35
# Successfully built colab-env
# Installing collected packages: python-dotenv, colab-env
# Successfully installed colab-env-0.2.0 python-dotenv-0.21.1
# Mounted at /content/gdrive
# Cloning into 'mistral-src'...
# remote: Enumerating objects: 156, done.
# remote: Counting objects: 100% (87/87), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 156 (delta 65), reused 45 (delta 32), pack-reused 69
# Receiving objects: 100% (156/156), 373.18 KiB | 20.73 MiB/s, done.
# Resolving deltas: 100% (74/74), done.
# /content/mistral-src
# Collecting fire (from -r /content/mistral-src/requirements.txt (line 1))
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting sentencepiece (from -r /content/mistral-src/requirements.txt (line 2))
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 33.0 MB/s eta 0:00:00
# Requirement already satisfied: torch>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/mistral-src/requirements.txt (line 3)) (2.1.0+cu121)
# Collecting xformers (from -r /content/mistral-src/requirements.txt (line 4))
#   Downloading xformers-0.0.23.post1-cp310-cp310-manylinux2014_x86_64.whl (213.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 MB 7.8 MB/s eta 0:00:00
# Collecting simple-parsing (from -r /content/mistral-src/requirements.txt (line 5))
#   Downloading simple_parsing-0.1.4-py3-none-any.whl (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.4/113.4 kB 15.9 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fire->-r /content/mistral-src/requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire->-r /content/mistral-src/requirements.txt (line 1)) (2.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.0->-r /content/mistral-src/requirements.txt (line 3)) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.0->-r /content/mistral-src/requirements.txt (line 3)) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.0->-r /content/mistral-src/requirements.txt (line 3)) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.0->-r /content/mistral-src/requirements.txt (line 3)) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.0->-r /content/mistral-src/requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.0->-r /content/mistral-src/requirements.txt (line 3)) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.0->-r /content/mistral-src/requirements.txt (line 3)) (2.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xformers->-r /content/mistral-src/requirements.txt (line 4)) (1.23.5)
# Collecting torch>=2.1.0 (from -r /content/mistral-src/requirements.txt (line 3))
#   Downloading torch-2.1.2-cp310-cp310-manylinux1_x86_64.whl (670.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 1.3 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=2.1.0->-r /content/mistral-src/requirements.txt (line 3))
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 67.6 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=2.1.0->-r /content/mistral-src/requirements.txt (line 3))
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 65.8 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=2.1.0->-r /content/mistral-src/requirements.txt (line 3))
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 91.9 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=2.1.0->-r /content/mistral-src/requirements.txt (line 3))
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.5 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=2.1.0->-r /content/mistral-src/requirements.txt (line 3))
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.6 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=2.1.0->-r /content/mistral-src/requirements.txt (line 3))
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 13.0 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=2.1.0->-r /content/mistral-src/requirements.txt (line 3))
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 27.6 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=2.1.0->-r /content/mistral-src/requirements.txt (line 3))
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 11.6 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=2.1.0->-r /content/mistral-src/requirements.txt (line 3))
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.8 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.18.1 (from torch>=2.1.0->-r /content/mistral-src/requirements.txt (line 3))
#   Downloading nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl (209.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 MB 8.2 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=2.1.0->-r /content/mistral-src/requirements.txt (line 3))
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 14.7 MB/s eta 0:00:00
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.1.0->-r /content/mistral-src/requirements.txt (line 3))
#   Downloading nvidia_nvjitlink_cu12-12.3.101-py3-none-manylinux1_x86_64.whl (20.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.5/20.5 MB 89.7 MB/s eta 0:00:00
# Collecting docstring-parser~=0.15 (from simple-parsing->-r /content/mistral-src/requirements.txt (line 5))
#   Downloading docstring_parser-0.15-py3-none-any.whl (36 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.1.0->-r /content/mistral-src/requirements.txt (line 3)) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=2.1.0->-r /content/mistral-src/requirements.txt (line 3)) (1.3.0)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116934 sha256=b7ea546b1eaf25ea436089af3a75c9452701906bf1341c1d7203d68672c392c4
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# Successfully built fire
# Installing collected packages: sentencepiece, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, fire, docstring-parser, simple-parsing, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, xformers
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.0+cu121
#     Uninstalling torch-2.1.0+cu121:
#       Successfully uninstalled torch-2.1.0+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.1.0+cu121 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# torchdata 0.7.0 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# torchtext 0.16.0 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# torchvision 0.16.0+cu121 requires torch==2.1.0, but you have torch 2.1.2 which is incompatible.
# Successfully installed docstring-parser-0.15 fire-0.5.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.18.1 nvidia-nvjitlink-cu12-12.3.101 nvidia-nvtx-cu12-12.1.105 sentencepiece-0.1.99 simple-parsing-0.1.4 torch-2.1.2 xformers-0.0.23.post1

# %% [markdown]
# # Run the DEMO - Run the model
#
# https://github.com/mistralai/mistral-src/tree/main

# %%
## PREPARIND STAND-ALONE THE DEMO.

# !pip install colab-env --upgrade
import colab_env

# !git clone https://github.com/mistralai/mistral-src.git
# %cd /content/mistral-src
# !pip install -r /content/mistral-src/requirements.txt

# %%
#!python -m main demo /content/gdrive/MyDrive/datasets/mistral/mistral-7B-v0.1/

# To give your own prompts
#!python -m main interactive /content/gdrive/MyDrive/datasets/mistral/mistral-7B-v0.1/

#!python -m test_generate

#!python -m main interactive /content/gdrive/MyDrive/datasets/mistral/mistral-7B-v0.1/ --max_tokens 256 --temperature 1.0

# %%
#Imports
import csv
import tqdm
import torch
import numpy as np
from pathlib import Path

import torch
from torch import bfloat16

#model = Transformer.from_folder(model_path, dtype=bfloat16)

code_path = "/content/mistral-src/"  # codebase
data_path = Path("/content/gdrive/MyDrive/datasets/mistral/mistral-7B-v0.1/Symptom2Disease.csv")  # dataset downloaded from Kaggle
model_path = Path("/content/gdrive/MyDrive/datasets/mistral/mistral-7B-v0.1/")  # model and tokenizer location

import sys
sys.path.append(code_path)  # append the path where mistral-src was cloned

from mistral.model import Transformer
from mistral.tokenizer import Tokenizer
from main import generate

#Load the model and tokenizer # ALTERNATIVE

## T4 GPU
#model = Transformer.from_folder(model_path, max_batch_size=3)

### A100 GPU
model = Transformer.from_folder(model_path, dtype=torch.bfloat16)

tokenizer = Tokenizer(str(model_path / "tokenizer.model"))

max_tokens = 256
temperature = 1.0
prompt='I bought an ice cream for 6 kids. Each cone was $1.25 and I paid with a $10 bill. How many dollars did I get back? Explain first before answering.'
response=generate([prompt], model, tokenizer, max_tokens=max_tokens, temperature=temperature)

#tokenizer.batch_decode(response)[0]

print(response[0])
# Out:
# ['I bought an ice cream for 6 kids. Each cone was $1.25 and I paid with a $10 bill. How many dollars did I get back? Explain first before answering.\n\n## Answer\n\nStep-by-step explanation:\n\nThe cost of the ice cream was $7.50 ($1.25 x 6 kids)\n\nThis means that $10 – $7.50 = $2.50 was the change\n\nTo be sure you are correct you can also solve the problem as follows:\n\nEach ice cream was $1.25 and I bought 6 ice creams.\n\nThe total cost was $1.25 x 6 = $7.50\n\nI paid with a $10 bill.\n\nThis means I gave the ice cream man $10.\n\nThe ice cream man gave me $10 – $7.50 = $2.50\n\n## Other explanations\n\nYou may be interested in:\n\n- Multiply and Divide Fractions: 4/5 ÷ 2/3\n- Multiply and Divide Fractions: 1/3 ÷ 1/2\n- Multiply and Divide Fractions: 4/7 ÷ 7/8\n- Multiply and Divide Fractions: 3']

# %%
max_tokens = 512
temperature = 0.9

prompt = "As a data scientist, can you explain the concept of regularization in machine learning?"
prompt='I bought an ice cream for 6 kids. Each cone was $1.25 and I paid with a $10 bill. How many dollars did I get back? Explain first before answering.'

#prompt='Which country has the most natural lakes? Answer with only the country name.'

response=generate([prompt], model, tokenizer, max_tokens=max_tokens, temperature=temperature)
#print(response[0])
tokenizer.decode(response[0])


#model = Transformer(args).to("cuda", dtype=torch.float32)
#tokenizer = DebugTokenizer()
# Out:
# 'I bought an ice cream for 6 kids. Each cone was $1.25 and I paid with a $10 bill. How many dollars did I get back? Explain first before answering.\n\n### Answer & Explanation\n\nThis is a math question that can be solved by setting up an equation and solving for the unknown variable.\nThe total cost of the ice cream cones is $6.25.\nThe amount of money paid is $10.\nThe amount of money received back is the difference between the total cost and the amount paid, or $10 - $6.25 = $3.75.\nThis question can be solved using basic algebraic principles.\nThe equation is $10 - $6.25 = $3.75.\nThe solution is $3.75.\n\nAnswer is 3.75.к 10 - 6.25 = 3.75.к 10 - 6.25 = 3.75.к 10 - 6.25 = 3.75.к 10 - 6.25 = 3.75.к 10 - 6.25 = 3.75.к 10 - 6.25 = 3.75.к 10 - 6.25 = 3.75.к 10 - 6.25 = 3.75.к 10 - 6.25 = 3.75.к 10 - 6.25 = 3.75.к 10 - 6.25 = 3.75. індек 10 - 6.25 = 3.75.к 10 - 6.25 = 3.75.к 10 - 6.25 = 3.75. українка 10 - 6.25 = 3.75.\n\nThe answer is $3.75.к 10 - 6.25 = 3.75. укр 10 - 6.25 = 3.75. укр 10 - 6.25 = 3.75. укр 10 - 6.25 = 3.75. укр 10 -'

# %% [markdown]
# # Load the model and tokenizer

# %%
# https://huggingface.co/docs/transformers/main/model_doc/mistral


#Imports
import csv
import tqdm
import torch
import numpy as np

# !git clone https://github.com/mistralai/mistral-src.git
# %cd /content/mistral-src
#!pip install -r /content/mistral-src/requirements.txt
code_path = "/content/mistral-src/"

import sys

from transformers import AutoModelForCausalLM, AutoTokenizer

device = "cuda" # the device to load the model onto

model = AutoModelForCausalLM.from_pretrained("mistralai/Mistral-7B-Instruct-v0.1")
tokenizer = AutoTokenizer.from_pretrained("mistralai/Mistral-7B-Instruct-v0.1")
# Out:
# Cloning into 'mistral-src'...
# remote: Enumerating objects: 156, done.
# remote: Counting objects: 100% (87/87), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 156 (delta 65), reused 45 (delta 32), pack-reused 69
# Receiving objects: 100% (156/156), 373.18 KiB | 19.64 MiB/s, done.
# Resolving deltas: 100% (74/74), done.
# /content/mistral-src
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.47k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]

# %% [markdown]
# # Examples #1

# %%
# NEED A100 GPU BECAUSE THE HIGH MEMORY TOO

prompt = "As a data scientist, can you explain the concept of regularization in machine learning?"

model_inputs = tokenizer([prompt], return_tensors="pt").to(device)
model.to(device)

#model = MistralForCausalLM.from_pretrained("gpt2-xl")



generated_ids = model.generate(**model_inputs, max_new_tokens=51200, do_sample=True)
print()
#CUDA_VISIBLE_DEVICES=0,1
#tokenizer.batch_decode(generated_ids)[0]
tokenizer.batch_decode(generated_ids)[0]
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# '<s> As a data scientist, can you explain the concept of regularization in machine learning?\n\nSure! Regularization is a technique used in machine learning to prevent overfitting and reduce the complexity of a model. It adds a penalty term to the loss function that the model is trying to minimize, which encourages the model to have smaller coefficients or weights. This can help prevent the model from memorizing the training data and improve its ability to generalize to new data. Regularization methods include L1, L2, and elastic net regularization.</s>'

# %% [markdown]
# # Examples #2

# %%
prompt='Which country has the most natural lakes? Answer with only the country name.'

model_inputs = tokenizer([prompt], return_tensors="pt").to(device)
model.to(device)

generated_ids = model.generate(**model_inputs, max_new_tokens=51200, do_sample=True)
print()
tokenizer.batch_decode(generated_ids)[0]
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# '<s> Which country has the most natural lakes? Answer with only the country name. Canada</s>'

# %% [markdown]
# # Examples #3

# %%
prompt = "My favourite condiment is"

model_inputs = tokenizer([prompt], return_tensors="pt").to(device)
model.to(device)

generated_ids = model.generate(**model_inputs, max_new_tokens=51200, do_sample=True)
print()
tokenizer.batch_decode(generated_ids)[0]
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# '<s> My favourite condiment is probably ketchup. I love its bright red colour and the tangy taste it adds to everything from burgers to eggs and even french fries. I think a good quality ketchup really enhances the flavour of the dish it is being used on and brings some freshness to the dish.</s>'

# %% [markdown]
# # Examples #4

# %%
prompt='I bought an ice cream for 6 kids. Each cone was $1.25 and I paid with a $10 bill. How many dollars did I get back? Explain first before answering.'

model_inputs = tokenizer([prompt], return_tensors="pt").to(device)
model.to(device)

generated_ids = model.generate(**model_inputs, max_new_tokens=51200, do_sample=True)
print()
tokenizer.batch_decode(generated_ids)[0]
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# "<s> I bought an ice cream for 6 kids. Each cone was $1.25 and I paid with a $10 bill. How many dollars did I get back? Explain first before answering. Here's how to figure this out. If the price of one cone is $1.25, how much is the total cost of 6 cones? The total cost would be multiplied by 6 to get 6 times $1.25, which equals $7.50. Once I paid with a $10 bill, I put the change aside. The $10 is greater than the $7.50, so I have $2.50 ($10 - $7.50) back. \n\nSo, I got $2.50 back.</s>"
