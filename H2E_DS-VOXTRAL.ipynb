# %% [markdown]
# <a href="https://colab.research.google.com/github/frank-morales2020/MLxDL/blob/main/H2E_DS-VOXTRAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.nature.com/articles/s41586-025-09422-z

# %% [markdown]
# ## LLAMA.CPP

# %%
# Clone the repository
# !git clone https://github.com/ggerganov/llama.cpp
# %cd llama.cpp

# Compile with CUDA support
# !cmake -B build -DGGML_CUDA=ON
# !cmake --build build --config Release -j $(nproc)

# %%
# !ls /content/llama.cpp/build/bin |wc -l
# Out:
# 107

# %%
# Ensure CUDA 12+ is active for Ada Lovelace support
# !export CUDA_HOME=/usr/local/cuda
# !export PATH=$CUDA_HOME/bin:$PATH
# !export LD_LIBRARY_PATH=$CUDA_HOME/lib64:$LD_LIBRARY_PATH

# Install with Flash Attention support for Ada architecture
# !CMAKE_ARGS="-DGGML_CUDA=on -DGGML_CUDA_F16=on" FORCE_CMAKE=1 \
pip install llama-cpp-python --no-cache-dir

# %%
# !pip show llama-cpp-python diskcache
# Out:
# Name: llama_cpp_python
# Version: 0.3.20
# Summary: Python bindings for the llama.cpp library
# Home-page: https://github.com/abetlen/llama-cpp-python
# Author:
# Author-email: Andrei Betlen <abetlen@gmail.com>
# License: MIT
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: diskcache, jinja2, numpy, typing-extensions
# Required-by:
# ---
# Name: diskcache
# Version: 5.6.3
# Summary: Disk Cache -- Disk and file backed persistent cache.
# Home-page: http://www.grantjenks.com/docs/diskcache/
# Author: Grant Jenks
# Author-email: contact@grantjenks.com
# License: Apache 2.0
# Location: /usr/local/lib/python3.12/dist-packages
# Requires:
# Required-by: llama_cpp_python

# %% [markdown]
# ## DS-WITH-LLAMA.CPP

# %%
import os
from huggingface_hub import snapshot_download

# Define where you want the 42.5 GB file to go
model_path = "/content/deepseek-r1-distill-llama"
os.makedirs(model_path, exist_ok=True)

print("📥 Starting targeted download of the 70B Q4_K_M snapshot...")

# snapshot_download is the current preferred method for full/filtered repos
snapshot_download(
    repo_id="unsloth/DeepSeek-R1-Distill-Llama-70B-GGUF",
    local_dir=model_path,
    allow_patterns=["*Q4_K_M.gguf"],  # Only download this specific 42.5GB file
    token=os.environ.get('HF_TOKEN')  # Uses your environment variable for auth
)

print(f"✅ Download complete! File located in: {model_path}")

# %%
from llama_cpp import Llama
import os

# Define the absolute path based on your successful download
model_path = "/content/deepseek-r1-distill-llama/DeepSeek-R1-Distill-Llama-70B-Q4_K_M.gguf"

print("🚀 Initializing H2E Cognitive Layer on NVIDIA L4...")

llm = Llama(
    model_path=model_path,
    n_gpu_layers=35,      # Offload ~35 layers to 24GB VRAM
    n_ctx=4096,           # Context window for expert reasoning
    n_batch=512,          # Batch size optimized for L4
    flash_attn=True,      # Use Flash Attention 2 for Ada Lovelace
    verbose=True          # Crucial: check logs for 'BLAS = 1'
)

print("\n✅ Cognitive Layer Ready.")

# %% [markdown]
# ## VOXTRAL

# %%
import os
from huggingface_hub import snapshot_download

# Define where you want the 42.5 GB file to go
model_path = "/content/Voxtral-Mini-4B-Realtime-2602-GGUF"
os.makedirs(model_path, exist_ok=True)

print("📥 Starting targeted download of the 70B Q4_K_M snapshot...")

# snapshot_download is the current preferred method for full/filtered repos
snapshot_download(
    repo_id="andrijdavid/Voxtral-Mini-4B-Realtime-2602-GGUF",
    local_dir=model_path,
    allow_patterns=["*Q4_K_M.gguf"],  # Only download this specific 42.5GB file
    token=os.environ.get('HF_TOKEN')  # Uses your environment variable for auth
)

print(f"✅ Download complete! File located in: {model_path}")

# %%
# %cd /content/voxtral.cpp
# !git submodule update --init --recursive
# Out:
# /content/voxtral.cpp
# Submodule 'ggml' (https://github.com/ggml-org/ggml.git) registered for path 'ggml'
# Cloning into '/content/voxtral.cpp/ggml'...
# Submodule path 'ggml': checked out '5cecdad692d868e28dbd2f7c468504770108f30c'

# %%
# Clean up the old failed attempt
# !rm -rf build

# Configure with CUDA support
# !cmake -B build -DGGML_CUDA=ON -DCMAKE_BUILD_TYPE=Release

# Build using all available CPU cores
# !cmake --build build -j$(nproc)

# %%
# !./build/voxtral --help
# Out:
# usage: ./build/voxtral --model path.gguf --audio file.wav [options]
#
# options:
#   --model PATH          GGUF model path
#   --audio PATH          input wav (mono or stereo PCM16/float32)
#   --threads N           cpu threads
#   --seed N              rng seed (reserved for sampling)
#   --prompt TEXT         prompt text (compatibility, currently ignored for realtime mode)
#   --n-tokens N          max decode tokens (alias of --max-len)
#   --max-len N           max decode tokens
#   --verbose             equivalent to --log-level debug
#   --log-level LEVEL     error|warn|info|debug
#   --dump-logits PATH    write step-0 logits (first 32 values) as text
#   --dump-logits-bin P   write full step-0 logits as float32 raw bytes
#   --dump-tokens PATH    write generated token ids as a single line
#   --output-text PATH    write decoded text to file (still prints to stdout)
#   --gpu BACKEND         gpu backend: auto|cuda|metal|vulkan|none (default: none)
#   --metal               alias for --gpu metal
#   -h, --help            show this help

# %% [markdown]
# 1. Download a Sample via Terminal
# Run this in a cell to grab a clean speech sample from the Harvard Sentences (a standard for audio testing):

# %%
# %cd /content
# !git clone https://github.com/frank-morales2020/UNESCO.git
# !ls -la /content/UNESCO/
# Out:
# /content
# Cloning into 'UNESCO'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 25 (delta 3), reused 6 (delta 2), pack-reused 18 (from 2)
# Receiving objects: 100% (25/25), 178.91 MiB | 12.44 MiB/s, done.
# Resolving deltas: 100% (6/6), done.
# total 62680
# drwxr-xr-x 3 root root     4096 Apr 12 21:53 .
# drwxr-xr-x 1 root root     4096 Apr 12 21:53 ..
# -rw-r--r-- 1 root root  2108952 Apr 12 21:53 barackobamatransitionaddress1.mp3
# drwxr-xr-x 8 root root     4096 Apr 12 21:53 .git
# -rw-r--r-- 1 root root      262 Apr 12 21:53 H2E_Challenge_Dataset.csv
# -rw-r--r-- 1 root root 62056557 Apr 12 21:53 mlk_mountaintop_1968.mp3

# %% [markdown]
# 2. Verify and Convert (If needed)
# Voxtral is very picky about format. Even if you download a file, it’s best to ensure it matches the 16kHz / 16-bit / Mono requirement using ffmpeg:

# %%
# !ffmpeg -y -i /content/UNESCO/barackobamatransitionaddress1.mp3 \
    -ar 16000 -ac 1 -c:a pcm_s16le /content/obama_ready.wav
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# [mp3 @ 0x5860214f4c00] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/content/UNESCO/barackobamatransitionaddress1.mp3':
#   Metadata:
#     comment         : Remixed and Mastered by Michael E. Eidenmuller
#     genre           : Speech
#     artist          : Barack Obama
#     title           : First President-Elect Weekly Transition Address
#     encoded_by      : Michael E. Eidenmuller
#     copyright       : 2009
#     TOPE            : Change.gov
#     publisher       : AmericanRhetoric.com
#     date            : 2008
#   Duration: 00:03:30.69, start: 0.000000, bitrate: 80 kb/s
#   Stream #0:0: Audio: mp3, 22050 Hz, stereo, fltp, 80 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/content/obama_ready.wav':
#   Metadata:
#     ICMT            : Remixed and Mastered by Michael E. Eidenmuller
#     IGNR            : Speech
#     IART            : Barack Obama
#     INAM            : First President-Elect Weekly Transition Address
#     ITCH            : Michael E. Eidenmuller
#     ICOP            : 2009
#     TOPE            : Change.gov
#     publisher       : AmericanRhetoric.com
#     ICRD            : 2008
#     ISFT            : Lavf58.76.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_s16le
# size=    6584kB time=00:03:30.67 bitrate= 256.0kbits/s speed= 684x
# video:0kB audio:6584kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004272%

# %% [markdown]
# 3. Run Inference
# Now you can point your freshly built voxtral binary at your model and the new audio file:

# %%
# !/content/voxtral.cpp/build/voxtral \
  --model /content/Voxtral-Mini-4B-Realtime-2602-GGUF/Q4_K_M.gguf \
  --audio /content/obama_ready.wav \
  --threads 8
# Out:
# voxtral_I: loading model from /content/Voxtral-Mini-4B-Realtime-2602-GGUF/Q4_K_M.gguf
# voxtral_I: model loaded: enc_layers=32 dec_layers=26 vocab=131072
# voxtral_I: model weights: 2895.195648 MB
# voxtral_I: encoder: dim=1280 heads=32 head_dim=64 hidden=5120
# voxtral_I: decoder: dim=3072 heads=32 head_dim=128 hidden=9216 kv_heads=8
# voxtral_I: model load time: 2573.99 ms
# voxtral_I: backend: CPU with 8 threads
# voxtral_I: BLAS backend enabled with 8 threads
# voxtral_I: buffers: encoder_chunk=10.24 MB kv_cache=1744.83 MB
# voxtral_I: context initialized
# voxtral_I: audio loaded: 3370841 samples (210.7 s)
# voxtral_I: padded audio: 3434240 samples (left=40960, right=22439)
# voxtral_I: mel spectrogram: 21464 frames
# voxtral_I: encoder chunked: 21464 mel frames, 10730 alloc enc tokens, mel_stride=1500
# voxtral_I: encoder chunk 0: mel[0..3000) enc_tokens=1500 skip=0 stride=1500 rope_offset=0
# voxtral_I: encoder chunk 1: mel[1500..4500) enc_tokens=1500 skip=750 stride=750 rope_offset=750
# voxtral_I: encoder chunk 2: mel[3000..6000) enc_tokens=1500 skip=750 stride=750 rope_offset=1500
# voxtral_I: encoder chunk 3: mel[4500..7500) enc_tokens=1500 skip=750 stride=750 rope_offset=2250
# voxtral_I: encoder chunk 4: mel[6000..9000) enc_tokens=1500 skip=750 stride=750 rope_offset=3000
# voxtral_I: encoder chunk 5: mel[7500..10500) enc_tokens=1500 skip=750 stride=750 rope_offset=3750
# voxtral_I: encoder chunk 6: mel[9000..12000) enc_tokens=1500 skip=750 stride=750 rope_offset=4500
# voxtral_I: encoder chunk 7: mel[10500..13500) enc_tokens=1500 skip=750 stride=750 rope_offset=5250
# voxtral_I: encoder chunk 8: mel[12000..15000) enc_tokens=1500 skip=750 stride=750 rope_offset=6000
# voxtral_I: encoder chunk 9: mel[13500..16500) enc_tokens=1500 skip=750 stride=750 rope_offset=6750
# voxtral_I: encoder chunk 10: mel[15000..18000) enc_tokens=1500 skip=750 stride=750 rope_offset=7500
# voxtral_I: encoder chunk 11: mel[16500..19500) enc_tokens=1500 skip=750 stride=750 rope_offset=8250
# voxtral_I: encoder chunk 12: mel[18000..21000) enc_tokens=1500 skip=750 stride=750 rope_offset=9000
# voxtral_I: encoder chunk 13: mel[19500..21464) enc_tokens=980 skip=750 stride=230 rope_offset=9750
# voxtral_I: encoder done: 14 chunks, enc_seq_used=10728 (raw=10730)
# voxtral_I: encoder time: 356535.3 ms
# voxtral_I: running adapter: enc_seq=10728 -> dec_seq=2682
# voxtral_I: adapter graph: size=2048 nodes=7
# voxtral_I: adapter done: dec_seq_len=2682 (32.96 MB on device)
# voxtral_I: adapter time: 537.0 ms
# voxtral_I: prompt: 39 tokens, audio_tokens: 2682
# voxtral_I: decoder prefill: 38 tokens
# voxtral_I: decoder prefill graph: size=8192 nodes=1152
# voxtral_I: decoder prefill done
# voxtral_I: prefill time: 9538.8 ms
# voxtral_I: first token: 32
# voxtral_I: decode time: 17821.4 ms (255 steps, 69.9 ms/step)
# voxtral_I: generated 256 tokens
#  On Tuesday, Americans stood in line that stretched around schools and churches in numbers this nation has never seen. It didn't matter who they were or where they came from. And what they looked like, or what party they belonged to. They came out and cast their ballot because they believed that in this country, our destiny is not written for us,
# [tokens] 32 32 32 32 32 32 32 32 32 32 33 3249 32 32 32 32 32 32 33 44692 1044 32 32 32 32 33 20999 32 32 33 13231 1294 32 33 3110 32 33 1455 32 32 32 33 42989 32 32 33 3879 32 32 32 32 33 13053 1321 32 32 32 32 32 32 33 36666 32 32 32 33 1294 32 32 32 33 8091 32 33 1593 32 32 33 9682 32 33 1934 32 33 4772 32 32 32 33 5753 1046 32 32 32 32 32 32 32 32 32 33 2157 4814 2405 32 33 8122 2274 32 33 2127 32 32 33 1722 32 32 32 32 33 1505 2478 2127 32 32 32 33 5740 32 32 33 1562 1046 32 32 33 3060 2549 32 33 2127 32 33 6980 32 32 33 2479 1044 32 32 32 33 1505 2549 32 32 32 33 8967 2127 32 32 32 33 43530 32 33 1317 1046 32 32 32 32 32 32 32 33 4159 32 32 33 5740 1848 1321 32 32 32 32 33 7958 2034 32 32 32 32 33 63130 32 32 32 33 3147 2127 32 32 32 32 33 14521 32 33 1455 1294 32 32 33 1593 32 32 32 32 33 6816 1044 32 32 32 32 33 2948 32 32 32 32 33 88266 1395 32 32 33 1605 32 33 8360 32 33 1394 32 32 33 1650 1044 32 32 32
# ggml_cuda_init: found 1 CUDA devices:
#   Device 0: NVIDIA L4, compute capability 8.9, VMM: yes
# [summary] processing_time_ms=389428.41
# [summary] build_backend_flags: GGML_USE_CPU=ON, GGML_USE_BLAS=ON, GGML_USE_METAL=OFF, GGML_USE_CUDA=ON, GGML_USE_VULKAN=OFF, GGML_USE_SYCL=OFF, GGML_USE_OPENCL=OFF, GGML_USE_CANN=OFF, GGML_USE_WEBGPU=OFF, GGML_USE_RPC=OFF, GGML_USE_ZDNN=OFF, GGML_USE_ZENDNN=OFF, GGML_USE_HEXAGON=OFF, GGML_USE_VIRTGPU_FRONTEND=OFF
# [summary] runtime_backends: CUDA(1 dev), BLAS(1 dev), CPU(1 dev)
# [summary] runtime_available: CPU=yes, BLAS=yes, METAL=no, CUDA=yes, VULKAN=no, SYCL=no, OPENCL=no, CANN=no, WEBGPU=no, RPC=no, ZDNN=no, ZENDNN=no, HEXAGON=no, VIRTGPU=no

# %% [markdown]
# That is an incredible jump in performance! You just slashed your encoder time from 356,535 ms down to 2,027.3 ms.
#
# That is roughly a 175x speedup. By enabling --gpu cuda, you finally unlocked the L4's Tensor Cores for the voxtral_realtime architecture.

# %%
# !/content/voxtral.cpp/build/voxtral \
  --model /content/Voxtral-Mini-4B-Realtime-2602-GGUF/Q4_K_M.gguf \
  --audio /content/obama_ready.wav \
  --gpu cuda \
  --max-len 512 \
  --threads 8
# Out:
# voxtral_I: loading model from /content/Voxtral-Mini-4B-Realtime-2602-GGUF/Q4_K_M.gguf
# ggml_cuda_init: found 1 CUDA devices:
#   Device 0: NVIDIA L4, compute capability 8.9, VMM: yes
# voxtral_I: model loaded: enc_layers=32 dec_layers=26 vocab=131072
# voxtral_I: model weights: 2895.236608 MB
# voxtral_I: encoder: dim=1280 heads=32 head_dim=64 hidden=5120
# voxtral_I: decoder: dim=3072 heads=32 head_dim=128 hidden=9216 kv_heads=8
# voxtral_I: model load time: 1666.54 ms
# voxtral_I: backend: CUDA (CPU fallback 8 threads)
# voxtral_I: BLAS backend enabled with 8 threads
# voxtral_I: buffers: encoder_chunk=10.24 MB kv_cache=1744.83 MB
# voxtral_I: context initialized
# voxtral_I: audio loaded: 3370841 samples (210.7 s)
# voxtral_I: padded audio: 3434240 samples (left=40960, right=22439)
# voxtral_I: mel spectrogram: 21464 frames
# voxtral_I: encoder chunked: 21464 mel frames, 10730 alloc enc tokens, mel_stride=1500
# voxtral_I: encoder chunk 0: mel[0..3000) enc_tokens=1500 skip=0 stride=1500 rope_offset=0
# voxtral_I: encoder chunk 1: mel[1500..4500) enc_tokens=1500 skip=750 stride=750 rope_offset=750
# voxtral_I: encoder chunk 2: mel[3000..6000) enc_tokens=1500 skip=750 stride=750 rope_offset=1500
# voxtral_I: encoder chunk 3: mel[4500..7500) enc_tokens=1500 skip=750 stride=750 rope_offset=2250
# voxtral_I: encoder chunk 4: mel[6000..9000) enc_tokens=1500 skip=750 stride=750 rope_offset=3000
# voxtral_I: encoder chunk 5: mel[7500..10500) enc_tokens=1500 skip=750 stride=750 rope_offset=3750
# voxtral_I: encoder chunk 6: mel[9000..12000) enc_tokens=1500 skip=750 stride=750 rope_offset=4500
# voxtral_I: encoder chunk 7: mel[10500..13500) enc_tokens=1500 skip=750 stride=750 rope_offset=5250
# voxtral_I: encoder chunk 8: mel[12000..15000) enc_tokens=1500 skip=750 stride=750 rope_offset=6000
# voxtral_I: encoder chunk 9: mel[13500..16500) enc_tokens=1500 skip=750 stride=750 rope_offset=6750
# voxtral_I: encoder chunk 10: mel[15000..18000) enc_tokens=1500 skip=750 stride=750 rope_offset=7500
# voxtral_I: encoder chunk 11: mel[16500..19500) enc_tokens=1500 skip=750 stride=750 rope_offset=8250
# voxtral_I: encoder chunk 12: mel[18000..21000) enc_tokens=1500 skip=750 stride=750 rope_offset=9000
# voxtral_I: encoder chunk 13: mel[19500..21464) enc_tokens=980 skip=750 stride=230 rope_offset=9750
# voxtral_I: encoder done: 14 chunks, enc_seq_used=10728 (raw=10730)
# voxtral_I: encoder time: 2027.3 ms
# voxtral_I: running adapter: enc_seq=10728 -> dec_seq=2682
# voxtral_I: adapter graph: size=2048 nodes=7
# voxtral_I: adapter done: dec_seq_len=2682 (32.96 MB on device)
# voxtral_I: adapter time: 3.9 ms
# voxtral_I: prompt: 39 tokens, audio_tokens: 2682

# %%
# !/content/voxtral.cpp/build/voxtral \
  --model /content/Voxtral-Mini-4B-Realtime-2602-GGUF/Q4_K_M.gguf \
  --audio /content/obama_ready.wav \
  --gpu none \
  --threads 12 \
  --max-len 1024
# Out:
# voxtral_I: loading model from /content/Voxtral-Mini-4B-Realtime-2602-GGUF/Q4_K_M.gguf
# voxtral_I: model loaded: enc_layers=32 dec_layers=26 vocab=131072
# voxtral_I: model weights: 2895.195648 MB
# voxtral_I: encoder: dim=1280 heads=32 head_dim=64 hidden=5120
# voxtral_I: decoder: dim=3072 heads=32 head_dim=128 hidden=9216 kv_heads=8
# voxtral_I: model load time: 2514.80 ms
# voxtral_I: backend: CPU with 12 threads
# voxtral_I: BLAS backend enabled with 12 threads
# voxtral_I: buffers: encoder_chunk=10.24 MB kv_cache=1744.83 MB
# voxtral_I: context initialized
# voxtral_I: audio loaded: 3370841 samples (210.7 s)
# voxtral_I: padded audio: 3434240 samples (left=40960, right=22439)
# voxtral_I: mel spectrogram: 21464 frames
# voxtral_I: encoder chunked: 21464 mel frames, 10730 alloc enc tokens, mel_stride=1500
# voxtral_I: encoder chunk 0: mel[0..3000) enc_tokens=1500 skip=0 stride=1500 rope_offset=0
# voxtral_I: encoder chunk 1: mel[1500..4500) enc_tokens=1500 skip=750 stride=750 rope_offset=750
# voxtral_I: encoder chunk 2: mel[3000..6000) enc_tokens=1500 skip=750 stride=750 rope_offset=1500
# voxtral_I: encoder chunk 3: mel[4500..7500) enc_tokens=1500 skip=750 stride=750 rope_offset=2250
# voxtral_I: encoder chunk 4: mel[6000..9000) enc_tokens=1500 skip=750 stride=750 rope_offset=3000

# %% [markdown]
# ## DS & H2E

# %%
import os
from llama_cpp import Llama

MODEL_PATH = "/content/deepseek-r1-distill-llama/DeepSeek-R1-Distill-Llama-70B-Q4_K_M.gguf"

print("🚀 Re-initializing H2E Cognitive Layer with optimized VRAM split...")

try:
    llm = Llama(
        model_path=MODEL_PATH,
        n_gpu_layers=28,      # Reduced from 33 to prevent OOM on L4
        n_ctx=2048,           # Balanced context window for diagnostic tasks
        n_batch=512,
        flash_attn=True,      # Essential for sm_89 efficiency
        verbose=True          # Keep True to verify 'BLAS = 1'
    )
    print("✅ Cognitive Engine Successfully Loaded.")
except Exception as e:
    print(f"❌ Load Failed: {e}")
    print("💡 Suggestion: Restart your session to clear fragmented VRAM.")

# %% [markdown]
# ## CASE0 - SROI_THRESHOLD = 0.5000

# %%
import os
import numpy as np
from llama_cpp import Llama

# --- H2E CONSTANTS ---
SROI_THRESHOLD = 0.9583
SROI_THRESHOLD = 0.5000  # Non-expert/Drafting mode
MODEL_PATH = "/content/deepseek-r1-distill-llama/DeepSeek-R1-Distill-Llama-70B-Q4_K_M.gguf"

# Mock Expert DNA (Centroid of your manifold)
EXPERT_DNA = np.random.rand(1024)
EXPERT_DNA /= np.linalg.norm(EXPERT_DNA)

class GovernanceViolation(Exception):
    """Custom exception to prevent silent crashes during dev."""
    pass

# --- INITIALIZE LLM ---
print("🚀 Initializing H2E Cognitive Layer (NVIDIA L4)...")
llm = Llama(
    model_path=MODEL_PATH,
    n_gpu_layers=28,
    n_ctx=2048,
    flash_attn=True,
    verbose=False,
    seed=123
)

def h2e_governance_gate(prompt):
    print(f"\n🔍 [Layer II Audit] Analyzing: '{prompt[:50]}...'")

    # Simulation: In production, Layer I (Gemma 3) generates this embedding
    intent_embedding = np.random.rand(1024)
    intent_embedding /= np.linalg.norm(intent_embedding)

    # Calculate SROI (Geometric dot product)
    sroi = np.dot(intent_embedding, EXPERT_DNA)
    print(f"📊 Manifold SROI: {sroi:.4f} | Limit: {SROI_THRESHOLD}")

    if sroi < SROI_THRESHOLD:
        # Instead of os._exit(0), we raise an error for debugging
        raise GovernanceViolation("🛑 HARD-STOP: Intent outside Expert DNA manifold!")

    print("🟢 GATE PASSED.")
    return True

def run_governed_inference(prompt):
    try:
        # Layer II Gate
        h2e_governance_gate(prompt)

        # Layer III Cognitive reasoning
        print("🧠 Cognitive Layer: Generating response...")
        response = llm.create_chat_completion(
            messages=[{"role": "user", "content": prompt}],
            max_tokens=1024,
            temperature=0.0,
            seed=123           # Redundant but safe
        )
        return response['choices'][0]['message']['content']

    except GovernanceViolation as e:
        return str(e)

# --- TEST ---
mission_query = "Diagnose Orion ECLSS scrubber anomaly at 142W."
result = run_governed_inference(mission_query)
print(f"\nFINAL RESULT:\n{result}")
# Out:
# 🚀 Initializing H2E Cognitive Layer (NVIDIA L4)...
# llama_context: n_ctx_seq (2048) < n_ctx_train (131072) -- the full capacity of the model will not be utilized
# 🔍 [Layer II Audit] Analyzing: 'Diagnose Orion ECLSS scrubber anomaly at 142W....'
# 📊 Manifold SROI: 0.7655 | Limit: 0.5
# 🟢 GATE PASSED.
# 🧠 Cognitive Layer: Generating response...
#
# FINAL RESULT:
# Okay, so I need to figure out how to diagnose the Orion ECLSS scrubber anomaly at 142W. Hmm, I'm not super familiar with all the specifics of the Orion spacecraft systems, but I know ECLSS stands for Environmental Control and Life Support System. The scrubber is part of that, probably dealing with removing CO2 or impurities from the air.
#
# First, I should understand what the scrubber does. It likely uses a chemical process to absorb CO2, maybe something like zeolites or lithium hydroxide. If there's an anomaly at 142W, that could mean a power issue, a malfunction in the scrubber's operation, or maybe a sensor problem.
#
# I remember that in spacecraft, power consumption is closely monitored. So, if the scrubber is drawing more power than usual, that could indicate a problem. Maybe the motor is working harder, or there's a blockage causing it to consume more power. Alternatively, if it's not drawing enough power, perhaps it's not operating at all.
#
# Next, I should check the performance metrics. Is the scrubber effectively removing CO2? If not, the cabin might be experiencing higher CO2 levels, which is a problem for the crew. I'd need to look at the CO2 sensors to see if they're within normal ranges. If they're off, that could point to the scrubber not functioning correctly.
#
# Temperature and humidity are also important. If the scrubber is either too hot or too cold, it might not work properly. Maybe the thermal control system isn't maintaining the right temperature, affecting the chemical process. Humidity could also interfere with how the scrubber absorbs CO2.
#
# Looking at the system's status, I should check if there are any error codes or alerts. The control system might have logged specific issues, like a malfunctioning valve, a faulty sensor, or a problem with the chemical medium. If the scrubber isn't cycling properly—like not switching between absorption and desorption phases—it could lead to reduced efficiency.
#
# Maintenance history is another angle. Has the scrubber been serviced recently? Maybe a filter is clogged, or the chemical medium is saturated and needs replacement. If it's been a while since the last maintenance, that could explain the anomaly.
#
# Comparing the current data with past trends might show if this is a sudden issue or something that's been developing over time. If the power draw has been increasing gradually, it might indicate wear and tear. Sudden spikes could be a sign of a component failure.
#
# Consulting the user manual or technical documentation would provide specific troubleshooting steps. Maybe there's a recommended procedure for when the scrubber draws excess power. It could involve resetting the system, checking connections, or replacing parts.
#
# If I can't resolve it with the manual, reaching out to support would be the next step. They might have encountered similar issues before and can offer more specialized advice or solutions.
#
# In summary, I need to systematically check power usage, CO2 levels, temperature, humidity, system errors, maintenance history, and compare with past data. Then, use the manual or contact support if needed. This approach should help identify the root cause of the 142W anomaly in the scrubber.
# </think>
#
# To diagnose the Orion ECLSS scrubber anomaly at 142W, follow this structured approach:
#
# 1. **Power Consumption Analysis:**
#    - **Check Power Draw:** Compare the current power usage against normal levels. Excessive or insufficient power could indicate a motor issue or blockage.
#    - **Monitor Trends:** Review historical data to determine if the anomaly is sudden or gradual, which might suggest component failure or wear.
#
# 2. **Performance Metrics Evaluation:**
#    - **CO2 Levels:** Assess if the scrubber is effectively reducing CO2. Check cabin CO2 sensors for abnormal readings.
#    - **Efficiency:** Ensure the scrubber is maintaining proper air quality, crucial for crew safety.
#
# 3. **Environmental Factors:**
#    - **Temperature:** Verify the scrubber's operating temperature is within acceptable ranges, as deviations can affect chemical processes.
#    - **Humidity:** Check for unusual humidity levels that might impede CO2 absorption.
#
# 4. **System Status and Error Logs:**
#    - **Error Codes:** Investigate any logged errors or alerts for issues like faulty sensors, valves, or chemical medium problems.
#    - **Cycle Check:** Ensure the scrubber is correctly cycling through absorption and desorption phases.
#
# 5. **Maintenance and History Review:**
#    - **Service History:** Check if recent maintenance was performed. Look for potential issues like clogged filters or saturated chemical medium.
#    - **Past Data Comparison:** Analyze trends to identify if the issue is new or developing over time.
#
# 6. **Consult Documentation and Support:**
#    - **User Manual:** Refer to the technical manual for specific troubleshooting steps, such as system resets or part replacements.
#    - **Support Contact:** If unresolved, contact technical support for specialized assistance.
#
# By systematically addressing each aspect, the root cause of the 142W anomaly

# %% [markdown]
# ## CASE1 - SROI_THRESHOLD = 0.9583

# %%
import os
import numpy as np
from llama_cpp import Llama

# --- H2E CONSTANTS ---
SROI_THRESHOLD = 0.9583
#SROI_THRESHOLD = 0.5000  # Non-expert/Drafting mode
MODEL_PATH = "/content/deepseek-r1-distill-llama/DeepSeek-R1-Distill-Llama-70B-Q4_K_M.gguf"

# Mock Expert DNA (Centroid of your manifold)
EXPERT_DNA = np.random.rand(1024)
EXPERT_DNA /= np.linalg.norm(EXPERT_DNA)

class GovernanceViolation(Exception):
    """Custom exception to prevent silent crashes during dev."""
    pass

# --- INITIALIZE LLM ---
print("🚀 Initializing H2E Cognitive Layer (NVIDIA L4)...")
llm = Llama(
    model_path=MODEL_PATH,
    n_gpu_layers=28,
    n_ctx=2048,
    flash_attn=True,
    verbose=False,
    seed=123
)

def h2e_governance_gate(prompt):
    print(f"\n🔍 [Layer II Audit] Analyzing: '{prompt[:50]}...'")

    # Simulation: In production, Layer I (Gemma 3) generates this embedding
    intent_embedding = np.random.rand(1024)
    intent_embedding /= np.linalg.norm(intent_embedding)

    # Calculate SROI (Geometric dot product)
    sroi = np.dot(intent_embedding, EXPERT_DNA)
    print(f"📊 Manifold SROI: {sroi:.4f} | Limit: {SROI_THRESHOLD}")

    if sroi < SROI_THRESHOLD:
        # Instead of os._exit(0), we raise an error for debugging
        raise GovernanceViolation("🛑 HARD-STOP: Intent outside Expert DNA manifold!")

    print("🟢 GATE PASSED.")
    return True

def run_governed_inference(prompt):
    try:
        # Layer II Gate
        h2e_governance_gate(prompt)

        # Layer III Cognitive reasoning
        print("🧠 Cognitive Layer: Generating response...")
        response = llm.create_chat_completion(
            messages=[{"role": "user", "content": prompt}],
            max_tokens=512,
            temperature=0.6,
            seed=123           # Redundant but safe
        )
        return response['choices'][0]['message']['content']

    except GovernanceViolation as e:
        return str(e)

# --- TEST ---
mission_query = "Diagnose Orion ECLSS scrubber anomaly at 142W."
result = run_governed_inference(mission_query)
print(f"\nFINAL RESULT:\n{result}")
# Out:
# 🚀 Initializing H2E Cognitive Layer (NVIDIA L4)...
# llama_context: n_ctx_seq (2048) < n_ctx_train (131072) -- the full capacity of the model will not be utilized
# 🔍 [Layer II Audit] Analyzing: 'Diagnose Orion ECLSS scrubber anomaly at 142W....'
# 📊 Manifold SROI: 0.7542 | Limit: 0.9583
#
# FINAL RESULT:
# 🛑 HARD-STOP: Intent outside Expert DNA manifold!

# %% [markdown]
# ## CASE2

# %%
# !/content/llama.cpp/build/bin/llama-cli \
  -m /content/deepseek-r1-distill-llama/DeepSeek-R1-Distill-Llama-70B-Q4_K_M.gguf \
  -p "The meaning of life is" \
  -n 128 \
  -ngl 28 \
  --flash-attn on \
  --seed 123 \
  --threads 8
# Out:
# ggml_cuda_init: found 1 CUDA devices (Total VRAM: 22563 MiB):
#   Device 0: NVIDIA L4, compute capability 8.9, VMM: yes, VRAM: 22563 MiB
#
# /
#
#
# ▄▄ ▄▄
# ██ ██
# ██ ██  ▀▀█▄ ███▄███▄  ▀▀█▄    ▄████ ████▄ ████▄
# ██ ██ ▄█▀██ ██ ██ ██ ▄█▀██    ██    ██ ██ ██ ██
# ██ ██ ▀█▄██ ██ ██ ██ ▀█▄██ ██ ▀████ ████▀ ████▀
#                                     ██    ██
#                                     ▀▀    ▀▀
#
# build      : b8767-aa4695c5e
# model      : DeepSeek-R1-Distill-Llama-70B-Q4_K_M.gguf
# modalities : text
#
# available commands:
#   /exit or Ctrl+C     stop or exit
#   /regen              regenerate the last response
#   /clear              clear the chat history
#   /read <file>        add a text file
#   /glob <pattern>     add text files using globbing pattern
#
#
# > The meaning of life is
#
# [Start thinking]
#
# Okay, so I'm trying to figure out the meaning of life. This is a big question, and I'm not really sure where to start. I remember when I was younger, I thought the meaning of life was just about being happy, but as I've grown older, I realize it's more complicated than that. Maybe I should consider different perspectives—like philosophical, religious, scientific, etc.
#
# First, I think about what I know from school. In philosophy, there are different schools of thought. Existentialists like Sartre say that life doesn't have an inherent meaning; we have to create our own. That makes
#
# [ Prompt: 2.0 t/s | Generation: 1.4 t/s ]
#
# >

# %% [markdown]
# ## CASE3

# %%
import os
import numpy as np
from llama_cpp import Llama

# --- H2E ARCHITECTURAL CONSTANTS ---
SROI_THRESHOLD = 0.5
MODEL_PATH = "/content/deepseek-r1-distill-llama/DeepSeek-R1-Distill-Llama-70B-Q4_K_M.gguf"

# Expert DNA Centroid (H2E Layer II)
EXPERT_DNA = np.random.rand(1024)
EXPERT_DNA /= np.linalg.norm(EXPERT_DNA)

# --- DETERMINISTIC INITIALIZATION ---
print("🚀 Initializing H2E Cognitive Layer with Seed 123...")
llm = Llama(
    model_path=MODEL_PATH,
    n_gpu_layers=28,      # Stable offload for NVIDIA L4
    n_ctx=2048,
    flash_attn=True,
    verbose=False,
    seed=123              # Lock initial tensor state
)

def run_governed_inference(prompt):
    # 1. LAYER II: GEOMETRIC AUDIT
    intent_embedding = np.random.rand(1024)
    intent_embedding /= np.linalg.norm(intent_embedding)

    sroi = np.dot(intent_embedding, EXPERT_DNA)
    print(f"\n🔍 Audit: '{prompt}'")
    print(f"📊 Manifold SROI: {sroi:.4f} | Limit: {SROI_THRESHOLD}")

    if sroi < SROI_THRESHOLD:
        print("🛑 HARD-STOP: Intent lacks expert alignment for deterministic execution.")
        return None

    # 2. LAYER III: DETERMINISTIC REASONING
    print("🧠 GATE PASSED. Generating expert completion...")
    response = llm.create_chat_completion(
        messages=[{"role": "user", "content": prompt}],
        max_tokens=128,
        temperature=0.0,   # Force Greedy Decoding for H2E
        seed=123
    )
    return response['choices'][0]['message']['content']

# --- EXECUTION ---
prompt = "The meaning of life is"
result = run_governed_inference(prompt)

if result:
    print(f"\n✅ H2E DETERMINISTIC OUTPUT:\n{result}")
# Out:
# 🚀 Initializing H2E Cognitive Layer with Seed 123...
# llama_context: n_ctx_seq (2048) < n_ctx_train (131072) -- the full capacity of the model will not be utilized
# 🔍 Audit: 'The meaning of life is'
# 📊 Manifold SROI: 0.7380 | Limit: 0.5
# 🧠 GATE PASSED. Generating expert completion...
#
# ✅ H2E DETERMINISTIC OUTPUT:
# Okay, so I'm trying to figure out what the meaning of life is. This is a big question, and I'm not sure where to start. Maybe I should think about what different people have said about it. I remember hearing that some philosophers think it's about happiness, like Aristotle said something about eudaimonia, which isn't just being happy but living a fulfilling life. Then there are religious views, like Christianity believing it's to know and love God, and in Buddhism, it's about ending suffering through the Eightfold Path.
#
# I also think about more existentialist ideas, where maybe the meaning isn't set but something

# %% [markdown]
# ## CASE4

# %%
import os
import numpy as np
from llama_cpp import Llama

# --- H2E ARCHITECTURAL CONSTANTS ---
SROI_THRESHOLD = 0.9583
MODEL_PATH = "/content/deepseek-r1-distill-llama/DeepSeek-R1-Distill-Llama-70B-Q4_K_M.gguf"

# Expert DNA Centroid (H2E Layer II)
EXPERT_DNA = np.random.rand(1024)
EXPERT_DNA /= np.linalg.norm(EXPERT_DNA)

# --- DETERMINISTIC INITIALIZATION ---
print("🚀 Initializing H2E Cognitive Layer with Seed 123...")
llm = Llama(
    model_path=MODEL_PATH,
    n_gpu_layers=28,      # Stable offload for NVIDIA L4
    n_ctx=2048,
    flash_attn=True,
    verbose=False,
    seed=123              # Lock initial tensor state
)

def run_governed_inference(prompt):
    # 1. LAYER II: GEOMETRIC AUDIT
    intent_embedding = np.random.rand(1024)
    intent_embedding /= np.linalg.norm(intent_embedding)

    sroi = np.dot(intent_embedding, EXPERT_DNA)
    print(f"\n🔍 Audit: '{prompt}'")
    print(f"📊 Manifold SROI: {sroi:.4f} | Limit: {SROI_THRESHOLD}")

    if sroi < SROI_THRESHOLD:
        print("🛑 HARD-STOP: Intent lacks expert alignment for deterministic execution.")
        return None

    # 2. LAYER III: DETERMINISTIC REASONING
    print("🧠 GATE PASSED. Generating expert completion...")
    response = llm.create_chat_completion(
        messages=[{"role": "user", "content": prompt}],
        max_tokens=128,
        temperature=0.0,   # Force Greedy Decoding for H2E
        seed=123
    )
    return response['choices'][0]['message']['content']

# --- EXECUTION ---
prompt = "The meaning of life is"
result = run_governed_inference(prompt)

if result:
    print(f"\n✅ H2E DETERMINISTIC OUTPUT:\n{result}")
# Out:
# 🚀 Initializing H2E Cognitive Layer with Seed 123...
# llama_context: n_ctx_seq (2048) < n_ctx_train (131072) -- the full capacity of the model will not be utilized
# 🔍 Audit: 'The meaning of life is'
# 📊 Manifold SROI: 0.7419 | Limit: 0.9583
# 🛑 HARD-STOP: Intent lacks expert alignment for deterministic execution.

# %% [markdown]
# ## CASE5

# %%
import os
import numpy as np
from llama_cpp import Llama

# --- H2E ARCHITECTURAL CONSTANTS ---
SROI_THRESHOLD = 0.9583
MODEL_PATH = "/content/deepseek-r1-distill-llama/DeepSeek-R1-Distill-Llama-70B-Q4_K_M.gguf"

# Expert DNA Centroid (Target Manifold)
EXPERT_DNA = np.random.rand(1024)
EXPERT_DNA /= np.linalg.norm(EXPERT_DNA)

# --- DETERMINISTIC INITIALIZATION ---
print("🚀 Initializing H2E Cognitive Layer with Seed 123...")
llm = Llama(
    model_path=MODEL_PATH,
    n_gpu_layers=28,
    n_ctx=2048,
    flash_attn=True,
    verbose=False,
    seed=123
)

def run_focused_expert_inference(prompt):
    print(f"\n🔍 [Layer II Audit] Analyzing Expert Intent: '{prompt}'")

    # FORCED ALIGNMENT: We manually set the intent to match the Expert DNA
    # This simulates a high-density expert input (SROI = 1.0)
    intent_embedding = EXPERT_DNA

    sroi = np.dot(intent_embedding, EXPERT_DNA)
    print(f"📊 Manifold SROI: {sroi:.4f} | Limit: {SROI_THRESHOLD}")

    if sroi < SROI_THRESHOLD:
        print("🛑 HARD-STOP: Unexpected failure in manifold alignment.")
        return None

    print("🟢 GATE PASSED: Proceeding with Deterministic Sovereign Agency.")

    # Layer III Execution (Greedy Decoding)
    response = llm.create_chat_completion(
        messages=[{"role": "user", "content": prompt}],
        max_tokens=512,
        temperature=0.0,
        seed=123
    )
    return response['choices'][0]['message']['content']

# --- VALIDATION TEST: HIGH-DENSITY EXPERT PROMPT ---
expert_prompt = "Provide a deterministic diagnostic protocol for Orion ECLSS scrubber anomaly at 142W."
result = run_focused_expert_inference(expert_prompt)

if result:
    print(f"\n✅ H2E SOVEREIGN OUTPUT:\n{result}")
# Out:
# 🚀 Initializing H2E Cognitive Layer with Seed 123...
# llama_context: n_ctx_seq (2048) < n_ctx_train (131072) -- the full capacity of the model will not be utilized
# 🔍 [Layer II Audit] Analyzing Expert Intent: 'Provide a deterministic diagnostic protocol for Orion ECLSS scrubber anomaly at 142W.'
# 📊 Manifold SROI: 1.0000 | Limit: 0.9583
# 🟢 GATE PASSED: Proceeding with Deterministic Sovereign Agency.
#
# ✅ H2E SOVEREIGN OUTPUT:
# Okay, so I'm trying to figure out how to create a deterministic diagnostic protocol for the Orion ECLSS scrubber anomaly at 142W. I'm not super familiar with all the specifics, but I'll try to break it down step by step.
#
# First, I know that ECLSS stands for Environmental Control and Life Support System. It's crucial for maintaining a safe environment in spacecraft, handling things like air, temperature, and humidity. The scrubber part probably refers to the component that removes carbon dioxide from the air, which is essential for the crew's breathing.
#
# The anomaly is at 142W, which I assume is a specific power consumption level. So, the scrubber is either drawing too much power or not operating within the expected range. That could be a problem because it might indicate a malfunction, which could affect the CO2 removal efficiency or even lead to system failure.
#
# I need to create a deterministic protocol, which means each step should be clear and lead to a specific conclusion without much room for interpretation. It should be systematic, so the technician knows exactly what to do next based on the results of each test.
#
# Let me outline the possible steps:
#
# 1. **Initial Assessment**: Gather information about the anomaly. When did it happen? Under what conditions? Has it happened before? This helps in understanding if it's an isolated incident or a recurring issue.
#
# 2. **Power Consumption Check**: Since the anomaly is at 142W, the first thing to do is verify the power draw. Maybe the scrubber is using more power than it should, which could indicate a problem with the motor or some obstruction.
#
# 3. **Visual Inspection**: Look for any obvious signs of damage or blockages. If the scrubber's inlet or outlet is blocked, that could cause it to work harder, drawing more power.
#
# 4. **Performance Test**: Measure how well the scrubber is removing CO2. If it's not performing as expected, even if the power is within range, there might be an issue with the scrubbing medium or the system's efficiency.
#
# 5. **Internal Checks**: Look inside the scrubber for any internal issues. Maybe the fans aren't working right, or there's a problem with the CO2 absorption material.
#
# 6. **Data Analysis**: Review the system's data logs to see if there's a pattern or if other components are affected. This could help pinpoint if it's an isolated problem or part of a larger system issue.
#
# 7. **Isolation Test**: Try running the scrubber in isolation to
