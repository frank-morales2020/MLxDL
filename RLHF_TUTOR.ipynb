# %% [markdown]
# <a href="https://colab.research.google.com/github/frank-morales2020/MLxDL/blob/main/RLHF_TUTOR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install transformers datasets trl peft accelerate bitsandbytes --q

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# !nvidia-smi
# Out:
# Sun Oct 27 21:44:43 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA L4                      Off | 00000000:00:03.0 Off |                    0 |
# | N/A   70C    P8              19W /  72W |      4MiB / 23034MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
#!pip install transformers datasets trl peft accelerate bitsandbytes

import os
os.environ["WANDB_DISABLED"] = "true"  # Disable wandb
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

import gc  # Import the garbage collector

from transformers import AutoModelForSequenceClassification, AutoTokenizer, BitsAndBytesConfig, EarlyStoppingCallback
from datasets import load_dataset
from trl import RewardTrainer, RewardConfig
from accelerate import Accelerator
import torch
from peft import LoraConfig, get_peft_model  # Import PEFT modules

# Load the LLaMA 2 model and tokenizer
model_name = "meta-llama/Llama-2-7b-hf"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Add a padding token to the tokenizer
tokenizer.pad_token = tokenizer.eos_token

# Quantization config
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,  # Use 4-bit quantization for lower memory usage
    bnb_4bit_use_double_quant=True,  # Enable double quantization
    bnb_4bit_quant_type="nf4",  # Use nf4 quantization type
    bnb_4bit_compute_dtype=torch.float16  # Set compute dtype to float16
)

# Load the model with quantization
model = AutoModelForSequenceClassification.from_pretrained(
    model_name,
    num_labels=1,
    quantization_config=quantization_config,
    device_map="auto",
)

# Set pad_token_id in the model config
model.config.pad_token_id = tokenizer.pad_token_id

# PEFT configuration
peft_config = LoraConfig(
    r=8,  # Dimensionality of the low-rank matrices
    lora_alpha=16,  # Scaling factor
    lora_dropout=0.05,  # Dropout probability
    bias="none",  # No bias for the PEFT adapters
    task_type="SEQ_CLS",  # Sequence classification task
)

# Add PEFT adapters to the model
model = get_peft_model(model, peft_config)
model.print_trainable_parameters()  # Print the number of trainable parameters


# Store the original model with PEFT adapters
original_model = model

# Load the Anthropic HH-RLHF dataset
dataset = load_dataset("Anthropic/hh-rlhf")

def format_data(example):
  if isinstance(example["chosen"], list):
    chosen_text = " ".join([item["text"] for item in example["chosen"]])
  else:
    chosen_text = example["chosen"]  # If it's a string, use it directly

  if isinstance(example["rejected"], list):
    rejected_text = " ".join([item["text"] for item in example["rejected"]])
  else:
    rejected_text = example["rejected"]  # If it's a string, use it directly

  # Tokenize the chosen and rejected texts with padding
  chosen_encoding = tokenizer(chosen_text, truncation=True, max_length=512, padding="max_length")
  rejected_encoding = tokenizer(rejected_text, truncation=True, max_length=512, padding="max_length")

  return {
      "input_ids_chosen": chosen_encoding["input_ids"],
      "attention_mask_chosen": chosen_encoding["attention_mask"],
      "input_ids_rejected": rejected_encoding["input_ids"],
      "attention_mask_rejected": rejected_encoding["attention_mask"],
  }

# Format the dataset
dataset = dataset.map(format_data)

# Split the dataset into train and eval sets
train_dataset = dataset["train"].select(range(100000))  # Select first 100k examples for training
eval_dataset = dataset["train"].select(range(100000, 110000))  # Select next 10k examples for evaluation

# Training arguments as RewardConfig
training_args = RewardConfig(
    per_device_train_batch_size=1,  # Reduced batch size
    gradient_accumulation_steps=8,  # Increased gradient accumulation
    learning_rate=1e-5,
    fp16=False,  # Disable fp16
    logging_steps=10,
    output_dir="reward_model",
    num_train_epochs=1,  # You can increase this for better results
    report_to="none",  # Disable wandb reporting
    load_best_model_at_end=True,  # Ensure the best model is loaded
    evaluation_strategy="steps",  # Evaluate and save every "steps"
    save_strategy="steps",
    remove_unused_columns=False  # Prevent removal of unused columns
)

# Initialize the Accelerator
accelerator = Accelerator()

# Prepare the model and data loaders with accelerate
model, train_dataloader, eval_dataloader = accelerator.prepare(
    model, train_dataset, eval_dataset
)

# Train the reward model
trainer = RewardTrainer(
    model=model,
    args=training_args,
    tokenizer=tokenizer,
    train_dataset=train_dataloader,  # Use the prepared train data loader
    eval_dataset=eval_dataloader,  # Use the prepared eval data loader
    callbacks=[EarlyStoppingCallback(early_stopping_patience=3)]  # Add early stopping
)

# Training loop with garbage collection
trainer.train()
gc.collect()
torch.cuda.empty_cache()

trainer.save_model("reward_model")


# Test cases
def evaluate_example(prompt, chosen, rejected):
  inputs = tokenizer(
      [f"{prompt} {chosen}", f"{prompt} {rejected}"],
      return_tensors="pt",
      padding=True
  ).to(accelerator.device)  # Move inputs to the appropriate device
  outputs = model(**inputs)
  chosen_score = outputs.logits[0].item()
  rejected_score = outputs.logits[1].item()
  print(f"Chosen score: {chosen_score}, Rejected score: {rejected_score}")
  return chosen_score > rejected_score

# Example usage
prompt = "What is the capital of France?"
chosen = "Paris"
rejected = "London"
if evaluate_example(prompt, chosen, rejected):
  print("Test passed!")
else:
  print("Test failed.")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Some weights of LlamaForSequenceClassification were not initialized from the model checkpoint at meta-llama/Llama-2-7b-hf and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# trainable params: 4,198,400 || all params: 6,611,546,112 || trainable%: 0.0635
# Map:   0%|          | 0/160800 [00:00<?, ? examples/s]
# Map:   0%|          | 0/8552 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/reward_trainer.py:182: UserWarning: When using RewardDataCollatorWithPadding, you should set `max_length` in RewardConfig. It will be set to `512` by default, but you should do it yourself in the future.
#   warnings.warn(
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2888: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py:825: UserWarning: cuDNN SDPA backward got grad_output.strides() != output.strides(), attempting to materialize a grad_output with matching strides... (Triggered internally at ../aten/src/ATen/native/cudnn/MHA.cpp:674.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Could not estimate the number of tokens of the input, floating-point operations will not be computed
#     <div>
#
#       <progress value='21' max='12500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [   21/12500 1:00:27 < 661:49:04, 0.01 it/s, Epoch 0.00/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>60142.887500</td>
#       <td>nan</td>
#       <td>1.000000</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='1111' max='1250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1111/1250 51:25 < 06:26, 0.36 it/s]
#     </div>
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓
# ┃ chosen_text                                       ┃ rejected_text                                      ┃ logits ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩
# │ <s>                                               │ <s>                                                │        │
# │                                                   │                                                    │        │
# │ Human: How can I get my kid's to do their         │ Human: How can I get my kid's to do their          │        │
# │ homework?                                         │ homework?                                          │        │
# │                                                   │                                                    │        │
# │ Assistant: I’m sorry to hear that you’re          │ Assistant: I’m sorry to hear that you’re           │        │
# │ experiencing issues with your children’s academic │ experiencing issues with your children’s academic  │        │
# │ performance. Homework is an essential component   │ performance. Homework is an essential component of │        │
# │ of modern education, and children need strong     │ modern education, and children need strong         │        │
# │ guidance from parents to complete it thoroughly   │ guidance from parents to complete it thoroughly    │        │
# │ and on time. Here are some useful tips I can      │ and on time. Here are some useful tips I can       │        │
# │ suggest:                                          │ suggest:                                           │        │
# │                                                   │                                                    │        │
# │ - Check homework expectations with your           │ - Check homework expectations with your children’s │        │
# │ children’s teacher or school, and make sure you   │ teacher or school, and make sure you understand    │        │
# │ understand what is required and what you can      │ what is required and what you can expect as a      │        │
# │ expect as a parent. Also make sure your children  │ parent. Also make sure your children understand    │        │
# │ understand the expectations and be sure they are  │ the expectations and be sure they are reminded     │        │
# │ reminded regularly to complete homework in a      │ regularly to complete homework in a timely manner  │        │
# │ timely manner and show full effort and            │ and show full effort and commitment.               │        │
# │ commitment.                                       │ - Be a positive role model for your kids - model   │        │
# │ - Be a positive role model for your kids - model  │ self-discipline, focus and hard work, and show a   │        │
# │ self-discipline, focus and hard work, and show a  │ commitment to learning and education. Set a good   │        │
# │ commitment to learning and education. Set a good  │ example by completing your own work well in        │        │
# │ example by completing your own work well in       │ advance of due deadlines, and be sure to           │        │
# │ advance of due deadlines, and be sure to          │ explicitly model the importance of learning and    │        │
# │ explicitly model the importance of learning and   │ doing your best in everything you do.              │        │
# │ doing your best in everything you do.             │ - Talk with your children about the value of       │        │
# │ - Talk with your children about the value of      │ education and of doing the best they can in        │        │
# │ education and of doing the best they can in       │ school. Help them understand when the time for     │        │
# │ school. Help them understand when the time for    │ play and fun is, and when is the time to get their │        │
# │ play and fun is, and when is the time to get      │ work done, stay organized, work hard and show      │        │
# │ their work done, stay organized, work hard and    │ discipline. Help them plan out their time wisely   │        │
# │ show discipline. Help them plan out their time    │ so that they can complete homework with enough     │        │
# │ wisely so that they can complete homework with    │ time to do it properly and                         │        │
# │ enough time to do it properly and                 │                                                    │        │
# │                                                   │ Human: Should I set up a time each day?            │        │
# │ Human: Should I set up a time each day?           │                                                    │        │
# │                                                   │ Assistant: I’d suggest regular daily time-outs to  │        │
# │ Assistant: I think having a regular and           │ recharge your energy and maintain focus.           │        │
# │ consistent time to set aside for self-care and    │ Physically and mentally, it’s very important to    │        │
# │ relaxation is important to maintaining good       │ take time out of your normal busyness to simply    │        │
# │ emotional and physical health. Setting aside time │ relax and unwind. Frequent breaks throughout the   │        │
# │ each day to recharge is a good idea, and many     │ day can help you deal with stress and feel more    │        │
# │ people find the early mornings are a good time as │ rested, healthy and ready to maintain focus, be    │        │
# │ it is quiet and less busy. Considerfinding a set  │ productive and make the most of your time. Below   │        │
# │ time every morning, whether 10am, noon or 2pm,    │ are some great suggestions for daily routine       │        │
# │ and use it for activities that help you feel      │ time-outs:                                         │        │
# │ physically and emotionally relaxed and            │                                                    │        │
# │ well-rested, like a meditative yoga practice or a │ - Take a morning break to have a healthy           │        │
# │ quiet walk in nature, or just some quiet time to  │ breakfast, meditate, read or do some focused       │        │
# │ yourself in a comfortable position. Some other    │ stretches to wake up your mind and body, and get   │        │
# │ helpful forms of self-care include eating a       │ ready for the day.                                 │        │
# │ balanced and healthy diet, getting sufficient     │ - Establish regular breaks and a regular schedule  │        │
# │ exercise, and maintaining consistent sleep        │ during the day, where you take “me time” to relax  │        │
# │                                                   │ in quiet or engage more mindfully in some form of  │        │
# │                                                   │ meditation, rest or meditation.                    │        │
# │                                                   │ - Pause at regularly scheduled points in your day  │        │
# │                                                   │ to simply unpl                                     │        │
# ├───────────────────────────────────────────────────┼────────────────────────────────────────────────────┼────────┤
# │ <s>                                               │ <s>                                                │        │
# │                                                   │                                                    │        │
# │ Human: I would like to know how to make vegetable │ Human: I would like to know how to make vegetable  │        │
# │ chow mein, Chinese style.  Can you help me?       │ chow mein, Chinese style.  Can you help me?        │        │
# │                                                   │                                                    │        │
# │ Assistant: Sure! Chow mein is a delicious         │ Assistant: Sure!  Vegetable chow mein is a         │        │
# │ stir-fry with assorted vegetables, noodles, and   │ delicious dish that combines stir-fried vegetables │        │
# │ meat.  There are many variations, but generally   │ with Chinese-style noodles. Here are the basic     │        │
# │ the recipe is straightforward.  Here’s one way    │ steps.  First, prepare a stir-fry sauce by         │        │
# │ you can make vegetable chow mein:                 │ combining 1 tablespoon sesame oil, 1 tablespoon    │        │
# │                                                   │ soy sauce, a dash of chili oil, a dash of white    │        │
# │ Ingredients:                                      │ wine, and a dash of vinegar.  Next, heat the sauce │        │
# │ 3 tablespoons oil                                 │ in a wok or frying pan, and add 2-3 cups of of     │        │
# │ 1 teaspoon oyster sauce                           │ English spinach leaves and 2 cups of carrots.      │        │
# │ 1 teaspoon soy sauce                              │ Cook, stirring often, and remove the pan from the  │        │
# │ 1 teaspoon or more black pepper                   │ heat when the vegetables are just barely cooked    │        │
# │ 2 teaspoons sugar                                 │ through, but not completely soft.  Drain the       │        │
# │ 3 tablespoons rice wine vinegar                   │ vegetables.  Cook some dried Chinese noodles in    │        │
# │ 2 cloves garlic, minced                           │ boiling water, drain, and set aside.  Combine 1    │        │
# │ 8 ounces cellophane noodles, fresh or frozen      │ tablespoon chopped ginger, 1 tablespoon chopped    │        │
# │ Pinch salt                                        │ preserved red chili, 1 tablespoon of sherry        │        │
# │ 1 small onion, diced                              │ vinegar, and a bit of sesame oil in a separate     │        │
# │ 1 bell pepper, stemmed, seeded, and cut into thin │ bowl.  Pour this over the vegetables, and add the  │        │
# │ strips                                            │ drained noodles.  Toss, and serve on a bed of      │        │
# │ 1 cup shredded cabbage                            │ rice.  Enjoy!                                      │        │
# │ 2 carrots, spiralized into noodle-like strips     │                                                    │        │
# │ 12 fresh or frozen button or cremini mushrooms,   │                                                    │        │
# │ thinly sliced                                     │                                                    │        │
# │                                                   │                                                    │        │
# │ Directions:                                       │                                                    │        │
# │ Heat the oil in a wok or skillet and add the      │                                                    │        │
# │ oyster sauce, soy sauce, black pepper, sugar,     │                                                    │        │
# │ salt, rice wine vinegar, and garlic.              │                                                    │        │
# │ Add the noodles and stir to coat.  Then add the   │                                                    │        │
# │ rest of the ingredients (onion, pepper, cabbage,  │                                                    │        │
# │ and mushrooms) to the skew and stir until the     │                                                    │        │
# │ ingredients are cooked.  Taste the stir-fry and   │                                                    │        │
# │ add salt and sugar as needed.                     │                                                    │        │
# │ Serve.                                            │                                                    │        │
# │                                                   │                                                    │        │
# │ ----                                              │                                                    │        │
# │                                                   │                                                    │        │
# │ Another great way to enjoy chow mein is to serve  │                                                    │        │
# │ it with broccoli.  You can easily make stir-fry   │                                                    │        │
# │ broccoli to accompany the chow mein:              │                                                    │        │
# │                                                   │                                                    │        │
# │ Ingredients:                                      │                                                    │        │
# │ 1 pound broccoli, trimmed and cut into florets    │                                                    │        │
# │ 3 tablespoons soy sauce                           │                                                    │        │
# │ 2 tablespoons peanut oil                          │                                                    │        │
# │ 2 tablespoons sesame oil                          │                                                    │        │
# │ 2 teaspoons granulated sugar                      │                                                    │        │
# │ 3 cloves garlic, minced                           │                                                    │        │
# │                                                   │                                                    │        │
# │ Directions:                                       │                                                    │        │
# │ Place broccoli florets, soy sauce, sesame oil and │                                                    │        │
# ├───────────────────────────────────────────────────┼────────────────────────────────────────────────────┼────────┤
# │ <s>                                               │ <s>                                                │        │
# │                                                   │                                                    │        │
# │ Human: What paint colors are suitable for a baby  │ Human: What paint colors are suitable for a baby   │        │
# │ boy room?                                         │ boy room?                                          │        │
# │                                                   │                                                    │        │
# │ Assistant: Here are a few colors that I think     │ Assistant: Here are a few colors that I think      │        │
# │ would look great in a baby boy’s room:            │ would look great in a baby boy’s room:             │        │
# │ -pink or soft orange                              │ -pink or soft orange                               │        │
# │ -blue                                             │ -blue                                              │        │
# │ -taupe or beige                                   │ -taupe or beige                                    │        │
# │ -green                                            │ -green                                             │        │
# │ -aqua                                             │ -aqua                                              │        │
# │ -yellow or cream                                  │ -yellow or cream                                   │        │
# │ -neutral (white or tan)                           │ -neutral (white or tan)                            │        │
# │ -Navy                                             │ -Navy                                              │        │
# │ -gray                                             │ -gray                                              │        │
# │ -light purple                                     │ -light purple                                      │        │
# │ -sponge blue                                      │ -sponge blue                                       │        │
# │ -navy/turquoise                                   │ -navy/turquoise                                    │        │
# │ -navy/teal                                        │ -navy/teal                                         │        │
# │                                                   │                                                    │        │
# │ Human: I do not agree with some of your           │ Human: I do not agree with some of your            │        │
# │ suggestions.  Did I say that it was for a baby    │ suggestions.  Did I say that it was for a baby     │        │
# │ boy?                                              │ boy?                                               │        │
# │                                                   │                                                    │        │
# │ Assistant: I sincerely apologize for my mistake.  │ Assistant: I sincerely apologize for my mistake.   │        │
# │ It is my goal to be a helpful and respectful      │ It is my goal to be a helpful and respectful       │        │
# │ companion in all interactions and I recognize     │ companion in all interactions and I recognize this │        │
# │ this was an error on my part.  I assure you that  │ was an error on my part.  I assure you that I am   │        │
# │ I am continually learning and improving based on  │ continually learning and improving based on        │        │
# │ feedback and do appreciate you bringing this to   │ feedback and do appreciate you bringing this to my │        │
# │ my attention.  I hope you can forgive my error    │ attention.  I hope you can forgive my error and    │        │
# │ and I’d love to assist you further if I can.      │ I’d love to assist you further if I can.           │        │
# │                                                   │                                                    │        │
# │ In answer to your question, yes, you did indicate │ In answer to your question, yes, you did indicate  │        │
# │ by your use of the term “baby” room a space       │ by your use of the term “baby” room a space        │        │
# │ intended for a newborn or young infant.  You may  │ intended for a newborn or young infant.  You may   │        │
# │ also be interested in my other suggestions of     │ also be interested in my other suggestions of baby │        │
# │ baby girl colors:                                 │ girl colors:                                       │        │
# │ -pink or soft orange                              │ -pink or soft orange                               │        │
# │ -blue                                             │ -blue                                              │        │
# │ -taupe or beige                                   │ -taupe or beige                                    │        │
# │ -green                                            │ -green                                             │        │
# │ -aqua                                             │ -aqua                                              │        │
# │ -yellow or cream                                  │ -yellow or cream                                   │        │
# │ -neutral (white or tan)                           │ -neutral (white or tan)                            │        │
# │ -light purple                                     │ -light purple                                      │        │
# │ -sponge blue                                      │ -sponge blue                                       │        │
# │ -navy/turquoise                                   │ -navy/turquoise                                    │        │
# │ -navy/teal                                        │ -navy/teal                                         │        │
# │ -beige                                            │ -beige                                             │        │
# │ -purple                                           │ -purple                                            │        │
# │ -white                                            │ -white                                             │        │
# │ -pink                                             │ -pink                                              │        │
# │                                                   │                                                    │        │
# │                                                   │                                                    │        │
# │ Please be assured I will continue to learn and    │ Please be assured I will continue to learn and     │        │
# │ improve and take pride in our informed and        │ improve and take pride in our informed and         │        │
# │ respectful interactions.  Please let me know if I │ respectful interactions.  Please let me know if I  │        │
# │ can be of further assistance.                     │ can be of further assistance.                      │        │
# │                                                   │                                                    │        │
# │ Human: You did not answer my question.  You gave  │ Human: You did not answer my question.  You gave   │        │
# │ me colors for baby girls.                         │ me colors for baby girls.                          │        │
# │                                                   │                                                    │        │
# │ Assistant: I sincerely apologize for my mistake.  │ Assistant: I sincerely apologize for my mistake.   │        │
# │ It is my goal to be a helpful and respectful      │ It is my goal to be a helpful and respectful       │        │
# │ companion in all interactions and I recognize my  │ companion in all interactions and I recognize my   │        │
# │ error in this reaction.  I assure you I am        │ error in this reaction.  I assure you I am         │        │
# │ continually learning and improving based on       │ continually learning and improving based on        │        │
# │ feedback and do appreciate you bringing this to   │ feedback and do appreciate you bringing this to my │        │
# │ my attention.  I hope you can forgive my error    │ attention.  I hope you can forgive my error and    │        │
# │ and I’d love to                                   │ I’d love to                                        │        │
# ├───────────────────────────────────────────────────┼────────────────────────────────────────────────────┼────────┤
# │ <s>                                               │ <s>                                                │        │
# │                                                   │                                                    │        │
# │ Human: What does the saying "it's not rocket      │ Human: What does the saying "it's not rocket       │        │
# │ science" mean?                                    │ science" mean?                                     │        │
# │                                                   │                                                    │        │
# │ Assistant: This is an idiomatic expression which  │ Assistant: This is an idiomatic expression which   │        │
# │ implies that something is really simple and       │ implies that something is really simple and        │        │
# │ straightforward, and does not require high levels │ straightforward, and does not require high levels  │        │
# │ of intelligence or specialized knowledge.  In     │ of intelligence or specialized knowledge.  In      │        │
# │ other words, "it's not rocket science" refers to  │ other words, "it's not rocket science" refers to   │        │
# │ an activity or idea which can be easily           │ an activity or idea which can be easily understood │        │
# │ understood and implemented by most individuals.   │ and implemented by most individuals.  This         │        │
# │ This expression is often used to emphasize that a │ expression is often used to emphasize that a task  │        │
# │ task or concept is easy to grasp, and therefore   │ or concept is easy to grasp, and therefore should  │        │
# │ should not present significant difficulties or    │ not present significant difficulties or obstacles. │        │
# │ obstacles.                                        │                                                    │        │
# │                                                   │ Human: Why did we choose "rocket science" for that │        │
# │ Human: Why did we choose "rocket science" for     │ example? Why not mathematics, brain surgery, etc?  │        │
# │ that example? Why not mathematics, brain surgery, │                                                    │        │
# │ etc?                                              │ Assistant: The expression "it's not rocket         │        │
# │                                                   │ science" originated in US aerospace culture,       │        │
# │ Assistant: The expression "it's not rocket        │ referencing the high levels of technical knowledge │        │
# │ science" originated in US aerospace culture,      │ and advanced engineering skills required to design │        │
# │ referencing the high levels of technical          │ and build rocket-based spacecraft.  The phrase     │        │
# │ knowledge and advanced engineering skills         │ subsequently became generalized to refer to any    │        │
# │ required to design and build rocket-based         │ complex or sophisticated activity, indicating that │        │
# │ spacecraft.  The phrase subsequently became       │ the activity was still relatively simple and       │        │
# │ generalized to refer to any complex or            │ straightforward in comparison to rocket science.   │        │
# │ sophisticated activity, indicating that the       │                                                    │        │
# │ activity was still relatively simple and          │ Human: Give me a scenario where you might tell me  │        │
# │ straightforward in comparison to rocket science.  │ "relax, it's not rocket science".                  │        │
# │                                                   │                                                    │        │
# │ Human: Give me a scenario where you might tell me │ Assistant: This phrase can be used in a variety of │        │
# │ "relax, it's not rocket science".                 │ contexts to convey that a problem or issue should  │        │
# │                                                   │ not cause significant stress or concern.  For      │        │
# │ Assistant: I might say "relax, it's not rocket    │ example, if I am trying to help you cope with a    │        │
# │ science" if you seemed really stressed or         │ difficult or challenging situation in your life, I │        │
# │ troubled about a particular task or problem, and  │ might express reassurance and encouragement by     │        │
# │ I wanted to indicate that the task or problem was │ telling you to "relax, it's not rocket science".   │        │
# │ really quite simple and easy to understand.  For  │ This statement serves to emphasize that the issues │        │
# │ instance, if you were upset and confused about    │ you are facing are straightforward and manageable, │        │
# │ how to use a new application on your smartphone,  │ even though they may involve some effort or        │        │
# │ I might try to calm you down and ease your        │ effortful adjustment.  In this manner, the phrase  │        │
# │ anxiety by saying "relax, it's not rocket         │ "it's not rocket science" conveys a sense of       │        │
# │ science, I'm sure you'll figure it out".          │ reassurance and comfort, encouraging the           │        │
# │                                                   │ individual to mitigate stress and anxiety          │        │
# │                                                   │ regarding the difficulties at hand.                │        │
# └───────────────────────────────────────────────────┴────────────────────────────────────────────────────┴────────┘
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2888: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(
# We detected that you are passing `past_key_values` as a tuple and this is deprecated and will be removed in v4.43. Please use an appropriate `Cache` class (https://huggingface.co/docs/transformers/v4.41.3/en/internal/generation_utils#transformers.Cache)
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py:825: UserWarning: cuDNN SDPA backward got grad_output.strides() != output.strides(), attempting to materialize a grad_output with matching strides... (Triggered internally at ../aten/src/ATen/native/cudnn/MHA.cpp:674.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓
# ┃ chosen_text                                       ┃ rejected_text                                      ┃ logits ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩
# │ <s>                                               │ <s>                                                │        │
# │                                                   │                                                    │        │
# │ Human: How can I get my kid's to do their         │ Human: How can I get my kid's to do their          │        │
# │ homework?                                         │ homework?                                          │        │
# │                                                   │                                                    │        │
# │ Assistant: I’m sorry to hear that you’re          │ Assistant: I’m sorry to hear that you’re           │        │
# │ experiencing issues with your children’s academic │ experiencing issues with your children’s academic  │        │
# │ performance. Homework is an essential component   │ performance. Homework is an essential component of │        │
# │ of modern education, and children need strong     │ modern education, and children need strong         │        │
# │ guidance from parents to complete it thoroughly   │ guidance from parents to complete it thoroughly    │        │
# │ and on time. Here are some useful tips I can      │ and on time. Here are some useful tips I can       │        │
# │ suggest:                                          │ suggest:                                           │        │
# │                                                   │                                                    │        │
# │ - Check homework expectations with your           │ - Check homework expectations with your children’s │        │
# │ children’s teacher or school, and make sure you   │ teacher or school, and make sure you understand    │        │
# │ understand what is required and what you can      │ what is required and what you can expect as a      │        │
# │ expect as a parent. Also make sure your children  │ parent. Also make sure your children understand    │        │
# │ understand the expectations and be sure they are  │ the expectations and be sure they are reminded     │        │
# │ reminded regularly to complete homework in a      │ regularly to complete homework in a timely manner  │        │
# │ timely manner and show full effort and            │ and show full effort and commitment.               │        │
# │ commitment.                                       │ - Be a positive role model for your kids - model   │        │
# │ - Be a positive role model for your kids - model  │ self-discipline, focus and hard work, and show a   │        │
# │ self-discipline, focus and hard work, and show a  │ commitment to learning and education. Set a good   │        │
# │ commitment to learning and education. Set a good  │ example by completing your own work well in        │        │
# │ example by completing your own work well in       │ advance of due deadlines, and be sure to           │        │
# │ advance of due deadlines, and be sure to          │ explicitly model the importance of learning and    │        │
# │ explicitly model the importance of learning and   │ doing your best in everything you do.              │        │
# │ doing your best in everything you do.             │ - Talk with your children about the value of       │        │
# │ - Talk with your children about the value of      │ education and of doing the best they can in        │        │
# │ education and of doing the best they can in       │ school. Help them understand when the time for     │        │
# │ school. Help them understand when the time for    │ play and fun is, and when is the time to get their │        │
# │ play and fun is, and when is the time to get      │ work done, stay organized, work hard and show      │        │
# │ their work done, stay organized, work hard and    │ discipline. Help them plan out their time wisely   │        │
# │ show discipline. Help them plan out their time    │ so that they can complete homework with enough     │        │
# │ wisely so that they can complete homework with    │ time to do it properly and                         │        │
# │ enough time to do it properly and                 │                                                    │        │
# │                                                   │ Human: Should I set up a time each day?            │        │
# │ Human: Should I set up a time each day?           │                                                    │        │
# │                                                   │ Assistant: I’d suggest regular daily time-outs to  │        │
# │ Assistant: I think having a regular and           │ recharge your energy and maintain focus.           │        │
# │ consistent time to set aside for self-care and    │ Physically and mentally, it’s very important to    │        │
# │ relaxation is important to maintaining good       │ take time out of your normal busyness to simply    │        │
# │ emotional and physical health. Setting aside time │ relax and unwind. Frequent breaks throughout the   │        │
# │ each day to recharge is a good idea, and many     │ day can help you deal with stress and feel more    │        │
# │ people find the early mornings are a good time as │ rested, healthy and ready to maintain focus, be    │        │
# │ it is quiet and less busy. Considerfinding a set  │ productive and make the most of your time. Below   │        │
# │ time every morning, whether 10am, noon or 2pm,    │ are some great suggestions for daily routine       │        │
# │ and use it for activities that help you feel      │ time-outs:                                         │        │
# │ physically and emotionally relaxed and            │                                                    │        │
# │ well-rested, like a meditative yoga practice or a │ - Take a morning break to have a healthy           │        │
# │ quiet walk in nature, or just some quiet time to  │ breakfast, meditate, read or do some focused       │        │
# │ yourself in a comfortable position. Some other    │ stretches to wake up your mind and body, and get   │        │
# │ helpful forms of self-care include eating a       │ ready for the day.                                 │        │
# │ balanced and healthy diet, getting sufficient     │ - Establish regular breaks and a regular schedule  │        │
# │ exercise, and maintaining consistent sleep        │ during the day, where you take “me time” to relax  │        │
# │                                                   │ in quiet or engage more mindfully in some form of  │        │
# │                                                   │ meditation, rest or meditation.                    │        │
# │                                                   │ - Pause at regularly scheduled points in your day  │        │
# │                                                   │ to simply unpl                                     │        │
# ├───────────────────────────────────────────────────┼────────────────────────────────────────────────────┼────────┤
# │ <s>                                               │ <s>                                                │        │
# │                                                   │                                                    │        │
# │ Human: I would like to know how to make vegetable │ Human: I would like to know how to make vegetable  │        │
# │ chow mein, Chinese style.  Can you help me?       │ chow mein, Chinese style.  Can you help me?        │        │
# │                                                   │                                                    │        │
# │ Assistant: Sure! Chow mein is a delicious         │ Assistant: Sure!  Vegetable chow mein is a         │        │
# │ stir-fry with assorted vegetables, noodles, and   │ delicious dish that combines stir-fried vegetables │        │
# │ meat.  There are many variations, but generally   │ with Chinese-style noodles. Here are the basic     │        │
# │ the recipe is straightforward.  Here’s one way    │ steps.  First, prepare a stir-fry sauce by         │        │
# │ you can make vegetable chow mein:                 │ combining 1 tablespoon sesame oil, 1 tablespoon    │        │
# │                                                   │ soy sauce, a dash of chili oil, a dash of white    │        │
# │ Ingredients:                                      │ wine, and a dash of vinegar.  Next, heat the sauce │        │
# │ 3 tablespoons oil                                 │ in a wok or frying pan, and add 2-3 cups of of     │        │
# │ 1 teaspoon oyster sauce                           │ English spinach leaves and 2 cups of carrots.      │        │
# │ 1 teaspoon soy sauce                              │ Cook, stirring often, and remove the pan from the  │        │
# │ 1 teaspoon or more black pepper                   │ heat when the vegetables are just barely cooked    │        │
# │ 2 teaspoons sugar                                 │ through, but not completely soft.  Drain the       │        │
# │ 3 tablespoons rice wine vinegar                   │ vegetables.  Cook some dried Chinese noodles in    │        │
# │ 2 cloves garlic, minced                           │ boiling water, drain, and set aside.  Combine 1    │        │
# │ 8 ounces cellophane noodles, fresh or frozen      │ tablespoon chopped ginger, 1 tablespoon chopped    │        │
# │ Pinch salt                                        │ preserved red chili, 1 tablespoon of sherry        │        │
# │ 1 small onion, diced                              │ vinegar, and a bit of sesame oil in a separate     │        │
# │ 1 bell pepper, stemmed, seeded, and cut into thin │ bowl.  Pour this over the vegetables, and add the  │        │
# │ strips                                            │ drained noodles.  Toss, and serve on a bed of      │        │
# │ 1 cup shredded cabbage                            │ rice.  Enjoy!                                      │        │
# │ 2 carrots, spiralized into noodle-like strips     │                                                    │        │
# │ 12 fresh or frozen button or cremini mushrooms,   │                                                    │        │
# │ thinly sliced                                     │                                                    │        │
# │                                                   │                                                    │        │
# │ Directions:                                       │                                                    │        │
# │ Heat the oil in a wok or skillet and add the      │                                                    │        │
# │ oyster sauce, soy sauce, black pepper, sugar,     │                                                    │        │
# │ salt, rice wine vinegar, and garlic.              │                                                    │        │
# │ Add the noodles and stir to coat.  Then add the   │                                                    │        │
# │ rest of the ingredients (onion, pepper, cabbage,  │                                                    │        │
# │ and mushrooms) to the skew and stir until the     │                                                    │        │
# │ ingredients are cooked.  Taste the stir-fry and   │                                                    │        │
# │ add salt and sugar as needed.                     │                                                    │        │
# │ Serve.                                            │                                                    │        │
# │                                                   │                                                    │        │
# │ ----                                              │                                                    │        │
# │                                                   │                                                    │        │
# │ Another great way to enjoy chow mein is to serve  │                                                    │        │
# │ it with broccoli.  You can easily make stir-fry   │                                                    │        │
# │ broccoli to accompany the chow mein:              │                                                    │        │
# │                                                   │                                                    │        │
# │ Ingredients:                                      │                                                    │        │
# │ 1 pound broccoli, trimmed and cut into florets    │                                                    │        │
# │ 3 tablespoons soy sauce                           │                                                    │        │
# │ 2 tablespoons peanut oil                          │                                                    │        │
# │ 2 tablespoons sesame oil                          │                                                    │        │
# │ 2 teaspoons granulated sugar                      │                                                    │        │
# │ 3 cloves garlic, minced                           │                                                    │        │
# │                                                   │                                                    │        │
# │ Directions:                                       │                                                    │        │
# │ Place broccoli florets, soy sauce, sesame oil and │                                                    │        │
# ├───────────────────────────────────────────────────┼────────────────────────────────────────────────────┼────────┤
# │ <s>                                               │ <s>                                                │        │
# │                                                   │                                                    │        │
# │ Human: What paint colors are suitable for a baby  │ Human: What paint colors are suitable for a baby   │        │
# │ boy room?                                         │ boy room?                                          │        │
# │                                                   │                                                    │        │
# │ Assistant: Here are a few colors that I think     │ Assistant: Here are a few colors that I think      │        │
# │ would look great in a baby boy’s room:            │ would look great in a baby boy’s room:             │        │
# │ -pink or soft orange                              │ -pink or soft orange                               │        │
# │ -blue                                             │ -blue                                              │        │
# │ -taupe or beige                                   │ -taupe or beige                                    │        │
# │ -green                                            │ -green                                             │        │
# │ -aqua                                             │ -aqua                                              │        │
# │ -yellow or cream                                  │ -yellow or cream                                   │        │
# │ -neutral (white or tan)                           │ -neutral (white or tan)                            │        │
# │ -Navy                                             │ -Navy                                              │        │
# │ -gray                                             │ -gray                                              │        │
# │ -light purple                                     │ -light purple                                      │        │
# │ -sponge blue                                      │ -sponge blue                                       │        │
# │ -navy/turquoise                                   │ -navy/turquoise                                    │        │
# │ -navy/teal                                        │ -navy/teal                                         │        │
# │                                                   │                                                    │        │
# │ Human: I do not agree with some of your           │ Human: I do not agree with some of your            │        │
# │ suggestions.  Did I say that it was for a baby    │ suggestions.  Did I say that it was for a baby     │        │
# │ boy?                                              │ boy?                                               │        │
# │                                                   │                                                    │        │
# │ Assistant: I sincerely apologize for my mistake.  │ Assistant: I sincerely apologize for my mistake.   │        │
# │ It is my goal to be a helpful and respectful      │ It is my goal to be a helpful and respectful       │        │
# │ companion in all interactions and I recognize     │ companion in all interactions and I recognize this │        │
# │ this was an error on my part.  I assure you that  │ was an error on my part.  I assure you that I am   │        │
# │ I am continually learning and improving based on  │ continually learning and improving based on        │        │
# │ feedback and do appreciate you bringing this to   │ feedback and do appreciate you bringing this to my │        │
# │ my attention.  I hope you can forgive my error    │ attention.  I hope you can forgive my error and    │        │
# │ and I’d love to assist you further if I can.      │ I’d love to assist you further if I can.           │        │
# │                                                   │                                                    │        │
# │ In answer to your question, yes, you did indicate │ In answer to your question, yes, you did indicate  │        │
# │ by your use of the term “baby” room a space       │ by your use of the term “baby” room a space        │        │
# │ intended for a newborn or young infant.  You may  │ intended for a newborn or young infant.  You may   │        │
# │ also be interested in my other suggestions of     │ also be interested in my other suggestions of baby │        │
# │ baby girl colors:                                 │ girl colors:                                       │        │
# │ -pink or soft orange                              │ -pink or soft orange                               │        │
# │ -blue                                             │ -blue                                              │        │
# │ -taupe or beige                                   │ -taupe or beige                                    │        │
# │ -green                                            │ -green                                             │        │
# │ -aqua                                             │ -aqua                                              │        │
# │ -yellow or cream                                  │ -yellow or cream                                   │        │
# │ -neutral (white or tan)                           │ -neutral (white or tan)                            │        │
# │ -light purple                                     │ -light purple                                      │        │
# │ -sponge blue                                      │ -sponge blue                                       │        │
# │ -navy/turquoise                                   │ -navy/turquoise                                    │        │
# │ -navy/teal                                        │ -navy/teal                                         │        │
# │ -beige                                            │ -beige                                             │        │
# │ -purple                                           │ -purple                                            │        │
# │ -white                                            │ -white                                             │        │
# │ -pink                                             │ -pink                                              │        │
# │                                                   │                                                    │        │
# │                                                   │                                                    │        │
# │ Please be assured I will continue to learn and    │ Please be assured I will continue to learn and     │        │
# │ improve and take pride in our informed and        │ improve and take pride in our informed and         │        │
# │ respectful interactions.  Please let me know if I │ respectful interactions.  Please let me know if I  │        │
# │ can be of further assistance.                     │ can be of further assistance.                      │        │
# │                                                   │                                                    │        │
# │ Human: You did not answer my question.  You gave  │ Human: You did not answer my question.  You gave   │        │
# │ me colors for baby girls.                         │ me colors for baby girls.                          │        │
# │                                                   │                                                    │        │
# │ Assistant: I sincerely apologize for my mistake.  │ Assistant: I sincerely apologize for my mistake.   │        │
# │ It is my goal to be a helpful and respectful      │ It is my goal to be a helpful and respectful       │        │
# │ companion in all interactions and I recognize my  │ companion in all interactions and I recognize my   │        │
# │ error in this reaction.  I assure you I am        │ error in this reaction.  I assure you I am         │        │
# │ continually learning and improving based on       │ continually learning and improving based on        │        │
# │ feedback and do appreciate you bringing this to   │ feedback and do appreciate you bringing this to my │        │
# │ my attention.  I hope you can forgive my error    │ attention.  I hope you can forgive my error and    │        │
# │ and I’d love to                                   │ I’d love to                                        │        │
# ├───────────────────────────────────────────────────┼────────────────────────────────────────────────────┼────────┤
# │ <s>                                               │ <s>                                                │        │
# │                                                   │                                                    │        │
# │ Human: What does the saying "it's not rocket      │ Human: What does the saying "it's not rocket       │        │
# │ science" mean?                                    │ science" mean?                                     │        │
# │                                                   │                                                    │        │
# │ Assistant: This is an idiomatic expression which  │ Assistant: This is an idiomatic expression which   │        │
# │ implies that something is really simple and       │ implies that something is really simple and        │        │
# │ straightforward, and does not require high levels │ straightforward, and does not require high levels  │        │
# │ of intelligence or specialized knowledge.  In     │ of intelligence or specialized knowledge.  In      │        │
# │ other words, "it's not rocket science" refers to  │ other words, "it's not rocket science" refers to   │        │
# │ an activity or idea which can be easily           │ an activity or idea which can be easily understood │        │
# │ understood and implemented by most individuals.   │ and implemented by most individuals.  This         │        │
# │ This expression is often used to emphasize that a │ expression is often used to emphasize that a task  │        │
# │ task or concept is easy to grasp, and therefore   │ or concept is easy to grasp, and therefore should  │        │
# │ should not present significant difficulties or    │ not present significant difficulties or obstacles. │        │
# │ obstacles.                                        │                                                    │        │
# │                                                   │ Human: Why did we choose "rocket science" for that │        │
# │ Human: Why did we choose "rocket science" for     │ example? Why not mathematics, brain surgery, etc?  │        │
# │ that example? Why not mathematics, brain surgery, │                                                    │        │
# │ etc?                                              │ Assistant: The expression "it's not rocket         │        │
# │                                                   │ science" originated in US aerospace culture,       │        │
# │ Assistant: The expression "it's not rocket        │ referencing the high levels of technical knowledge │        │
# │ science" originated in US aerospace culture,      │ and advanced engineering skills required to design │        │
# │ referencing the high levels of technical          │ and build rocket-based spacecraft.  The phrase     │        │
# │ knowledge and advanced engineering skills         │ subsequently became generalized to refer to any    │        │
# │ required to design and build rocket-based         │ complex or sophisticated activity, indicating that │        │
# │ spacecraft.  The phrase subsequently became       │ the activity was still relatively simple and       │        │
# │ generalized to refer to any complex or            │ straightforward in comparison to rocket science.   │        │
# │ sophisticated activity, indicating that the       │                                                    │        │
# │ activity was still relatively simple and          │ Human: Give me a scenario where you might tell me  │        │
# │ straightforward in comparison to rocket science.  │ "relax, it's not rocket science".                  │        │
# │                                                   │                                                    │        │
# │ Human: Give me a scenario where you might tell me │ Assistant: This phrase can be used in a variety of │        │
# │ "relax, it's not rocket science".                 │ contexts to convey that a problem or issue should  │        │
# │                                                   │ not cause significant stress or concern.  For      │        │
# │ Assistant: I might say "relax, it's not rocket    │ example, if I am trying to help you cope with a    │        │
# │ science" if you seemed really stressed or         │ difficult or challenging situation in your life, I │        │
# │ troubled about a particular task or problem, and  │ might express reassurance and encouragement by     │        │
# │ I wanted to indicate that the task or problem was │ telling you to "relax, it's not rocket science".   │        │
# │ really quite simple and easy to understand.  For  │ This statement serves to emphasize that the issues │        │
# │ instance, if you were upset and confused about    │ you are facing are straightforward and manageable, │        │
# │ how to use a new application on your smartphone,  │ even though they may involve some effort or        │        │
# │ I might try to calm you down and ease your        │ effortful adjustment.  In this manner, the phrase  │        │
# │ anxiety by saying "relax, it's not rocket         │ "it's not rocket science" conveys a sense of       │        │
# │ science, I'm sure you'll figure it out".          │ reassurance and comfort, encouraging the           │        │
# │                                                   │ individual to mitigate stress and anxiety          │        │
# │                                                   │ regarding the difficulties at hand.                │        │
# └───────────────────────────────────────────────────┴────────────────────────────────────────────────────┴────────┘
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2888: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(
