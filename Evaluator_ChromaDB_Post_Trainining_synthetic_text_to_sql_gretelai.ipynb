# %% [markdown]
# <a href="https://colab.research.google.com/github/frank-morales2020/MLxDL/blob/main/Evaluator_ChromaDB_Post_Trainining_synthetic_text_to_sql_gretelai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q datasets
# !pip install -q chromadb
# !pip install -q faiss-gpu
# !pip install peft  -q

# !pip install bitsandbytes -q
# !pip pip install accelerate -q

# !pip install -U flash-attn --no-build-isolation --quiet

# !pip install colab-env --quiet

# !pip install mistral_inference -q

# !pip install -q evaluate sentence_transformers

# %%
# !nvidia-smi
# Out:
# Sun Jul  7 17:54:26 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA L4                      Off | 00000000:00:03.0 Off |                    0 |
# | N/A   37C    P8              16W /  72W |      1MiB / 23034MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
import torch
import colab_env
import os
import sys
import json
import IPython
from datetime import datetime
from datasets import load_dataset
from peft import LoraConfig, PeftModel, prepare_model_for_kbit_training, get_peft_model
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    AutoTokenizer,
    TrainingArguments,
)

# %% [markdown]
# # Environment Settings

# %%
import logging
from tqdm.auto import tqdm
from datasets import load_dataset
from peft import AutoPeftModelForCausalLM
from transformers import AutoTokenizer, pipeline
import os


from sentence_transformers import SentenceTransformer
import chromadb

# Logging Setup
logging.basicConfig(level=logging.INFO)

# 1. Configurable Parameters
PEFT_MODEL_ID = "frankmorales2020/Mistral-7B-text-to-sql-flash-attention-2-dataeval"

#b-mc2/sql-create-context
#DATASET_FILE = "/content/drive/MyDrive/datasets/test_dataset.json"

#gretelai/synthetic_text_to_sql
DATASET_FILE = "/content/drive/MyDrive/datasets/gretelai_test_dataset.json"


NUM_SAMPLES_TO_PROCESS = int(os.getenv("NUM_SAMPLES", 100))
GENERATION_PARAMS = {
    "max_new_tokens": 256, "do_sample": True, "temperature": 0.7, "top_k": 50, "top_p": 0.95
}
SIMILARITY_THRESHOLD = 0.75

# 2. Mount Google Drive (for Colab)
from google.colab import drive
drive.mount('/content/drive')

# 3. Load Evaluation Dataset
eval_dataset = load_dataset("json", data_files=DATASET_FILE, split="train")
if NUM_SAMPLES_TO_PROCESS > 0:
    eval_dataset = eval_dataset.select(range(NUM_SAMPLES_TO_PROCESS))
logging.info(f"Processing {len(eval_dataset)} samples from the dataset.")


# 4. Load Models and Tokenizer
logging.info(f"Loading fine-tuned PEFT model from: {PEFT_MODEL_ID}")
model = AutoPeftModelForCausalLM.from_pretrained(PEFT_MODEL_ID)
tokenizer = AutoTokenizer.from_pretrained(PEFT_MODEL_ID)
pipe = pipeline("text-generation", model=model, tokenizer=tokenizer, **GENERATION_PARAMS)
logging.info("Model and tokenizer loaded successfully!")

# 5. ChromaDB Setup
client = chromadb.PersistentClient(path='db')  # Store embeddings on disk
collection = client.get_or_create_collection(name="sql_queries_and_embeddings")

# Add Original SQL Queries to ChromaDB
embedding_model = SentenceTransformer("all-mpnet-base-v2")
original_sql_queries = [
    item['messages'][2]['content']
    for item in eval_dataset if len(item['messages']) > 2 and item['messages'][2].get('content')
]

sql_embeddings = embedding_model.encode(original_sql_queries).tolist()
collection.add(
    embeddings=sql_embeddings,
    metadatas=[{"original_sql": query} for query in original_sql_queries],
    ids=[f"original_{i}" for i in range(len(original_sql_queries))]  # Unique IDs
)

# %% [markdown]
# # Postgresql Setup

# %%
#ADDED By FM 01/06/2024
# !apt-get update -y
# !apt-get install postgresql-14 -y

# !service postgresql restart
# !sudo apt install postgresql-server-dev-all

# %%
# PostGRES SQL Settings
# !sudo -u postgres psql -c "CREATE USER postgres WITH SUPERUSER"
# !sudo -u postgres psql -c "ALTER USER postgres PASSWORD 'postgres'"
# Out:
# ERROR:  role "postgres" already exists
# ALTER ROLE

# %%
QUERY_create='CREATE TABLE table_name_24 (score VARCHAR, date VARCHAR)'

# %%
QUERY_select='SELECT 2009 FROM table_name_50 WHERE 2011 = "a"'

# %%
def table_creator(query):
    import os
    import psycopg2 as ps
    import pandas as pd

    DB_NAME = "postgres"
    DB_USER = "postgres"
    DB_PASS = "postgres"
    DB_HOST = "localhost"
    DB_PORT = "5432"

    conn = ps.connect(database=DB_NAME,
                  user=DB_USER,
                  password=DB_PASS,
                  host=DB_HOST,
                  port=DB_PORT)

    cur = conn.cursor() # creating a cursor




    # Wrap the execute command in a try-except block to handle potential errors
    try:
        cur.execute("""
                            # %s
                            """%query)
        conn.commit()
        print("Table Created successfully")
    except Exception as e:
        conn.rollback() # Rollback the transaction in case of an error
        print("Error creating table:", e)

    conn.close()

# %%
import os
import psycopg2 as ps
import pandas as pd

DB_NAME = "postgres"
DB_USER = "postgres"
DB_PASS = "postgres"
DB_HOST = "localhost"
DB_PORT = "5432"

# %%
import os
import psycopg2 as ps
import pandas as pd

def table_select(query):
    conn = ps.connect(database=DB_NAME,
                      user=DB_USER,
                      password=DB_PASS,
                      host=DB_HOST,
                      port=DB_PORT)
    print("Database connected successfully")

    #query = query.replace('"', "'") # Replace double quotes with single quotes for potential date values

    try:

        #df = pd.read_sql_query("%s"%query, con=conn)
        #print('rec: %'%df) # Print the resulting DataFrame

        cur = conn.cursor()
        cur.execute(query)
        rows = cur.fetchall()
        conn.commit()
        conn.close()
        print('\n')
        print('Record(s): %s \n'%len(rows))
        for row in rows:
            print(row)


        eqc=1

    except Exception as e:
        eqc=0
        #conn.rollback() # Rollback the transaction in case of an error
        print("Error executing query:", e)
        #print('TABLE IS EMPTY')
        conn.commit()
        conn.close()

    return eqc

# %%
table_creator(QUERY_create)
# Out:
# Table Created successfully

# %% [markdown]
# # Model Evaluator

# %%
# 6. Evaluation Function (Exact Match Only)
def evaluate(sample):
    eqc=0
    prompt = pipe.tokenizer.apply_chat_template(sample["messages"][:2], tokenize=False, add_generation_prompt=True)
    outputs = pipe(prompt, max_new_tokens=256, do_sample=True, temperature=0.7, top_k=50, top_p=0.95, eos_token_id=pipe.tokenizer.eos_token_id, pad_token_id=pipe.tokenizer.pad_token_id)
    predicted_answer = outputs[0]['generated_text'][len(prompt):].strip()

    #print("\n\n")
    question = sample["messages"][1]["content"]
    original_answer = sample["messages"][2]["content"]


    schema=sample["messages"][0]['content']
    schema_query=schema[153:len(schema)]

    print(f'Question: {question}')
    print(f'SCHEMA: {schema_query}')
    print(f'Original Answer: {original_answer}')
    print(f'Generated Answer: {predicted_answer}')

    if predicted_answer == original_answer:

        print("\n")
        print(f'SCHEMA QUERY: {schema_query}')
        table_creator(schema_query)
        print("\n")
        print(f'Generated Answer: {predicted_answer}')
        eqc=table_select(predicted_answer)
        print(eqc)
        print("\n")
        if int(eqc)==1:
           print('Good Query execution')
        else:
           print('Bad Query execution')

        print("\n")
        print('MATCH')
        return 1, eqc

    # If not an exact match, check semantic similarity using ChromaDB:
    predicted_embedding = embedding_model.encode([predicted_answer]).tolist()[0]
    results = collection.query(
        query_embeddings=[predicted_embedding],
        n_results=1,
        include=["distances", "metadatas"]
    )
    closest_distance = results['distances'][0][0]
    most_similar_query = results['metadatas'][0][0]['original_sql']
    print(f'Closest Distance: {closest_distance}')

    similarity_threshold = SIMILARITY_THRESHOLD

    if closest_distance < similarity_threshold:
        print("\n")
        print('MATCH (Semantically Similar)')
        print("\n")
        print(f'SCHEMA QUERY: {schema_query}')
        table_creator(schema_query)
        print("\n")
        print('Similar Query:', most_similar_query)
        eqc=table_select(most_similar_query)
        print("\n")
        if int(eqc)==1:
           print('Good Query execution')
        else:
           print('Bad Query execution')
        print("\n")
        return 1, eqc

    else:
        print('NO MATCH')
        return 0, eqc

    print("\n\n")

# 7. Main Evaluation Loop
success_rate = []
success_rate_query = []

for i, s in enumerate(tqdm(eval_dataset)):
    print()
    print(f"Evaluating sample: {i}")
    try:
        success_rate.append(evaluate(s))
    except Exception as e:
        logging.error(f"Error evaluating sample {i}: {e}")



# 8. Compute and Print Accuracy
if len(success_rate) > 0:
    # Extract the first element (match success indicator) from each tuple
    match_successes = [result[0] for result in success_rate]
    accuracy = sum(match_successes) / len(success_rate)
    print(f"\nMatch Accuracy: {accuracy:.2%}\n")

    query_successes = [result[1] for result in success_rate]
    accuracy = sum(query_successes) / len(query_successes)
    print(f"\nQuery Successes: {accuracy:.2%}\n")

else:
    print("\nNo samples were successfully evaluated. Check the dataset and evaluation logic.\n")


# 8. Compute and Print Accuracy
#if len(success_rate) > 0:
#    accuracy = sum(success_rate) / len(success_rate)
#    print(f"\nMatch Accuracy: {accuracy:.2%}\n")
#else:
#    print("\nNo samples were successfully evaluated. Check the dataset and evaluation logic.\n")
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Evaluating sample: 0
# Question: What is the percentage of successful open data initiatives in the education sector?
# SCHEMA: CREATE TABLE open_data_initiatives (id INT, sector VARCHAR(20), status VARCHAR(10)); INSERT INTO open_data_initiatives (id, sector, status) VALUES (1, 'justice', 'open'), (2, 'transportation', 'open'), (3, 'education', 'closed'), (4, 'education', 'open');
# Original Answer: SELECT 100.0 * COUNT(CASE WHEN status = 'open' THEN 1 END) / COUNT(*) FROM open_data_initiatives WHERE sector = 'education';
# Generated Answer: SELECT COUNT(*) FROM open_data_initiatives WHERE sector = 'education' AND status = 'open' / SELECT COUNT(*) FROM open_data_initiatives WHERE sector = 'education'
# Closest Distance: 0.3737031817436218
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE open_data_initiatives (id INT, sector VARCHAR(20), status VARCHAR(10)); INSERT INTO open_data_initiatives (id, sector, status) VALUES (1, 'justice', 'open'), (2, 'transportation', 'open'), (3, 'education', 'closed'), (4, 'education', 'open');
# Table Created successfully
#
#
# Similar Query: SELECT 100.0 * COUNT(CASE WHEN status = 'open' THEN 1 END) / COUNT(*) FROM open_data_initiatives WHERE sector = 'education';
# Database connected successfully
#
#
# Record(s): 1
#
# (Decimal('50.0000000000000000'),)
#
#
# Good Query execution
#
#
#
# Evaluating sample: 1
# Question: What is the average Shariah-compliant investment portfolio return for female investors in the Middle East, grouped by year?
# SCHEMA: CREATE TABLE Investments (Id INT, InvestorGender VARCHAR(10), Location VARCHAR(20), InvestmentType VARCHAR(20), Return DECIMAL(5,2), InvestmentYear INT); INSERT INTO Investments (Id, InvestorGender, Location, InvestmentType, Return, InvestmentYear) VALUES (1, 'Female', 'Middle East', 'Shariah Compliant', 8.56, 2020), (2, 'Female', 'Middle East', 'Shariah Compliant', 9.15, 2021);
# Original Answer: SELECT AVG(Return) AS Avg_Return, InvestmentYear FROM Investments WHERE InvestmentType = 'Shariah Compliant' AND InvestorGender = 'Female' GROUP BY InvestmentYear;
# Generated Answer: SELECT AVG(Return), InvestmentYear FROM Investments WHERE InvestorGender = 'Female' AND Location = 'Middle East' AND InvestmentType = 'Shariah Compliant' GROUP BY InvestmentYear
# Closest Distance: 0.09634736180305481
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE Investments (Id INT, InvestorGender VARCHAR(10), Location VARCHAR(20), InvestmentType VARCHAR(20), Return DECIMAL(5,2), InvestmentYear INT); INSERT INTO Investments (Id, InvestorGender, Location, InvestmentType, Return, InvestmentYear) VALUES (1, 'Female', 'Middle East', 'Shariah Compliant', 8.56, 2020), (2, 'Female', 'Middle East', 'Shariah Compliant', 9.15, 2021);
# Table Created successfully
#
#
# Similar Query: SELECT AVG(Return) AS Avg_Return, InvestmentYear FROM Investments WHERE InvestmentType = 'Shariah Compliant' AND InvestorGender = 'Female' GROUP BY InvestmentYear;
# Database connected successfully
#
#
# Record(s): 2
#
# (Decimal('8.5600000000000000'), 2020)
# (Decimal('9.1500000000000000'), 2021)
#
#
# Good Query execution
#
#
#
# Evaluating sample: 2
# Question: Find the minimum founding year for startups founded by Indigenous or Native entrepreneurs
# SCHEMA: CREATE TABLE company (id INT, name TEXT, founding_year INT, founder_race TEXT); INSERT INTO company (id, name, founding_year, founder_race) VALUES (1, 'IndigenousTech', 2010, 'Indigenous or Native American'); INSERT INTO company (id, name, founding_year, founder_race) VALUES (2, 'Beta', 2015, 'White');
# Original Answer: SELECT MIN(founding_year) FROM company WHERE founder_race = 'Indigenous or Native American';
# Generated Answer: SELECT MIN(founding_year) FROM company WHERE founder_race = 'Indigenous or Native American'
# Closest Distance: 0.0234964732080698
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE company (id INT, name TEXT, founding_year INT, founder_race TEXT); INSERT INTO company (id, name, founding_year, founder_race) VALUES (1, 'IndigenousTech', 2010, 'Indigenous or Native American'); INSERT INTO company (id, name, founding_year, founder_race) VALUES (2, 'Beta', 2015, 'White');
# Table Created successfully
#
#
# Similar Query: SELECT MIN(founding_year) FROM company WHERE founder_race = 'Indigenous or Native American';
# Database connected successfully
#
#
# Record(s): 1
#
# (2010,)
#
#
# Good Query execution
#
#
#
# Evaluating sample: 3
# Question: How many intelligence operations were conducted in 'Africa' in the 'IntelligenceOperations' table?
# SCHEMA: CREATE TABLE IntelligenceOperations (id INT PRIMARY KEY, operation_name VARCHAR(100), location VARCHAR(50), operation_type VARCHAR(50), start_date DATE, end_date DATE); INSERT INTO IntelligenceOperations (id, operation_name, location, operation_type, start_date, end_date) VALUES (1, 'Operation Red Anvil', 'Africa', 'Surveillance', '2021-01-01', '2021-03-31'); INSERT INTO IntelligenceOperations (id, operation_name, location, operation_type, start_date, end_date) VALUES (2, 'Operation Night Hawk', 'Europe', 'Counterintelligence', '2021-04-01', '2021-06-30');
# Original Answer: SELECT COUNT(*) FROM IntelligenceOperations WHERE location = 'Africa';
# Generated Answer: SELECT COUNT(*) FROM IntelligenceOperations WHERE location = "Africa" AND operation_type = "Surveillance" AND start_date <= 2021 AND end_date <= 2021
# Closest Distance: 0.34414035081863403
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE IntelligenceOperations (id INT PRIMARY KEY, operation_name VARCHAR(100), location VARCHAR(50), operation_type VARCHAR(50), start_date DATE, end_date DATE); INSERT INTO IntelligenceOperations (id, operation_name, location, operation_type, start_date, end_date) VALUES (1, 'Operation Red Anvil', 'Africa', 'Surveillance', '2021-01-01', '2021-03-31'); INSERT INTO IntelligenceOperations (id, operation_name, location, operation_type, start_date, end_date) VALUES (2, 'Operation Night Hawk', 'Europe', 'Counterintelligence', '2021-04-01', '2021-06-30');
# Table Created successfully
#
#
# Similar Query: SELECT COUNT(*) FROM IntelligenceOperations WHERE location = 'Africa';
# Database connected successfully
#
#
# Record(s): 1
#
# (1,)
#
#
# Good Query execution
#
#
#
# Evaluating sample: 4
# Question: What is the total number of space missions led by women?
# SCHEMA: CREATE TABLE space_missions (id INT, name VARCHAR(255), leader VARCHAR(255), year INT); INSERT INTO space_missions (id, name, leader, year) VALUES (1, 'Mars Rover', 'Dr. Jessica Watkins', 2022); INSERT INTO space_missions (id, name, leader, year) VALUES (2, 'ISS Expedition', 'Anousheh Ansari', 2023);
# Original Answer: SELECT COUNT(*) FROM space_missions WHERE leader IN (SELECT name FROM astronauts WHERE gender = 'Female');
# Generated Answer: SELECT COUNT(*) FROM space_missions WHERE leader = 'Anousheh Ansari' AND year > 2022
# Closest Distance: 0.5059126615524292
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE space_missions (id INT, name VARCHAR(255), leader VARCHAR(255), year INT); INSERT INTO space_missions (id, name, leader, year) VALUES (1, 'Mars Rover', 'Dr. Jessica Watkins', 2022); INSERT INTO space_missions (id, name, leader, year) VALUES (2, 'ISS Expedition', 'Anousheh Ansari', 2023);
# Table Created successfully
#
#
# Similar Query: SELECT COUNT(*) FROM space_missions WHERE leader IN (SELECT name FROM astronauts WHERE gender = 'Female');
# Database connected successfully
# Error executing query: relation "astronauts" does not exist
# LINE 1: ... space_missions WHERE leader IN (SELECT name FROM astronauts...
#                                                              ^
#
#
#
# Bad Query execution
#
#
#
# Evaluating sample: 5
# Question: How many products are sold by each supplier?
# SCHEMA: CREATE TABLE Products (ProductID int, SupplierID int, QuantitySold int);
# Original Answer: SELECT SupplierID, SUM(QuantitySold) FROM Products GROUP BY SupplierID;
# Generated Answer: SELECT COUNT(*), SupplierID FROM Products GROUP BY SupplierID
# Closest Distance: 0.18182766437530518
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE Products (ProductID int, SupplierID int, QuantitySold int);
# Table Created successfully
#
#
# Similar Query: SELECT supplier_id, COUNT(DISTINCT id) FROM products GROUP BY supplier_id;
# Database connected successfully
# Error executing query: column "supplier_id" does not exist
# LINE 1: SELECT supplier_id, COUNT(DISTINCT id) FROM products GROUP B...
#                ^
# HINT:  Perhaps you meant to reference the column "products.supplierid".
#
#
#
# Bad Query execution
#
#
#
# Evaluating sample: 6
# Question: What is the total waste generation in kg for the top 3 countries in 2020?
# SCHEMA: CREATE TABLE waste_generation (country VARCHAR(255), year INT, amount FLOAT); INSERT INTO waste_generation (country, year, amount) VALUES ('USA', 2020, 500.0), ('Canada', 2020, 350.0), ('Mexico', 2020, 400.0);
# Original Answer: SELECT wg.country, SUM(wg.amount) as total_waste FROM waste_generation wg WHERE wg.year = 2020 AND wg.country IN ('USA', 'Canada', 'Mexico') GROUP BY wg.country ORDER BY total_waste DESC LIMIT 3;
# Generated Answer: SELECT SUM(amount) FROM waste_generation WHERE country IN ('USA', 'Canada', 'Mexico') AND year = 2020
# Closest Distance: 0.2812768220901489
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE waste_generation (country VARCHAR(255), year INT, amount FLOAT); INSERT INTO waste_generation (country, year, amount) VALUES ('USA', 2020, 500.0), ('Canada', 2020, 350.0), ('Mexico', 2020, 400.0);
# Table Created successfully
#
#
# Similar Query: SELECT wg.country, SUM(wg.amount) as total_waste FROM waste_generation wg WHERE wg.year = 2020 AND wg.country IN ('USA', 'Canada', 'Mexico') GROUP BY wg.country ORDER BY total_waste DESC LIMIT 3;
# Database connected successfully
#
#
# Record(s): 3
#
# ('USA', 500.0)
# ('Mexico', 400.0)
# ('Canada', 350.0)
#
#
# Good Query execution
#
#
#
# Evaluating sample: 7
# Question: What is the average age of attendees at arts events in California and how many unique events have there been?
# SCHEMA: CREATE TABLE ca_events (id INT, num_attendees INT, avg_age FLOAT); CREATE TABLE ca_event_types (id INT, event_type VARCHAR(15)); INSERT INTO ca_events (id, num_attendees, avg_age) VALUES (1, 1200, 35.5), (2, 1800, 40.2); INSERT INTO ca_event_types (id, event_type) VALUES (1, 'Dance'), (2, 'Music');
# Original Answer: SELECT AVG(ce.avg_age), COUNT(DISTINCT cet.event_type) FROM ca_events ce INNER JOIN ca_event_types cet ON TRUE;
# Generated Answer: SELECT AVG(t2.avg_age) FROM ca_events AS t1 JOIN ca_event_types AS t2 ON t1.event_type = t2.id WHERE t2.event_type = "Dance" OR t2.event_type = "Music"
# Closest Distance: 0.4498296082019806
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE ca_events (id INT, num_attendees INT, avg_age FLOAT); CREATE TABLE ca_event_types (id INT, event_type VARCHAR(15)); INSERT INTO ca_events (id, num_attendees, avg_age) VALUES (1, 1200, 35.5), (2, 1800, 40.2); INSERT INTO ca_event_types (id, event_type) VALUES (1, 'Dance'), (2, 'Music');
# Table Created successfully
#
#
# Similar Query: SELECT AVG(ce.avg_age), COUNT(DISTINCT cet.event_type) FROM ca_events ce INNER JOIN ca_event_types cet ON TRUE;
# Database connected successfully
#
#
# Record(s): 1
#
# (37.85, 2)
#
#
# Good Query execution
#
#
#
# Evaluating sample: 8
# Question: Find the average waste generation for chemicals with a carbon footprint above 800.
# SCHEMA: CREATE TABLE waste_generation (id INT PRIMARY KEY, chemical_id INT, waste_generation INT); INSERT INTO waste_generation (id, chemical_id, waste_generation) VALUES (1, 1, 900); CREATE TABLE environmental_impact (id INT PRIMARY KEY, chemical_id INT, carbon_footprint INT); INSERT INTO environmental_impact (id, chemical_id, carbon_footprint) VALUES (1, 1, 850);
# Original Answer: SELECT AVG(waste_generation) FROM waste_generation wg JOIN environmental_impact ei ON wg.chemical_id = ei.chemical_id WHERE ei.carbon_footprint > 800;
# Generated Answer: SELECT AVG(w.generation) FROM waste_generation AS w JOIN environmental_impact AS e ON w.chemical_id = e.chemical_id WHERE e.carbon_footprint > 800
# Closest Distance: 0.03243521973490715
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE waste_generation (id INT PRIMARY KEY, chemical_id INT, waste_generation INT); INSERT INTO waste_generation (id, chemical_id, waste_generation) VALUES (1, 1, 900); CREATE TABLE environmental_impact (id INT PRIMARY KEY, chemical_id INT, carbon_footprint INT); INSERT INTO environmental_impact (id, chemical_id, carbon_footprint) VALUES (1, 1, 850);
# Error creating table: relation "waste_generation" already exists
#
#
#
# Similar Query: SELECT AVG(waste_generation) FROM waste_generation wg JOIN environmental_impact ei ON wg.chemical_id = ei.chemical_id WHERE ei.carbon_footprint > 800;
# Database connected successfully
# Error executing query: relation "environmental_impact" does not exist
# LINE 1: ...G(waste_generation) FROM waste_generation wg JOIN environmen...
#                                                              ^
#
#
#
# Bad Query execution
#
#
#
# Evaluating sample: 9
# Question: How many TV shows have the word 'News' in their title?
# SCHEMA: CREATE TABLE shows (id INT, title TEXT, genre TEXT); INSERT INTO shows (id, title, genre) VALUES (1, 'News Show1', 'News'), (2, 'Entertainment Show2', 'Entertainment'), (3, 'Breaking News Show3', 'News');
# Original Answer: SELECT COUNT(*) FROM shows WHERE title LIKE '%News%';
# Generated Answer: SELECT COUNT(*) FROM shows WHERE genre = 'News'
# Closest Distance: 0.4847338795661926
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE shows (id INT, title TEXT, genre TEXT); INSERT INTO shows (id, title, genre) VALUES (1, 'News Show1', 'News'), (2, 'Entertainment Show2', 'Entertainment'), (3, 'Breaking News Show3', 'News');
# Table Created successfully
#
#
# Similar Query: SELECT COUNT(*) FROM shows WHERE title LIKE '%News%';
# Database connected successfully
#
#
# Record(s): 1
#
# (2,)
#
#
# Good Query execution
#
#
#
# Evaluating sample: 10
# Question: What was the total energy consumption (in MWh) for residential buildings in California in 2020?
# SCHEMA: CREATE TABLE residential_energy_consumption (state VARCHAR(20), year INT, sector VARCHAR(20), energy_consumption FLOAT);
# Original Answer: SELECT SUM(energy_consumption) FROM residential_energy_consumption WHERE state = 'California' AND year = 2020 AND sector = 'Residential';
# Generated Answer: SELECT SUM(energy_consumption) FROM residential_energy_consumption WHERE state = "California" AND sector = "residential" AND year = 2020
# Closest Distance: 0.0150598818436265
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE residential_energy_consumption (state VARCHAR(20), year INT, sector VARCHAR(20), energy_consumption FLOAT);
# Table Created successfully
#
#
# Similar Query: SELECT SUM(energy_consumption) FROM residential_energy_consumption WHERE state = 'California' AND year = 2020 AND sector = 'Residential';
# Database connected successfully
#
#
# Record(s): 1
#
# (None,)
#
#
# Good Query execution
#
#
#
# Evaluating sample: 11
# Question: What is the number of news articles published per day in the United States and Canada, for the last 30 days?
# SCHEMA: CREATE TABLE news_articles (id INT, title VARCHAR(50), publication_date DATE, country VARCHAR(50)); INSERT INTO news_articles (id, title, publication_date, country) VALUES (1, 'Article1', '2022-01-01', 'United States'), (2, 'Article2', '2022-01-02', 'Canada'), (3, 'Article3', '2022-01-03', 'United States'), (4, 'Article4', '2022-01-04', 'Canada');
# Original Answer: SELECT DATE(publication_date) as date, COUNT(*) as num_articles FROM news_articles WHERE country IN ('United States', 'Canada') AND publication_date >= NOW() - INTERVAL 30 DAY GROUP BY date ORDER BY date DESC;
# Generated Answer: SELECT COUNT(*) FROM news_articles WHERE country = 'United States' OR country = 'Canada' AND publication_date >= DATE_SUB(CURDATE(), INTERVAL 30 DAY)
# Closest Distance: 0.2352416217327118
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE news_articles (id INT, title VARCHAR(50), publication_date DATE, country VARCHAR(50)); INSERT INTO news_articles (id, title, publication_date, country) VALUES (1, 'Article1', '2022-01-01', 'United States'), (2, 'Article2', '2022-01-02', 'Canada'), (3, 'Article3', '2022-01-03', 'United States'), (4, 'Article4', '2022-01-04', 'Canada');
# Table Created successfully
#
#
# Similar Query: SELECT DATE(publication_date) as date, COUNT(*) as num_articles FROM news_articles WHERE country IN ('United States', 'Canada') AND publication_date >= NOW() - INTERVAL 30 DAY GROUP BY date ORDER BY date DESC;
# Database connected successfully
# Error executing query: syntax error at or near "30"
# LINE 1: ...Canada') AND publication_date >= NOW() - INTERVAL 30 DAY GRO...
#                                                              ^
#
#
#
# Bad Query execution
#
#
#
# Evaluating sample: 12
# Question: What is the number of travel advisories issued for each month for each country?
# SCHEMA: CREATE TABLE if not exists travel_advisory (advisory_id INT, country VARCHAR(50), issue_date DATE); INSERT INTO travel_advisory (advisory_id, country, issue_date) VALUES (1, 'France', '2022-02-01'), (2, 'Japan', '2022-03-01'), (3, 'Canada', '2022-01-01'), (4, 'Egypt', '2022-04-01'), (5, 'Australia', '2022-05-01');
# Original Answer: SELECT EXTRACT(MONTH FROM issue_date) as month, country, COUNT(*) as num_advisories FROM travel_advisory GROUP BY month, country;
# Generated Answer: SELECT COUNT(advisory_id), country FROM travel_advisory GROUP BY country, issue_date HAVING COUNT(*) = 1
# Closest Distance: 0.5168290138244629
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE if not exists travel_advisory (advisory_id INT, country VARCHAR(50), issue_date DATE); INSERT INTO travel_advisory (advisory_id, country, issue_date) VALUES (1, 'France', '2022-02-01'), (2, 'Japan', '2022-03-01'), (3, 'Canada', '2022-01-01'), (4, 'Egypt', '2022-04-01'), (5, 'Australia', '2022-05-01');
# Table Created successfully
#
#
# Similar Query: SELECT EXTRACT(MONTH FROM issue_date) as month, country, COUNT(*) as num_advisories FROM travel_advisory GROUP BY month, country;
# Database connected successfully
#
#
# Record(s): 5
#
# (Decimal('2'), 'France', 1)
# (Decimal('3'), 'Japan', 1)
# (Decimal('4'), 'Egypt', 1)
# (Decimal('1'), 'Canada', 1)
# (Decimal('5'), 'Australia', 1)
#
#
# Good Query execution
#
#
#
# Evaluating sample: 13
# Question: Delete the record with id 2 from the 'animals' table
# SCHEMA: CREATE TABLE animals (id INT PRIMARY KEY, name VARCHAR(50), species VARCHAR(50), population INT);
# Original Answer: DELETE FROM animals WHERE id = 2;
# Generated Answer: DELETE FROM animals WHERE id = 2
# Closest Distance: 0.04491596296429634
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE animals (id INT PRIMARY KEY, name VARCHAR(50), species VARCHAR(50), population INT);
# Table Created successfully
#
#
# Similar Query: DELETE FROM animals WHERE id = 2;
# Database connected successfully
# Error executing query: no results to fetch
#
#
# Bad Query execution
#
#
#
# Evaluating sample: 14
# Question: How many donors from each country have donated to causes with a focus on climate change?
# SCHEMA: CREATE TABLE Donors (DonorID INT, DonorName VARCHAR(50), DonationAmount DECIMAL(10,2), CauseID INT, FirstDonationDate DATE, Country VARCHAR(50));CREATE TABLE Causes (CauseID INT, CauseName VARCHAR(50), Focus VARCHAR(50));
# Original Answer: SELECT D.Country, COUNT(DISTINCT D.DonorID) FROM Donors D JOIN Causes C ON D.CauseID = C.CauseID WHERE C.Focus = 'climate change' GROUP BY D.Country;
# Generated Answer: SELECT COUNT(*), DonorName, Country FROM Donors JOIN Causes ON Donors.CauseID = Causes.CauseID WHERE Causes.Focus = 'Climate change' GROUP BY DonorName, Country
# Closest Distance: 0.07848970592021942
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE Donors (DonorID INT, DonorName VARCHAR(50), DonationAmount DECIMAL(10,2), CauseID INT, FirstDonationDate DATE, Country VARCHAR(50));CREATE TABLE Causes (CauseID INT, CauseName VARCHAR(50), Focus VARCHAR(50));
# Table Created successfully
#
#
# Similar Query: SELECT D.Country, COUNT(DISTINCT D.DonorID) FROM Donors D JOIN Causes C ON D.CauseID = C.CauseID WHERE C.Focus = 'climate change' GROUP BY D.Country;
# Database connected successfully
#
#
# Record(s): 0
#
#
#
# Good Query execution
#
#
#
# Evaluating sample: 15
# Question: Calculate the total cost of military equipment for Asian countries in the last 5 years
# SCHEMA: CREATE TABLE military_equipment (equipment_type VARCHAR(255), acquisition_cost INT, acquisition_year INT, country VARCHAR(255)); INSERT INTO military_equipment (equipment_type, acquisition_cost, acquisition_year, country) VALUES ('Fighter Jet', 50000000, 2017, 'China'), ('Submarine', 1000000000, 2019, 'Japan');
# Original Answer: SELECT country, SUM(acquisition_cost) FROM military_equipment WHERE country LIKE 'Asia%' AND acquisition_year BETWEEN (YEAR(CURRENT_DATE) - 5) AND YEAR(CURRENT_DATE) GROUP BY country;
# Generated Answer: SELECT SUM(acquisition_cost) FROM military_equipment WHERE country = 'Asia' AND acquisition_year > 2014
# Closest Distance: 0.2300858497619629
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE military_equipment (equipment_type VARCHAR(255), acquisition_cost INT, acquisition_year INT, country VARCHAR(255)); INSERT INTO military_equipment (equipment_type, acquisition_cost, acquisition_year, country) VALUES ('Fighter Jet', 50000000, 2017, 'China'), ('Submarine', 1000000000, 2019, 'Japan');
# Table Created successfully
#
#
# Similar Query: SELECT country, SUM(acquisition_cost) FROM military_equipment WHERE country LIKE 'Asia%' AND acquisition_year BETWEEN (YEAR(CURRENT_DATE) - 5) AND YEAR(CURRENT_DATE) GROUP BY country;
# Database connected successfully
# Error executing query: function year(date) does not exist
# LINE 1: ...ountry LIKE 'Asia%' AND acquisition_year BETWEEN (YEAR(CURRE...
#                                                              ^
# HINT:  No function matches the given name and argument types. You might need to add explicit type casts.
#
#
#
# Bad Query execution
#
#
#
# Evaluating sample: 16
# Question: What is the minimum fare collected for the 'Red Line' during any given month?
# SCHEMA: CREATE TABLE fare_by_month (route_name VARCHAR(50), month_year DATE, fare_amount DECIMAL(10,2)); INSERT INTO fare_by_month (route_name, month_year, fare_amount) VALUES ('Red Line', '2022-01-01', 100.00), ('Red Line', '2022-02-01', 110.00), ('Red Line', '2022-03-01', 95.00);
# Original Answer: SELECT MIN(fare_amount) FROM fare_by_month WHERE route_name = 'Red Line';
# Generated Answer: SELECT MIN(fare_amount) FROM fare_by_month WHERE route_name = 'Red Line' AND month_year > '2022-01-01'
# Closest Distance: 0.07992449402809143
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE fare_by_month (route_name VARCHAR(50), month_year DATE, fare_amount DECIMAL(10,2)); INSERT INTO fare_by_month (route_name, month_year, fare_amount) VALUES ('Red Line', '2022-01-01', 100.00), ('Red Line', '2022-02-01', 110.00), ('Red Line', '2022-03-01', 95.00);
# Table Created successfully
#
#
# Similar Query: SELECT MIN(fare_amount) FROM fare_by_month WHERE route_name = 'Red Line';
# Database connected successfully
#
#
# Record(s): 1
#
# (Decimal('95.00'),)
#
#
# Good Query execution
#
#
#
# Evaluating sample: 17
# Question: What is the CO2 emission reduction of each production facility in the North America region from 2021 to 2022?
# SCHEMA: CREATE TABLE facility_emission_data (facility_id INT, facility_location VARCHAR(255), CO2_emission INT, year INT);
# Original Answer: SELECT facility_location, (a.CO2_emission - b.CO2_emission) AS CO2_emission_reduction FROM facility_emission_data a JOIN facility_emission_data b ON a.facility_location = b.facility_location AND a.year = b.year + 1 WHERE a.facility_location LIKE 'North America%' AND b.year = 2021;
# Generated Answer: SELECT CO2_emission FROM facility_emission_data WHERE facility_location = "north america" AND year > 2021 - 2022
# Closest Distance: 0.46491074562072754
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE facility_emission_data (facility_id INT, facility_location VARCHAR(255), CO2_emission INT, year INT);
# Table Created successfully
#
#
# Similar Query: SELECT facility_location, (a.CO2_emission - b.CO2_emission) AS CO2_emission_reduction FROM facility_emission_data a JOIN facility_emission_data b ON a.facility_location = b.facility_location AND a.year = b.year + 1 WHERE a.facility_location LIKE 'North America%' AND b.year = 2021;
# Database connected successfully
# Error executing query: column reference "facility_location" is ambiguous
# LINE 1: SELECT facility_location, (a.CO2_emission - b.CO2_emission) ...
#                ^
#
#
#
# Bad Query execution
#
#
#
# Evaluating sample: 18
# Question: What is the total number of transactions for each digital asset in the 'crypto_assets' table?
# SCHEMA: CREATE TABLE crypto_assets (asset_id INT, asset_name VARCHAR(50), total_transactions INT); INSERT INTO crypto_assets (asset_id, asset_name, total_transactions) VALUES (1, 'Bitcoin', 1000000); INSERT INTO crypto_assets (asset_id, asset_name, total_transactions) VALUES (2, 'Ethereum', 500000);
# Original Answer: SELECT asset_name, SUM(total_transactions) FROM crypto_assets GROUP BY asset_name;
# Generated Answer: SELECT COUNT(*) FROM crypto_assets GROUP BY asset_id, asset_name, total_transactions
# Closest Distance: 0.2868979275226593
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE crypto_assets (asset_id INT, asset_name VARCHAR(50), total_transactions INT); INSERT INTO crypto_assets (asset_id, asset_name, total_transactions) VALUES (1, 'Bitcoin', 1000000); INSERT INTO crypto_assets (asset_id, asset_name, total_transactions) VALUES (2, 'Ethereum', 500000);
# Table Created successfully
#
#
# Similar Query: SELECT asset_name, SUM(total_transactions) FROM crypto_assets GROUP BY asset_name;
# Database connected successfully
#
#
# Record(s): 2
#
# ('Bitcoin', 1000000)
# ('Ethereum', 500000)
#
#
# Good Query execution
#
#
#
# Evaluating sample: 19
# Question: Update the arrival age of visitors from Japan to 30.
# SCHEMA: CREATE TABLE tourism_data (visitor_id INT, country VARCHAR(50), arrival_age INT); INSERT INTO tourism_data (visitor_id, country, arrival_age) VALUES (1, 'USA', 35), (2, 'USA', 42), (3, 'Japan', 28), (4, 'Australia', 31), (5, 'UK', 29), (6, 'UK', 34), (7, 'Canada', 22), (8, 'Canada', 25);
# Original Answer: UPDATE tourism_data SET arrival_age = 30 WHERE country = 'Japan';
# Generated Answer: UPDATE tourism_data SET arrival_age = 30 WHERE country = 'japan'
# Closest Distance: 0.03462090343236923
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE tourism_data (visitor_id INT, country VARCHAR(50), arrival_age INT); INSERT INTO tourism_data (visitor_id, country, arrival_age) VALUES (1, 'USA', 35), (2, 'USA', 42), (3, 'Japan', 28), (4, 'Australia', 31), (5, 'UK', 29), (6, 'UK', 34), (7, 'Canada', 22), (8, 'Canada', 25);
# Table Created successfully
#
#
# Similar Query: UPDATE tourism_data SET arrival_age = 30 WHERE country = 'Japan';
# Database connected successfully
# Error executing query: no results to fetch
#
#
# Bad Query execution
#
#
#
# Evaluating sample: 20
# Question: How many mining operations are located in 'Canada'?
# SCHEMA: CREATE TABLE mining_operations (id INT PRIMARY KEY, operation_name VARCHAR(50), location VARCHAR(50), num_employees INT);
# Original Answer: SELECT COUNT(*) FROM mining_operations WHERE location = 'Canada';
# Generated Answer: SELECT COUNT(*) FROM mining_operations WHERE location = "canada"
# Closest Distance: 0.022677164524793625
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE mining_operations (id INT PRIMARY KEY, operation_name VARCHAR(50), location VARCHAR(50), num_employees INT);
# Table Created successfully
#
#
# Similar Query: SELECT COUNT(*) FROM mining_operations WHERE location = 'Canada';
# Database connected successfully
#
#
# Record(s): 1
#
# (0,)
#
#
# Good Query execution
#
#
#
# Evaluating sample: 21
# Question: What is the total cost of all space missions launched by SpaceX?
# SCHEMA: CREATE TABLE Missions (MissionID INT, Name VARCHAR(50), Agency VARCHAR(50), Cost INT); INSERT INTO Missions (MissionID, Name, Agency, Cost) VALUES (1, 'Falcon 9', 'SpaceX', 60000000), (2, 'Falcon Heavy', 'SpaceX', 90000000);
# Original Answer: SELECT SUM(Cost) FROM Missions WHERE Agency = 'SpaceX';
# Generated Answer: SELECT SUM(Cost) FROM Missions WHERE Agency = 'SpaceX'
# Closest Distance: 0.021514497697353363
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE Missions (MissionID INT, Name VARCHAR(50), Agency VARCHAR(50), Cost INT); INSERT INTO Missions (MissionID, Name, Agency, Cost) VALUES (1, 'Falcon 9', 'SpaceX', 60000000), (2, 'Falcon Heavy', 'SpaceX', 90000000);
# Table Created successfully
#
#
# Similar Query: SELECT SUM(Cost) FROM Missions WHERE Agency = 'SpaceX';
# Database connected successfully
#
#
# Record(s): 1
#
# (150000000,)
#
#
# Good Query execution
#
#
#
# Evaluating sample: 22
# Question: What is the average soil moisture level for each crop type in the past month?
# SCHEMA: CREATE TABLE SoilMoistureData (moisture FLOAT, time DATETIME, crop VARCHAR(255));
# Original Answer: SELECT crop, AVG(moisture) FROM SoilMoistureData WHERE time > DATE_SUB(CURRENT_TIMESTAMP(), INTERVAL 1 MONTH) GROUP BY crop;
# Generated Answer: SELECT AVG(moisture), time FROM SoilMoistureData WHERE time > DATEADD(MONTH, -1, GETDATE()) AND crop = "corn"
# Closest Distance: 0.25217875838279724
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE SoilMoistureData (moisture FLOAT, time DATETIME, crop VARCHAR(255));
# Error creating table: type "datetime" does not exist
# LINE 2: ...EATE TABLE SoilMoistureData (moisture FLOAT, time DATETIME, ...
#                                                              ^
#
#
#
# Similar Query: SELECT crop, AVG(moisture) FROM SoilMoistureData WHERE time > DATE_SUB(CURRENT_TIMESTAMP(), INTERVAL 1 MONTH) GROUP BY crop;
# Database connected successfully
# Error executing query: syntax error at or near ")"
# LINE 1: ...stureData WHERE time > DATE_SUB(CURRENT_TIMESTAMP(), INTERVA...
#                                                              ^
#
#
#
# Bad Query execution
#
#
#
# Evaluating sample: 23
# Question: Insert a new record into the "ocean_pollution" table with the following data: "Plastic", "Great Pacific Garbage Patch", 2010
# SCHEMA: CREATE TABLE ocean_pollution (id INT PRIMARY KEY, pollutant_type VARCHAR(255), location VARCHAR(255), year INT);
# Original Answer: INSERT INTO ocean_pollution (pollutant_type, location, year) VALUES ('Plastic', 'Great Pacific Garbage Patch', 2010);
# Generated Answer: INSERT INTO ocean_pollution (pollutant_type, location, year) VALUES ("Plastic", "Great Pacific Garbage Patch", 2010)
# Closest Distance: 0.035345837473869324
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE ocean_pollution (id INT PRIMARY KEY, pollutant_type VARCHAR(255), location VARCHAR(255), year INT);
# Table Created successfully
#
#
# Similar Query: INSERT INTO ocean_pollution (pollutant_type, location, year) VALUES ('Plastic', 'Great Pacific Garbage Patch', 2010);
# Database connected successfully
# Error executing query: null value in column "id" of relation "ocean_pollution" violates not-null constraint
# DETAIL:  Failing row contains (null, Plastic, Great Pacific Garbage Patch, 2010).
#
#
#
# Bad Query execution
#
#
#
# Evaluating sample: 24
# Question: List the hotels that have consistently reduced their energy consumption.
# SCHEMA: CREATE TABLE hotels (hotel_id INT, hotel_name TEXT, city TEXT, country TEXT, energy_consumption FLOAT, year INT); INSERT INTO hotels (hotel_id, hotel_name, city, country, energy_consumption, year) VALUES (1, 'Hotel A', 'Rome', 'Italy', 12000.0, 2021), (1, 'Hotel A', 'Rome', 'Italy', 11000.0, 2022);
# Original Answer: SELECT hotel_name, energy_consumption FROM (SELECT hotel_name, energy_consumption, energy_consumption - LAG(energy_consumption) OVER (PARTITION BY hotel_name ORDER BY year) as diff FROM hotels) where diff < 0;
# Generated Answer: SELECT hotel_name FROM hotels GROUP BY hotel_id HAVING MIN(energy_consumption) < MAX(energy_consumption)
# Closest Distance: 0.5944753289222717
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE hotels (hotel_id INT, hotel_name TEXT, city TEXT, country TEXT, energy_consumption FLOAT, year INT); INSERT INTO hotels (hotel_id, hotel_name, city, country, energy_consumption, year) VALUES (1, 'Hotel A', 'Rome', 'Italy', 12000.0, 2021), (1, 'Hotel A', 'Rome', 'Italy', 11000.0, 2022);
# Table Created successfully
#
#
# Similar Query: SELECT hotel_name, energy_consumption FROM (SELECT hotel_name, energy_consumption, energy_consumption - LAG(energy_consumption) OVER (PARTITION BY hotel_name ORDER BY year) as diff FROM hotels) where diff < 0;
# Database connected successfully
# Error executing query: subquery in FROM must have an alias
# LINE 1: SELECT hotel_name, energy_consumption FROM (SELECT hotel_nam...
#                                                    ^
# HINT:  For example, FROM (SELECT ...) [AS] foo.
#
#
#
# Bad Query execution
#
#
#
# Evaluating sample: 25
# Question: What is the average age of females who have voted in the last 3 presidential elections in the state of California?
# SCHEMA: CREATE TABLE voters (voter_id INT, gender VARCHAR(10), age INT, state VARCHAR(20), election_year INT); INSERT INTO voters (voter_id, gender, age, state, election_year) VALUES (1, 'Female', 35, 'California', 2020), (2, 'Male', 45, 'Texas', 2016), (3, 'Female', 50, 'California', 2016), (4, 'Male', 25, 'California', 2020), (5, 'Female', 40, 'Texas', 2016), (6, 'Female', 30, 'California', 2012); CREATE TABLE elections (election_id INT, election_year INT, state VARCHAR(20)); INSERT INTO elections (election_id, election_year, state) VALUES (1, 2020, 'California'), (2, 2016, 'Texas'), (3, 2016, 'California'), (4, 2020, 'California'), (5, 2012, 'California');
# Original Answer: SELECT AVG(age) FROM voters JOIN elections ON voters.election_year = elections.election_year WHERE gender = 'Female' AND state = 'California' AND elections.election_year IN (2012, 2016, 2020);
# Generated Answer: SELECT AVG(t1.age) FROM voters AS t1 JOIN elections AS t2 ON t1.election_year = t2.election_year WHERE t1.gender = 'Female' AND t2.state = 'California' AND t2.election_year IN (2012, 2016, 2020)
# Closest Distance: 0.058995604515075684
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE voters (voter_id INT, gender VARCHAR(10), age INT, state VARCHAR(20), election_year INT); INSERT INTO voters (voter_id, gender, age, state, election_year) VALUES (1, 'Female', 35, 'California', 2020), (2, 'Male', 45, 'Texas', 2016), (3, 'Female', 50, 'California', 2016), (4, 'Male', 25, 'California', 2020), (5, 'Female', 40, 'Texas', 2016), (6, 'Female', 30, 'California', 2012); CREATE TABLE elections (election_id INT, election_year INT, state VARCHAR(20)); INSERT INTO elections (election_id, election_year, state) VALUES (1, 2020, 'California'), (2, 2016, 'Texas'), (3, 2016, 'California'), (4, 2020, 'California'), (5, 2012, 'California');
# Table Created successfully
#
#
# Similar Query: SELECT AVG(age) FROM voters JOIN elections ON voters.election_year = elections.election_year WHERE gender = 'Female' AND state = 'California' AND elections.election_year IN (2012, 2016, 2020);
# Database connected successfully
# Error executing query: column reference "state" is ambiguous
# LINE 1: ...ections.election_year WHERE gender = 'Female' AND state = 'C...
#                                                              ^
#
#
#
# Bad Query execution
#
#
#
# Evaluating sample: 26
# Question: What is the number of job applications received from veterans in the HR department?
# SCHEMA: CREATE TABLE JobApplications (ApplicationID int, Name varchar(50), VeteranStatus varchar(50), Department varchar(50)); INSERT INTO JobApplications (ApplicationID, Name, VeteranStatus, Department) VALUES (1, 'John Doe', 'Yes', 'HR'); INSERT INTO JobApplications (ApplicationID, Name, VeteranStatus, Department) VALUES (2, 'Jane Smith', 'No', 'IT');
# Original Answer: SELECT COUNT(*) FROM JobApplications WHERE VeteranStatus = 'Yes' AND Department = 'HR';
# Generated Answer: SELECT COUNT(*) FROM JobApplications WHERE VeteranStatus = "Yes" AND Department = "HR"
# Closest Distance: 0.017593197524547577
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE JobApplications (ApplicationID int, Name varchar(50), VeteranStatus varchar(50), Department varchar(50)); INSERT INTO JobApplications (ApplicationID, Name, VeteranStatus, Department) VALUES (1, 'John Doe', 'Yes', 'HR'); INSERT INTO JobApplications (ApplicationID, Name, VeteranStatus, Department) VALUES (2, 'Jane Smith', 'No', 'IT');
# Table Created successfully
#
#
# Similar Query: SELECT COUNT(*) FROM JobApplications WHERE VeteranStatus = 'Yes' AND Department = 'HR';
# Database connected successfully
#
#
# Record(s): 1
#
# (1,)
#
#
# Good Query execution
#
#
#
# Evaluating sample: 27
# Question: Count the number of explainable AI models developed by each organization and return the TOP 3 organizations with the highest count?
# SCHEMA: CREATE TABLE ExplainableAI (id INT, model_name VARCHAR(50), organization VARCHAR(50)); INSERT INTO ExplainableAI (id, model_name, organization) VALUES (1, 'LIME', 'Google'), (2, 'SHAP', 'Microsoft'), (3, 'Anchors', 'Uber'), (4, 'TreeExplainer', 'Google'), (5, 'DeepLIFT', 'Microsoft');
# Original Answer: SELECT organization, COUNT(model_name) as model_count FROM ExplainableAI GROUP BY organization ORDER BY model_count DESC LIMIT 3;
# Generated Answer: SELECT COUNT(*), organization FROM ExplainableAI GROUP BY organization ORDER BY COUNT(*) DESC LIMIT 3
# Closest Distance: 0.19043458998203278
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE ExplainableAI (id INT, model_name VARCHAR(50), organization VARCHAR(50)); INSERT INTO ExplainableAI (id, model_name, organization) VALUES (1, 'LIME', 'Google'), (2, 'SHAP', 'Microsoft'), (3, 'Anchors', 'Uber'), (4, 'TreeExplainer', 'Google'), (5, 'DeepLIFT', 'Microsoft');
# Table Created successfully
#
#
# Similar Query: SELECT organization, COUNT(model_name) as model_count FROM ExplainableAI GROUP BY organization ORDER BY model_count DESC LIMIT 3;
# Database connected successfully
#
#
# Record(s): 3
#
# ('Microsoft', 2)
# ('Google', 2)
# ('Uber', 1)
#
#
# Good Query execution
#
#
#
# Evaluating sample: 28
# Question: Identify the well with the lowest production volume in the Gulf of Mexico
# SCHEMA: CREATE TABLE wells (well_id INT, well_name VARCHAR(50), production_volume FLOAT, location VARCHAR(50)); INSERT INTO wells VALUES (1, 'Well A', 1000, 'Gulf of Mexico'); INSERT INTO wells VALUES (2, 'Well B', 1500, 'Alaska North Slope'); INSERT INTO wells VALUES (3, 'Well C', 1200, 'Gulf of Mexico'); INSERT INTO wells VALUES (4, 'Well D', 800, 'Gulf of Mexico');
# Original Answer: SELECT well_name, production_volume FROM wells WHERE location = 'Gulf of Mexico' ORDER BY production_volume LIMIT 1;
# Generated Answer: SELECT well_id FROM wells WHERE production_volume = (SELECT MIN(production_volume) FROM wells WHERE location = 'Gulf of Mexico')
# Closest Distance: 0.41160473227500916
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE wells (well_id INT, well_name VARCHAR(50), production_volume FLOAT, location VARCHAR(50)); INSERT INTO wells VALUES (1, 'Well A', 1000, 'Gulf of Mexico'); INSERT INTO wells VALUES (2, 'Well B', 1500, 'Alaska North Slope'); INSERT INTO wells VALUES (3, 'Well C', 1200, 'Gulf of Mexico'); INSERT INTO wells VALUES (4, 'Well D', 800, 'Gulf of Mexico');
# Table Created successfully
#
#
# Similar Query: SELECT well_name, production_volume FROM wells WHERE location = 'Gulf of Mexico' ORDER BY production_volume LIMIT 1;
# Database connected successfully
#
#
# Record(s): 1
#
# ('Well D', 800.0)
#
#
# Good Query execution
#
#
#
# Evaluating sample: 29
# Question: How many marine protected areas were added in 2020?
# SCHEMA: CREATE TABLE marine_protected_areas (name TEXT, added_year INTEGER); INSERT INTO marine_protected_areas (name, added_year) VALUES ('Tubbataha Reefs Natural Park', 1988), ('Palau National Marine Sanctuary', 2020), ('Malpelo Fauna and Flora Sanctuary', 1995);
# Original Answer: SELECT COUNT(*) FROM marine_protected_areas WHERE added_year = 2020;
# Generated Answer: SELECT COUNT(*) FROM marine_protected_areas WHERE added_year = 2020
# Closest Distance: 0.01627890206873417
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE marine_protected_areas (name TEXT, added_year INTEGER); INSERT INTO marine_protected_areas (name, added_year) VALUES ('Tubbataha Reefs Natural Park', 1988), ('Palau National Marine Sanctuary', 2020), ('Malpelo Fauna and Flora Sanctuary', 1995);
# Table Created successfully
#
#
# Similar Query: SELECT COUNT(*) FROM marine_protected_areas WHERE added_year = 2020;
# Database connected successfully
#
#
# Record(s): 1
#
# (1,)
#
#
# Good Query execution
#
#
#
# Evaluating sample: 30
# Question: Find the number of unique users who engaged with posts about 'data privacy' in the post_engagements table in the last month.
# SCHEMA: CREATE TABLE post_engagements (user_id INT, post_id INT, engagement_date DATE, post_topic VARCHAR(50));
# Original Answer: SELECT COUNT(DISTINCT user_id) as unique_users FROM post_engagements WHERE post_topic = 'data privacy' AND engagement_date >= DATE_SUB(CURDATE(), INTERVAL 1 MONTH);
# Generated Answer: SELECT COUNT(DISTINCT user_id) FROM post_engagements WHERE engagement_date >= DATE(NOW) - INTERVAL 1 MONTH AND post_topic = 'data privacy'
# Closest Distance: 0.14528240263462067
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE post_engagements (user_id INT, post_id INT, engagement_date DATE, post_topic VARCHAR(50));
# Table Created successfully
#
#
# Similar Query: SELECT COUNT(DISTINCT user_id) as unique_users FROM post_engagements WHERE post_topic = 'data privacy' AND engagement_date >= DATE_SUB(CURDATE(), INTERVAL 1 MONTH);
# Database connected successfully
# Error executing query: syntax error at or near "1"
# LINE 1: ...ND engagement_date >= DATE_SUB(CURDATE(), INTERVAL 1 MONTH);
#                                                               ^
#
#
#
# Bad Query execution
#
#
#
# Evaluating sample: 31
# Question: List the total number of accidents in each year?
# SCHEMA: CREATE TABLE AccidentYears (YearID int, Year int); CREATE TABLE AccidentReports (ReportID int, AccidentYearID int, AccidentDate date); INSERT INTO AccidentYears VALUES (1, 2010), (2, 2011), (3, 2012), (4, 2015), (5, 2019); INSERT INTO AccidentReports VALUES (1, 1, '2010-01-01'), (2, 1, '2011-05-15'), (3, 3, '2012-03-12'), (4, 4, '2015-06-18'), (5, 5, '2019-08-05');
# Original Answer: SELECT ay.Year, COUNT(ar.ReportID) as TotalAccidents FROM AccidentYears ay INNER JOIN AccidentReports ar ON ay.YearID = ar.AccidentYearID GROUP BY ay.Year;
# Generated Answer: SELECT COUNT(*), Year FROM AccidentYears JOIN AccidentReports ON AccidentReports.AccidentYearID = AccidentYears.YearID GROUP BY Year
# Closest Distance: 0.1418582648038864
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE AccidentYears (YearID int, Year int); CREATE TABLE AccidentReports (ReportID int, AccidentYearID int, AccidentDate date); INSERT INTO AccidentYears VALUES (1, 2010), (2, 2011), (3, 2012), (4, 2015), (5, 2019); INSERT INTO AccidentReports VALUES (1, 1, '2010-01-01'), (2, 1, '2011-05-15'), (3, 3, '2012-03-12'), (4, 4, '2015-06-18'), (5, 5, '2019-08-05');
# Table Created successfully
#
#
# Similar Query: SELECT ay.Year, COUNT(ar.ReportID) as TotalAccidents FROM AccidentYears ay INNER JOIN AccidentReports ar ON ay.YearID = ar.AccidentYearID GROUP BY ay.Year;
# Database connected successfully
#
#
# Record(s): 4
#
# (2012, 1)
# (2015, 1)
# (2010, 2)
# (2019, 1)
#
#
# Good Query execution
#
#
#
# Evaluating sample: 32
# Question: Which artists earned more than $50,000 in concert ticket sales?
# SCHEMA: CREATE TABLE Artists (ArtistID INT, Name VARCHAR(100), Genre VARCHAR(50));
# Original Answer: SELECT A.Name, SUM(T.Price) as TotalEarnings FROM Artists A INNER JOIN Concerts C ON A.ArtistID = C.ArtistID INNER JOIN Tickets T ON C.ConcertID = T.ConcertID GROUP BY A.Name HAVING TotalEarnings > 50000;
# Generated Answer: SELECT ArtistID, Name FROM Artists WHERE Genre = "rock" OR ConcertTicketSales > 50000
# Closest Distance: 0.4464685022830963
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE Artists (ArtistID INT, Name VARCHAR(100), Genre VARCHAR(50));
# Table Created successfully
#
#
# Similar Query: SELECT A.Name, SUM(T.Price) as TotalEarnings FROM Artists A INNER JOIN Concerts C ON A.ArtistID = C.ArtistID INNER JOIN Tickets T ON C.ConcertID = T.ConcertID GROUP BY A.Name HAVING TotalEarnings > 50000;
# Database connected successfully
# Error executing query: relation "concerts" does not exist
# LINE 1: ...Price) as TotalEarnings FROM Artists A INNER JOIN Concerts C...
#                                                              ^
#
#
#
# Bad Query execution
#
#
#
# Evaluating sample: 33
# Question: Find the maximum ticket price for pop concerts.
# SCHEMA: CREATE TABLE ConcertTickets (ticket_id INT, genre VARCHAR(20), price DECIMAL(5,2));
# Original Answer: SELECT MAX(price) FROM ConcertTickets WHERE genre = 'pop';
# Generated Answer: SELECT MAX(ticket_id), MAX(price) FROM ConcertTickets WHERE genre = "pop"
# Closest Distance: 0.09997956454753876
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE ConcertTickets (ticket_id INT, genre VARCHAR(20), price DECIMAL(5,2));
# Table Created successfully
#
#
# Similar Query: SELECT MAX(price) FROM ConcertTickets WHERE genre = 'pop';
# Database connected successfully
#
#
# Record(s): 1
#
# (None,)
#
#
# Good Query execution
#
#
#
# Evaluating sample: 34
# Question: Show the total energy consumption and total energy savings for each renewable energy project type, for projects in California.
# SCHEMA: CREATE TABLE RenewableEnergyProjectTypes (TypeID INT, TypeName VARCHAR(50));CREATE TABLE RenewableEnergyProjects (ProjectID INT, TypeID INT, EnergyConsumption FLOAT, EnergySavings FLOAT, State VARCHAR(2));
# Original Answer: SELECT RenewableEnergyProjectTypes.TypeName, SUM(RenewableEnergyProjects.EnergyConsumption) AS TotalEnergyConsumption, SUM(RenewableEnergyProjects.EnergySavings) AS TotalEnergySavings FROM RenewableEnergyProjectTypes INNER JOIN RenewableEnergyProjects ON RenewableEnergyProjectTypes.TypeID = RenewableEnergyProjects.TypeID WHERE RenewableEnergyProjects.State = 'CA' GROUP BY RenewableEnergyProjectTypes.TypeName;
# Generated Answer: SELECT COUNT(SUM(T1.EnergyConsumption)), COUNT(SUM(T1.EnergySavings)) FROM RenewableEnergyProjectTypes AS T1 JOIN RenewableEnergyProjects AS T2 ON T1.TypeID = T2.TypeID JOIN State AS T3 ON T2.State = T3.State WHERE T3.State = "California"
# Closest Distance: 0.33024367690086365
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE RenewableEnergyProjectTypes (TypeID INT, TypeName VARCHAR(50));CREATE TABLE RenewableEnergyProjects (ProjectID INT, TypeID INT, EnergyConsumption FLOAT, EnergySavings FLOAT, State VARCHAR(2));
# Table Created successfully
#
#
# Similar Query: SELECT RenewableEnergyProjectTypes.TypeName, SUM(RenewableEnergyProjects.EnergyConsumption) AS TotalEnergyConsumption, SUM(RenewableEnergyProjects.EnergySavings) AS TotalEnergySavings FROM RenewableEnergyProjectTypes INNER JOIN RenewableEnergyProjects ON RenewableEnergyProjectTypes.TypeID = RenewableEnergyProjects.TypeID WHERE RenewableEnergyProjects.State = 'CA' GROUP BY RenewableEnergyProjectTypes.TypeName;
# Database connected successfully
#
#
# Record(s): 0
#
#
#
# Good Query execution
#
#
#
# Evaluating sample: 35
# Question: What is the average quantity of vegetarian dishes sold per order?
# SCHEMA: CREATE TABLE menu (menu_id INT, name VARCHAR(50), category VARCHAR(50), price DECIMAL(5,2)); INSERT INTO menu (menu_id, name, category, price) VALUES (1, 'Spaghetti Marinara', 'Pasta', 11.99), (2, 'Vegetable Stir Fry', 'Entree', 13.99), (3, 'Caesar Salad', 'Salad', 9.99); CREATE TABLE orders (order_id INT, order_date DATE, menu_id INT, quantity INT); INSERT INTO orders (order_id, order_date, menu_id, quantity) VALUES (1, '2022-01-03', 1, 3), (2, '2022-01-03', 2, 2), (3, '2022-01-05', 3, 1);
# Original Answer: SELECT AVG(orders.quantity) FROM orders JOIN menu ON orders.menu_id = menu.menu_id WHERE menu.category = 'Vegetarian';
# Generated Answer: SELECT AVG(quantity) FROM orders AS T1 JOIN menu AS T2 ON T1.menu_id = T2.menu_id WHERE T2.category = 'Vegetable'
# Closest Distance: 0.09367476403713226
#
#
# MATCH (Semantically Similar)
#
#
# ...
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE satellites (id INT, country VARCHAR(255), launch_date DATE);
# Table Created successfully
#
#
# Similar Query: SELECT country, COUNT(*) AS launched_satellites FROM satellites WHERE EXTRACT(YEAR FROM launch_date) = 2010 GROUP BY country ORDER BY launched_satellites DESC LIMIT 1;
# Database connected successfully
#
#
# Record(s): 0
#
#
#
# Good Query execution
#
#
#
# Evaluating sample: 89
# Question: Who are the top 3 construction companies with the most completed projects in California?
# SCHEMA: CREATE TABLE Companies (CompanyID int, CompanyName varchar(255), State varchar(255)); CREATE TABLE Projects (ProjectID int, CompanyID int, StartDate date, EndDate date);
# Original Answer: SELECT CompanyName, COUNT(ProjectID) as CompletedProjects FROM Companies JOIN Projects ON Companies.CompanyID = Projects.CompanyID WHERE State = 'California' GROUP BY CompanyName ORDER BY CompletedProjects DESC LIMIT 3;
# Generated Answer: SELECT T2.CompanyName, COUNT(*) FROM Companies AS T1 JOIN Projects AS T2 ON T1.CompanyID = T2.CompanyID WHERE T2.EndDate > CURRENT_DATE AND T1.State = "California" GROUP BY T2.CompanyName ORDER BY COUNT(*) DESC LIMIT 3
# Closest Distance: 0.1802496612071991
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE Companies (CompanyID int, CompanyName varchar(255), State varchar(255)); CREATE TABLE Projects (ProjectID int, CompanyID int, StartDate date, EndDate date);
# Error creating table: relation "companies" already exists
#
#
#
# Similar Query: SELECT CompanyName, COUNT(ProjectID) as CompletedProjects FROM Companies JOIN Projects ON Companies.CompanyID = Projects.CompanyID WHERE State = 'California' GROUP BY CompanyName ORDER BY CompletedProjects DESC LIMIT 3;
# Database connected successfully
# Error executing query: relation "projects" does not exist
# LINE 1: ...ojectID) as CompletedProjects FROM Companies JOIN Projects O...
#                                                              ^
#
#
#
# Bad Query execution
#
#
#
# Evaluating sample: 90
# Question: How many local events in India and Mexico support environmental conservation and women's rights?
# SCHEMA: CREATE TABLE local_events (event_id INT, event_name TEXT, location TEXT, cause TEXT); INSERT INTO local_events (event_id, event_name, location, cause) VALUES (1, 'Festival of Diversity', 'India', 'Women''s Rights'), (2, 'Sustainable Fashion Show', 'Mexico', 'Environmental Conservation');
# Original Answer: SELECT COUNT(*) FROM local_events WHERE location IN ('India', 'Mexico') AND cause IN ('Environmental Conservation', 'Women''s Rights');
# Generated Answer: SELECT COUNT(*) FROM local_events WHERE location = "India" AND cause = "Women's Rights" UNION SELECT COUNT(*) FROM local_events WHERE location = "Mexico" AND cause = "Environmental Conservation"
# Closest Distance: 0.44650959968566895
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE local_events (event_id INT, event_name TEXT, location TEXT, cause TEXT); INSERT INTO local_events (event_id, event_name, location, cause) VALUES (1, 'Festival of Diversity', 'India', 'Women''s Rights'), (2, 'Sustainable Fashion Show', 'Mexico', 'Environmental Conservation');
# Table Created successfully
#
#
# Similar Query: SELECT COUNT(*) FROM local_events WHERE location IN ('India', 'Mexico') AND cause IN ('Environmental Conservation', 'Women''s Rights');
# Database connected successfully
#
#
# Record(s): 1
#
# (2,)
#
#
# Good Query execution
#
#
#
# Evaluating sample: 91
# Question: Who are the developers of the top 3 decentralized applications by transaction volume in South America?
# SCHEMA: CREATE TABLE decentralized_applications (id INT, name VARCHAR(255), developer VARCHAR(255), transaction_volume DECIMAL(10, 2), country VARCHAR(255)); INSERT INTO decentralized_applications (id, name, developer, transaction_volume, country) VALUES (1, 'App 1', 'Dev 1', 5000.00, 'Brazil'), (2, 'App 2', 'Dev 2', 7000.00, 'Argentina'), (3, 'App 3', 'Dev 3', 3000.50, 'Colombia'), (4, 'App 4', 'Dev 4', 6000.00, 'Chile'), (5, 'App 5', 'Dev 5', 4000.50, 'Peru');
# Original Answer: SELECT developer, SUM(transaction_volume) FROM decentralized_applications WHERE country IN ('Brazil', 'Argentina', 'Colombia', 'Chile', 'Peru') GROUP BY developer ORDER BY SUM(transaction_volume) DESC LIMIT 3;
# Generated Answer: SELECT developer FROM decentralized_applications WHERE country = 'South America' ORDER BY transaction_volume DESC LIMIT 3
# Closest Distance: 0.2910562753677368
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE decentralized_applications (id INT, name VARCHAR(255), developer VARCHAR(255), transaction_volume DECIMAL(10, 2), country VARCHAR(255)); INSERT INTO decentralized_applications (id, name, developer, transaction_volume, country) VALUES (1, 'App 1', 'Dev 1', 5000.00, 'Brazil'), (2, 'App 2', 'Dev 2', 7000.00, 'Argentina'), (3, 'App 3', 'Dev 3', 3000.50, 'Colombia'), (4, 'App 4', 'Dev 4', 6000.00, 'Chile'), (5, 'App 5', 'Dev 5', 4000.50, 'Peru');
# Table Created successfully
#
#
# Similar Query: SELECT developer, SUM(transaction_volume) FROM decentralized_applications WHERE country IN ('Brazil', 'Argentina', 'Colombia', 'Chile', 'Peru') GROUP BY developer ORDER BY SUM(transaction_volume) DESC LIMIT 3;
# Database connected successfully
#
#
# Record(s): 3
#
# ('Dev 2', Decimal('7000.00'))
# ('Dev 4', Decimal('6000.00'))
# ('Dev 1', Decimal('5000.00'))
#
#
# Good Query execution
#
#
#
# Evaluating sample: 92
# Question: What is the standard deviation of CO2 emissions for garments made from recycled nylon?
# SCHEMA: CREATE TABLE RecycledNylonGarments (id INT, co2_emission DECIMAL); INSERT INTO RecycledNylonGarments (id, co2_emission) VALUES (1, 7.2), (2, 7.8), (3, 7.6), (4, 8.1), (5, 7.4);
# Original Answer: SELECT STDDEV(co2_emission) FROM RecycledNylonGarments;
# Generated Answer: SELECT STDDEV(co2_emission) FROM RecycledNylonGarments
# Closest Distance: 0.0983736664056778
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE RecycledNylonGarments (id INT, co2_emission DECIMAL); INSERT INTO RecycledNylonGarments (id, co2_emission) VALUES (1, 7.2), (2, 7.8), (3, 7.6), (4, 8.1), (5, 7.4);
# Table Created successfully
#
#
# Similar Query: SELECT STDDEV(co2_emission) FROM RecycledNylonGarments;
# Database connected successfully
#
#
# Record(s): 1
#
# (Decimal('0.34928498393145961293'),)
#
#
# Good Query execution
#
#
#
# Evaluating sample: 93
# Question: Increase the 'funding' for a specific project by 10% in the 'Funding_Allocation' table.
# SCHEMA: CREATE TABLE Funding_Allocation (id INT, project VARCHAR(30), funding FLOAT);
# Original Answer: UPDATE Funding_Allocation SET funding = funding * 1.10 WHERE project = 'Arctic Biodiversity Monitoring';
# Generated Answer: UPDATE Funding_Allocation SET funding = funding * 1.10 WHERE project ='specific project'
# Closest Distance: 0.19640782475471497
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE Funding_Allocation (id INT, project VARCHAR(30), funding FLOAT);
# Table Created successfully
#
#
# Similar Query: UPDATE Funding_Allocation SET funding = funding * 1.10 WHERE project = 'Arctic Biodiversity Monitoring';
# Database connected successfully
# Error executing query: no results to fetch
#
#
# Bad Query execution
#
#
#
# Evaluating sample: 94
# Question: List the names and number of open cases for each government agency in the city of Chicago for the year 2019
# SCHEMA: CREATE TABLE government_agencies (agency_id INT, agency_name VARCHAR(50), city VARCHAR(20), year INT, cases_open INT); INSERT INTO government_agencies (agency_id, agency_name, city, year, cases_open) VALUES (1, 'Chicago Parks Department', 'Chicago', 2019, 200);
# Original Answer: SELECT agency_name, cases_open FROM government_agencies WHERE city = 'Chicago' AND year = 2019;
# Generated Answer: SELECT agency_name, COUNT(cases_open) FROM government_agencies WHERE city = 'Chicago' AND year = 2019 GROUP BY agency_name
# Closest Distance: 0.3165452778339386
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE government_agencies (agency_id INT, agency_name VARCHAR(50), city VARCHAR(20), year INT, cases_open INT); INSERT INTO government_agencies (agency_id, agency_name, city, year, cases_open) VALUES (1, 'Chicago Parks Department', 'Chicago', 2019, 200);
# Table Created successfully
#
#
# Similar Query: SELECT agency_name, cases_open FROM government_agencies WHERE city = 'Chicago' AND year = 2019;
# Database connected successfully
#
#
# Record(s): 1
#
# ('Chicago Parks Department', 200)
#
#
# Good Query execution
#
#
#
# Evaluating sample: 95
# Question: How many total attendees identified as part of the Hispanic community attended events in Texas in 2021?
# SCHEMA: CREATE TABLE Attendees (attendee_id INT, event_id INT, state VARCHAR(50), community_identity VARCHAR(50), attendance_year INT); INSERT INTO Attendees (attendee_id, event_id, state, community_identity, attendance_year) VALUES (15, 60, 'Texas', 'Hispanic', 2021), (16, 61, 'Texas', 'African American', 2021), (17, 62, 'Texas', 'Hispanic', 2021);
# Original Answer: SELECT COUNT(*) FROM Attendees WHERE state = 'Texas' AND attendance_year = 2021 AND community_identity IN ('Hispanic', 'Mexican', 'Puerto Rican', 'Cuban', 'Spanish');
# Generated Answer: SELECT COUNT(*) FROM Attendees WHERE state = 'Texas' AND community_identity = 'Hispanic' AND attendance_year = 2021
# Closest Distance: 0.14693787693977356
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE Attendees (attendee_id INT, event_id INT, state VARCHAR(50), community_identity VARCHAR(50), attendance_year INT); INSERT INTO Attendees (attendee_id, event_id, state, community_identity, attendance_year) VALUES (15, 60, 'Texas', 'Hispanic', 2021), (16, 61, 'Texas', 'African American', 2021), (17, 62, 'Texas', 'Hispanic', 2021);
# Table Created successfully
#
#
# Similar Query: SELECT COUNT(*) FROM Attendees WHERE state = 'Texas' AND attendance_year = 2021 AND community_identity IN ('Hispanic', 'Mexican', 'Puerto Rican', 'Cuban', 'Spanish');
# Database connected successfully
#
#
# Record(s): 1
#
# (2,)
#
#
# Good Query execution
#
#
#
# Evaluating sample: 96
# Question: Show all records from the top_ethics_training view
# SCHEMA: CREATE TABLE workforce_training (id INT PRIMARY KEY, employee_name VARCHAR(255), training_topic VARCHAR(255), training_hours INT, training_completion_date DATE); CREATE VIEW top_ethics_training AS WITH cte AS (SELECT * FROM workforce_training WHERE training_topic = 'ethics') SELECT * FROM cte WHERE training_hours > 5;
# Original Answer: SELECT * FROM top_ethics_training;
# Generated Answer: SELECT * FROM top_ethics_training
# Closest Distance: 0.07149428129196167
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE workforce_training (id INT PRIMARY KEY, employee_name VARCHAR(255), training_topic VARCHAR(255), training_hours INT, training_completion_date DATE); CREATE VIEW top_ethics_training AS WITH cte AS (SELECT * FROM workforce_training WHERE training_topic = 'ethics') SELECT * FROM cte WHERE training_hours > 5;
# Table Created successfully
#
#
# Similar Query: SELECT * FROM top_ethics_training;
# Database connected successfully
#
#
# Record(s): 0
#
#
#
# Good Query execution
#
#
#
# Evaluating sample: 97
# Question: List all cultivation licenses issued in California in 2021, in chronological order.
# SCHEMA: CREATE TABLE Licenses (License_ID INT, License_Type TEXT, License_Number TEXT, Issue_Date DATE); INSERT INTO Licenses (License_ID, License_Type, License_Number, Issue_Date) VALUES (1, 'Cultivation', 'CA-001-CUL', '2021-01-01');
# Original Answer: SELECT License_Number, Issue_Date FROM Licenses WHERE License_Type = 'Cultivation' AND YEAR(Issue_Date) = 2021 ORDER BY Issue_Date;
# Generated Answer: SELECT License_ID, License_Number FROM Licenses WHERE License_Type = 'Cultivation' AND Issue_Date = '2021-01-01' ORDER BY Issue_Date
# Closest Distance: 0.06873967498540878
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE Licenses (License_ID INT, License_Type TEXT, License_Number TEXT, Issue_Date DATE); INSERT INTO Licenses (License_ID, License_Type, License_Number, Issue_Date) VALUES (1, 'Cultivation', 'CA-001-CUL', '2021-01-01');
# Table Created successfully
#
#
# Similar Query: SELECT License_Number, Issue_Date FROM Licenses WHERE License_Type = 'Cultivation' AND YEAR(Issue_Date) = 2021 ORDER BY Issue_Date;
# Database connected successfully
# Error executing query: function year(date) does not exist
# LINE 1: ...M Licenses WHERE License_Type = 'Cultivation' AND YEAR(Issue...
#                                                              ^
# HINT:  No function matches the given name and argument types. You might need to add explicit type casts.
#
#
#
# Bad Query execution
#
#
#
# Evaluating sample: 98
# Question: What is the total amount donated by each program in the last quarter?
# SCHEMA: CREATE TABLE ProgramDonations (ProgramID INT, DonationDate DATE, DonationAmount DECIMAL(10,2)); INSERT INTO ProgramDonations (ProgramID, DonationDate, DonationAmount) VALUES (1, '2022-01-05', 500.00), (1, '2022-02-10', 750.00), (2, '2022-03-20', 300.00);
# Original Answer: SELECT ProgramID, SUM(DonationAmount) as TotalDonated FROM (SELECT ProgramID, DonationAmount FROM ProgramDonations WHERE DonationDate >= DATE_TRUNC('quarter', CURRENT_DATE - INTERVAL '3 months') AND DonationDate < DATE_TRUNC('quarter', CURRENT_DATE) + INTERVAL '1 day' ) t GROUP BY ProgramID;
# Generated Answer: SELECT ProgramID, SUM(DonationAmount) FROM ProgramDonations WHERE DonationDate LIKE "2022-03-%" GROUP BY ProgramID
# Closest Distance: 0.28456825017929077
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE ProgramDonations (ProgramID INT, DonationDate DATE, DonationAmount DECIMAL(10,2)); INSERT INTO ProgramDonations (ProgramID, DonationDate, DonationAmount) VALUES (1, '2022-01-05', 500.00), (1, '2022-02-10', 750.00), (2, '2022-03-20', 300.00);
# Table Created successfully
#
#
# Similar Query: SELECT ProgramID, SUM(DonationAmount) as TotalDonated FROM (SELECT ProgramID, DonationAmount FROM ProgramDonations WHERE DonationDate >= DATE_TRUNC('quarter', CURRENT_DATE - INTERVAL '3 months') AND DonationDate < DATE_TRUNC('quarter', CURRENT_DATE) + INTERVAL '1 day' ) t GROUP BY ProgramID;
# Database connected successfully
#
#
# Record(s): 0
#
#
#
# Good Query execution
#
#
#
# Evaluating sample: 99
# Question: Which programs had more than 25 volunteers in any month of 2022?
# SCHEMA: CREATE TABLE Volunteers (id INT, program VARCHAR(50), volunteer_count INT, engagement_date DATE); INSERT INTO Volunteers (id, program, volunteer_count, engagement_date) VALUES (1, 'Education', 15, '2022-01-05'), (2, 'Health', 20, '2022-01-12'), (3, 'Education', 25, '2022-03-20'), (4, 'Health', 18, '2022-03-27'), (5, 'Environment', 30, '2022-04-01'), (6, 'Education', 35, '2022-05-15');
# Original Answer: SELECT program, DATE_FORMAT(engagement_date, '%Y-%m') as engagement_month, SUM(volunteer_count) as total_volunteers FROM Volunteers WHERE engagement_date BETWEEN '2022-01-01' AND '2022-12-31' GROUP BY program, engagement_month HAVING total_volunteers > 25;
# Generated Answer: SELECT program FROM Volunteers WHERE volunteer_count > 25 AND engagement_date LIKE '2022%'
# Closest Distance: 0.4901929795742035
#
#
# MATCH (Semantically Similar)
#
#
# SCHEMA QUERY: CREATE TABLE Volunteers (id INT, program VARCHAR(50), volunteer_count INT, engagement_date DATE); INSERT INTO Volunteers (id, program, volunteer_count, engagement_date) VALUES (1, 'Education', 15, '2022-01-05'), (2, 'Health', 20, '2022-01-12'), (3, 'Education', 25, '2022-03-20'), (4, 'Health', 18, '2022-03-27'), (5, 'Environment', 30, '2022-04-01'), (6, 'Education', 35, '2022-05-15');
# Error creating table: relation "volunteers" already exists
#
#
#
# Similar Query: SELECT program, DATE_FORMAT(engagement_date, '%Y-%m') as engagement_month, SUM(volunteer_count) as total_volunteers FROM Volunteers WHERE engagement_date BETWEEN '2022-01-01' AND '2022-12-31' GROUP BY program, engagement_month HAVING total_volunteers > 25;
# Database connected successfully
# Error executing query: column "program" does not exist
# LINE 1: SELECT program, DATE_FORMAT(engagement_date, '%Y-%m') as eng...
#                ^
#
#
#
# Bad Query execution
#
#
#
# Match Accuracy: 97.00%
#
#
# Query Successes: 64.00%
