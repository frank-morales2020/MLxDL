# %% [markdown]
# <a href="https://colab.research.google.com/github/frank-morales2020/MLxDL/blob/main/gemini2dot0_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install colab-env --quiet
# !pip install google-generativeai --quiet

import colab_env

# %%
import google.generativeai as genai
from google.colab import userdata

# Retrieve API key from userdata
GOOGLE_API_KEY = userdata.get('GEMINI')

# Check if API key is retrieved successfully
if GOOGLE_API_KEY is None:
    raise ValueError("API key not found in userdata['GEMINI'].")

# Configure the client with the API key
genai.configure(api_key=GOOGLE_API_KEY)

# List available models and print their names
models = genai.list_models()
for model in models:
    print(model.name)

# Choose the appropriate Gemini 2.0 model from the list above
model = genai.GenerativeModel(model_name='models/gemini-2.0-flash-exp')

print()
# Example 1: Simple text generation with Gemini 2.0
prompt = "Write a short story about a cat who goes on an adventure in a hot air balloon."
response = model.generate_content(contents=[prompt])
print(response.text)

print()

# Example 2: Code generation with Gemini 2.0
prompt = "Write a Python function to calculate the factorial of a number."
response = model.generate_content(
    contents=[prompt],
)
print(response)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-pro-exp-0827
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-exp-0827
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.0-flash-exp
# models/gemini-exp-1206
# models/gemini-exp-1121
# models/gemini-exp-1114
# models/learnlm-1.5-pro-experimental
# models/embedding-001
# models/text-embedding-004
# models/aqa
#
# Clementine, a calico cat of discerning taste and a penchant for napping in sunbeams, was not a creature of adventure. Or so she thought. Her days were a gentle rhythm of purrs, head-butts, and chasing dust bunnies. That is, until the day the giant, colorful bubble appeared in her backyard.
#
# It wasn't just any bubble, of course. It was a hot air balloon, vibrant stripes of red, yellow, and blue billowing in the gentle breeze. A kindly old man, his face etched with the maps of a thousand smiles, was tethering it to the rose bush. He looked like someone who told secrets to the wind.
#
# Clementine, usually aloof, was captivated. Her emerald eyes widened as the balloon swayed, the wicker basket beneath looking suspiciously like the perfect napping spot. Curiosity, a foreign but exhilarating sensation, pricked her whiskers.
#
# Before she knew it, she'd leaped into the basket. The old man, startled but amused, chuckled. "Well, hello there, little traveler," he said, his voice like warm honey. "Ready for an adventure?"
#
# Clementine, usually so reserved, didn't object. The burner roared, the balloon began to lift, and Clementine's carefully curated world turned upside down.
#
# Below, the familiar garden shrank into a patchwork of green and color. Clementine gripped the edge of the basket, her claws sinking slightly into the wicker. She'd never been so high, so…uncontrolled. A bird swooped past, its song a tiny melody in the vast blue. Clementine puffed up, a mix of fear and excitement making her fur stand on end.
#
# The old man, whose name she learned was Silas, pointed out landmarks below: a shimmering river, a field of sunflowers that looked like a carpet of gold, a tiny town where houses huddled together like sleeping kittens. He even shared a piece of dried fish, which Clementine, in her newfound adventurous spirit, devoured with gusto.
#
# As they floated, Clementine started to relax. She sat back, her tail curling around her paws, and let the wind ruffle her fur. The sun warmed her coat, and she discovered the joy of just being. The world felt so big, and she, a little cat, was a part of it. She even chased a stray butterfly that dared to venture too close to the basket, batting at it with playful swipes.
#
# They drifted over forests that stretched for miles and sparkling lakes where ducks made tiny ripples on the surface. Clementine saw things she never knew existed, colors she'd never imagined. She felt like a tiny queen surveying her kingdom.
#
# After what felt like an eternity of wonder, Silas began to descend, gently easing the balloon back to earth. They landed softly in a field of clover, the balloon sighing as the hot air escaped.
#
# Back on the ground, Clementine stretched, her legs feeling a little wobbly. She looked up at the giant deflated balloon, a shadow of its former glory. She turned to Silas and, for the first time, rubbed against his leg, purring loudly.
#
# Silas smiled. "You were a wonderful co-pilot, Clementine," he said, scratching her behind the ears. "Perhaps we'll go again soon?"
#
# Clementine, usually so predictable, didn't answer with a head-butt, or a rub, or a purr. Instead, she simply looked out at the vast horizon, her emerald eyes full of a newfound light. She was still Clementine, the calico cat who loved sunbeams, but she was also Clementine, the adventurer who had flown amongst the clouds. And she knew, deep in her feline heart, that this was only the beginning of her explorations.
#
#
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "```python\ndef factorial(n):\n  \"\"\"\n  Calculates the factorial of a non-negative integer.\n\n  Args:\n    n: A non-negative integer.\n\n  Returns:\n    The factorial of n (n!). Returns 1 if n is 0.\n    Raises a ValueError if n is negative.\n  \"\"\"\n  if n < 0:\n    raise ValueError(\"Factorial is not defined for negative numbers.\")\n  elif n == 0:\n    return 1\n  else:\n    result = 1\n    for i in range(1, n + 1):\n      result *= i\n    return result\n\nif __name__ == '__main__':\n    # Test cases\n    print(f\"Factorial of 0: {factorial(0)}\")  # Output: 1\n    print(f\"Factorial of 1: {factorial(1)}\")  # Output: 1\n    print(f\"Factorial of 5: {factorial(5)}\")  # Output: 120\n    print(f\"Factorial of 10: {factorial(10)}\") # Output: 3628800\n\n    try:\n      print(f\"Factorial of -1: {factorial(-1)}\")\n    except ValueError as e:\n      print(f\"Error: {e}\")  # Output: Error: Factorial is not defined for negative numbers.\n\n```\n\n**Explanation:**\n\n1. **Function Definition:**\n   - `def factorial(n):` defines a function named `factorial` that takes one argument `n` (the number for which we want to calculate the factorial).\n\n2. **Error Handling (Negative Input):**\n   - `if n < 0:`: It checks if the input number `n` is negative. Factorials are not defined for negative numbers.\n   - `raise ValueError(\"Factorial is not defined for negative numbers.\")`: If `n` is negative, a `ValueError` is raised with an informative error message. This stops the function execution and alerts the user to the invalid input.\n\n3. **Base Case (0!):**\n   - `elif n == 0:`: If `n` is 0, the function returns 1 because the factorial of 0 is defined as 1. This is a base case for the recursive process (which is not used here but can be).\n\n4. **Iterative Calculation:**\n   - `else:`: If `n` is a positive integer, the code enters this block.\n   - `result = 1`: A variable `result` is initialized to 1. This will store the factorial value.\n   - `for i in range(1, n + 1):`: A `for` loop iterates from 1 up to `n` (inclusive).\n   - `result *= i`: Inside the loop, `result` is multiplied by the current value of `i`. This cumulatively calculates the factorial (1 * 2 * 3 * ... * n).\n   - `return result`: Finally, the calculated `result` (the factorial of `n`) is returned.\n\n5. **Test Cases (in `if __name__ == '__main__':`)**\n   - `if __name__ == '__main__':` ensures that the code block inside only executes when the script is run directly. This allows you to add test examples within the file.\n   - Test cases with expected outputs are printed to the console.\n   - An error case is tested to show the `ValueError` is raised when trying to calculate the factorial of a negative number.\n\n**How the Factorial is Calculated:**\n\nThe factorial of a non-negative integer `n`, denoted as `n!`, is the product of all positive integers less than or equal to `n`. \n\nFor example:\n- 5! = 5 * 4 * 3 * 2 * 1 = 120\n- 0! = 1 (by definition)\n- Factorials are not defined for negative integers.\n\nThis function uses an iterative approach to calculate the factorial. You could also calculate the factorial recursively; however, the iterative approach is usually more efficient for larger numbers as it avoids recursion stack limits.\n"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "safety_ratings": [
#             {
#               "category": "HARM_CATEGORY_HATE_SPEECH",
#               "probability": "NEGLIGIBLE"
#             },
#             {
#               "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
#               "probability": "NEGLIGIBLE"
#             },
#             {
#               "category": "HARM_CATEGORY_HARASSMENT",
#               "probability": "NEGLIGIBLE"
#             },
#             {
#               "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
#               "probability": "NEGLIGIBLE"
#             }
#           ],
#           "citation_metadata": {
#             "citation_sources": [
#               {
#                 "start_index": 3,
#                 "end_index": 164
#               },
#               {
#                 "start_index": 164,
#                 "end_index": 344
#               },
#               {
#                 "start_index": 282,
#                 "end_index": 460,
#                 "uri": "https://github.com/gpt-engineer-org/gpt-engineer"
#               },
#               {
#                 "start_index": 2687,
#                 "end_index": 2819,
#                 "uri": "https://promptbase.com/prompt/code-explainer-assistant"
#               },
#               {
#                 "start_index": 2728,
#                 "end_index": 2879
#               }
#             ]
#           },
#           "avg_logprobs": -0.26311896045135097
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 13,
#         "candidates_token_count": 916,
#         "total_token_count": 929
#       }
#     }),
# )
