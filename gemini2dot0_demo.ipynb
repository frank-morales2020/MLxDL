# %% [markdown]
# <a href="https://colab.research.google.com/github/frank-morales2020/MLxDL/blob/main/gemini2dot0_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install colab-env --quiet
# !pip install google-generativeai --quiet

import colab_env
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for colab-env (setup.py) ... done
# Mounted at /content/gdrive

# %%
import google.generativeai as genai
from google.colab import userdata

# Retrieve API key from userdata
GOOGLE_API_KEY = userdata.get('GEMINI')

# Check if API key is retrieved successfully
if GOOGLE_API_KEY is None:
    raise ValueError("API key not found in userdata['GEMINI'.")

# Configure the client with the API key
genai.configure(api_key=GOOGLE_API_KEY)

# List available models and print their names
models = genai.list_models()
for model in models:
    print(model.name)

# Choose the appropriate Gemini 2.0 model from the list above
model = genai.GenerativeModel(model_name='models/gemini-2.0-flash-exp')

print()
print('Example 1: Simple text generation with Gemini 2.0')
prompt = "Write a short story about a cat who goes on an adventure in a hot air balloon."
response = model.generate_content(contents=[prompt])
print(response.text)

print()
print('Example 2: Code generation with Gemini 2.0')
prompt = "Write a Python function to calculate the factorial of a number."
response = model.generate_content(
    contents=[prompt],
)
print(response.text)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-pro-exp-0827
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-exp-0827
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.0-flash-exp
# models/gemini-exp-1206
# models/gemini-exp-1121
# models/gemini-exp-1114
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/learnlm-1.5-pro-experimental
# models/embedding-001
# models/text-embedding-004
# models/aqa
#
# Example 1: Simple text generation with Gemini 2.0
# Clementine was, by all accounts, a rather ordinary tabby cat. She enjoyed sunbeams, chasing dust bunnies, and napping in cardboard boxes. But Clementine harbored a secret longing for something more, something beyond the confines of her suburban backyard. She dreamed of the fluffy white clouds that drifted lazily across the sky.
#
# One crisp autumn morning, while her humans were preoccupied with preparing for a local festival, Clementine spotted it: a magnificent, striped hot air balloon tethered in the adjacent field. The vibrant fabric rippled in the gentle breeze, beckoning her closer. Curiosity, a powerful feline motivator, got the better of her.
#
# Slipping through the unlatched gate, Clementine padded towards the behemoth. The air was thick with the smell of propane and the murmur of excited voices. A low wooden basket sat beneath the enormous balloon, its wicker weave a tempting scratching post. With a nimble leap, she landed inside.
#
# The crew, busy with their final preparations, hadn't noticed the small stowaway. The roar of the burner startled her, making her fur stand on end, but the thrill of the unknown kept her rooted to the spot. Suddenly, the basket lurched, and Clementine felt the ground fall away beneath her paws.
#
# They were rising! The field shrank into a patchwork quilt of green and gold. Clementine peered over the edge, her green eyes wide with wonder. Below, cars looked like tiny toys and houses resembled miniature blocks. The wind whipped through her whiskers, carrying the scent of crisp leaves and distant woodsmoke.
#
# The view was breathtaking. Clementine had never seen anything like it. She watched as birds soared below her, their silhouettes stark against the blue sky. They looked so small! It was a perspective she’d never imagined. She felt a strange mix of fear and exhilaration.
#
# The balloon drifted silently over rolling hills, the landscape changing from farm fields to patches of forest. Clementine, no longer just a housecat, felt like a daring explorer. She even managed a dignified sniff at the open flame of the burner, quickly deciding it was far too hot to investigate further.
#
# She spent the next hour mesmerized by the world unfolding beneath her. She saw a flock of sheep scattering across a field, a meandering river snaking its way through the valley, and a group of people waving excitedly from a hilltop.  She even saw another cat lounging on a window ledge, seemingly unimpressed with her skyward adventure.
#
# As the sun began to dip towards the horizon, painting the sky in fiery hues, the pilot began to descend. The gentle descent was just as thrilling as the ascent. Finally, with a soft bump, the balloon landed back in the field.
#
# Clementine, a little dusty but full of the thrill of adventure, hopped out of the basket as the crew deflated the giant fabric above.  She stretched, shook her fur, and took one last look at the magnificent balloon before padding back towards the familiar comfort of her home.
#
# Back in her own backyard, curled up in her favorite sunbeam, Clementine wasn't quite the same ordinary cat. She still enjoyed sunbeams and chasing dust bunnies, but now she carried a secret within her – the memory of flying above the world, a silent, striped adventurer soaring through the sky.  And every time she looked up at the clouds, she would remember the day she went on the greatest adventure of her nine lives, aboard a hot air balloon. And maybe, just maybe, she’d start dreaming of flying again.
#
#
# Example 2: Code generation with Gemini 2.0
# ```python
# def factorial(n):
#   """
#   Calculates the factorial of a non-negative integer.
#
#   Args:
#     n: A non-negative integer.
#
#   Returns:
#     The factorial of n (n!), or 1 if n is 0.
#     Raises a ValueError if n is negative.
#   """
#   if n < 0:
#     raise ValueError("Factorial is not defined for negative numbers.")
#   elif n == 0:
#     return 1
#   else:
#     result = 1
#     for i in range(1, n + 1):
#       result *= i
#     return result
#
# if __name__ == '__main__':
#   # Example usage
#   print(f"Factorial of 0 is: {factorial(0)}")
#   print(f"Factorial of 1 is: {factorial(1)}")
#   print(f"Factorial of 5 is: {factorial(5)}")
#   print(f"Factorial of 10 is: {factorial(10)}")
#
#   try:
#     print(f"Factorial of -1 is: {factorial(-1)}")  # This will raise a ValueError
#   except ValueError as e:
#     print(f"Error: {e}")
# ```
#
# **Explanation:**
#
# 1. **Function Definition:**
#    - The code defines a function called `factorial(n)` that takes one argument, `n`, which is expected to be a non-negative integer.
#    - It includes a docstring that explains the purpose of the function, its arguments, and what it returns.
#
# 2. **Error Handling:**
#    - It first checks if `n` is negative using `if n < 0:`. If it is, it raises a `ValueError` with a message indicating that factorials are not defined for negative numbers. This is important for robust code.
#
# 3. **Base Case:**
#    - If `n` is 0, the function returns 1 because the factorial of 0 is defined as 1. This is the base case for the recursive definition of factorials.
#
# 4. **Iterative Calculation:**
#    - If `n` is a positive integer, the function uses a `for` loop to calculate the factorial iteratively.
#    - `result` is initialized to 1.
#    - The loop iterates from 1 to `n` (inclusive).
#    - In each iteration, `result` is multiplied by the current value of `i`.
#    - After the loop completes, `result` contains the factorial of `n`.
#
# 5. **Return Value:**
#    - Finally, the function returns the calculated `result`.
#
# 6. **Example Usage:**
#    - The `if __name__ == '__main__':` block demonstrates how to use the `factorial` function.
#    - It calls the function with different input values and prints the results.
#    - It also includes a `try-except` block to show how the `ValueError` is handled when a negative input is provided.
#
# **Key Concepts Used:**
#
# - **Function Definition:** Creating reusable blocks of code.
# - **Error Handling:** Using `ValueError` to handle invalid inputs.
# - **Conditional Statements (`if`, `elif`, `else`):**  Controlling the flow of execution based on conditions.
# - **Loops (`for`):**  Iterating through a sequence of values.
# - **Iteration:** Performing actions repeatedly.
# - **Docstrings:** Providing clear documentation within the code.
# - **`if __name__ == '__main__':`:** Ensures that the example usage block only runs when the script is executed directly (not when it's imported as a module).
#
# This function provides a clear, efficient, and well-documented way to calculate factorials in Python.
