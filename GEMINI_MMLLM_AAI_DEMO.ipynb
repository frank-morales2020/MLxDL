# %% [markdown]
# <a href="https://colab.research.google.com/github/frank-morales2020/MLxDL/blob/main/GEMINI_MMLLM_AAI_DEMO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import requests
from PIL import Image
from io import BytesIO
import google.generativeai as genai # Import the generativeai library

# --- 1. Configuration for Agent ---
class AgentConfig:
    LLM_MODEL_NAME: str = "gemini-2.5-flash"
    MAX_AGENT_RETRIES: int = 2 # Max attempts for the agent to refine its answer

# --- 2. Google Colab / Gemini API Imports and Configuration ---
GOOGLE_API_KEY = None
try:
    from google.colab import userdata
    GOOGLE_API_KEY = userdata.get('GEMINI')
    print("Google Generative AI configured successfully using Colab Secrets.")
except (ImportError, KeyError):
    print("Not running in Google Colab or 'GEMINI' secret not found. Attempting to get 'GEMINI' environment variable.")
    GOOGLE_API_KEY = os.getenv('GEMINI')

# Initialize Gemini API
if GOOGLE_API_KEY:
    genai.configure(api_key=GOOGLE_API_KEY)
    print(f"Gemini API configured with model: {AgentConfig.LLM_MODEL_NAME}")
else:
    print("Warning: GOOGLE_API_KEY not found. LLM calls will not work.")
    print("Please set your 'GEMINI' environment variable or Colab secret.")


# --- 3. Data Ingestion & Indexing (Multimodal RAG Setup) ---

# Define KNOWLEDGE_BASE_DIR and VECTOR_DB_PATH outside the class if they are global
KNOWLEDGE_BASE_DIR = "knowledge_base_documents/" # Directory for your documents (text, images, etc.)
VECTOR_DB_PATH = "your_vector_db_path/" # e.g., for FAISS local storage (not used in this simplified example)


class MultimodalKnowledgeBase:
    def __init__(self, vector_db_path):
        self.vector_db_path = vector_db_path
        self.text_retriever = None
        self.image_retriever = None
        if GOOGLE_API_KEY:
            # Use a currently supported multimodal model for captioning
            # Corrected: Using gemini-1.5-flash as recommended by deprecation message
            self.image_captioning_model = genai.GenerativeModel('gemini-1.5-flash')
        else:
            print("Error: GOOGLE_API_KEY not set. Cannot initialize image captioning model.")
            self.image_captioning_model = None

    def load_documents(self, directory):
        """Loads and processes documents (text, images) into a vector store."""
        text_documents = []
        image_documents = [] # Store image paths and potentially their generated captions

        for filename in os.listdir(directory):
            filepath = os.path.join(directory, filename)
            if filename.endswith(".txt") or filename.endswith(".pdf"):
                with open(filepath, 'r', encoding='utf-8') as f:
                    content = f.read()
                    text_documents.append({"content": content, "source": filepath})
            elif filename.endswith((".jpg", ".png", ".jpeg")):
                # Only try to generate caption if the captioning model is available
                if self.image_captioning_model:
                    caption = self._generate_image_caption(filepath)
                    image_documents.append({"path": filepath, "caption": caption})
                else:
                    print(f"Skipping caption for {filepath} as captioning model is not initialized.")


        # Create/Load Vector Stores (placeholders for actual implementation)
        print(f"Loaded {len(text_documents)} text documents and {len(image_documents)} image documents.")

    def _generate_image_caption(self, image_path):
        """Generates image captions using a multi-modal LLM."""
        if not self.image_captioning_model:
            return f"Captioning model not available for image at {image_path}"
        try:
            img = Image.open(image_path).convert('RGB') # Ensure consistent image format
            response = self.image_captioning_model.generate_content(["Describe this image in detail for a flight planning context.", img])
            return response.text
        except Exception as e:
            print(f"Error generating caption for {image_path}: {e}")
            return f"Could not generate caption for image at {image_path}"

    def retrieve_text(self, query: str, k: int = 3):
        """Retrieves relevant text chunks based on query."""
        print(f"Retrieving text for query: '{query}'")
        return [f"Relevant text chunk 1 for '{query}' (from regulations.txt - Pilots must have valid licenses. Weather conditions must be VFR or IFR compliant. Fuel reserves are mandatory. Airspace classifications dictate specific procedures.)",
                f"Relevant text chunk 2 for '{query}' (from schedules.txt - Montreal (YUL) operates 24/7. Toronto (YYZ) has peak hours from 0600-0900 and 1700-2000 local time.)"]

    def retrieve_images(self, query: str, k: int = 3):
        """Retrieves relevant image captions/paths based on query.
           Only includes images that are actually expected to exist.
        """
        print(f"Retrieving images for query: '{query}'")
        # Ensure the path exists for the dummy image that WE explicitly created.
        dummy_image_path = os.path.join(KNOWLEDGE_BASE_DIR, "yul_airport_map.png")
        retrieved_image_list = []

        if os.path.exists(dummy_image_path):
            # We assume a caption has been generated for it during load_documents
            # In a real RAG, this would come from your vector store, associated with the image.
            # For this simplified example, we'll use a hardcoded caption or regenerate if needed.
            # For demonstration, we'll use a placeholder caption if _generate_image_caption
            # was not called or failed during load_documents.
            caption = "A map of Montreal Trudeau International Airport (YUL), showing runways, terminals, and taxiways, with a red circular marker and a gray rectangular building."
            retrieved_image_list.append({"path": dummy_image_path, "caption": caption})

        return retrieved_image_list

# --- 4. Agentic LLM for Multi-Modal Reasoning & Planning ---

class FlightPlanningAgent:
    def __init__(self, knowledge_base: MultimodalKnowledgeBase):
        self.knowledge_base = knowledge_base
        if GOOGLE_API_KEY:
            self.llm = genai.GenerativeModel(AgentConfig.LLM_MODEL_NAME)
        else:
            print(f"Error: GOOGLE_API_KEY not set. Cannot initialize agent LLM ({AgentConfig.LLM_MODEL_NAME}).")
            self.llm = None

    def _call_llm(self, prompt, image_inputs=None):
        """Helper to interact with the LLM, handling multimodal input."""
        if not self.llm: # Check if LLM was initialized
            print("LLM not initialized due to missing API key. Cannot make API call.")
            return "ERROR: LLM not available."

        contents = [prompt]
        if image_inputs:
            for img_data in image_inputs:
                try:
                    img = Image.open(img_data['path']).convert('RGB')
                    contents.append(img)
                    print(f"Adding image: {img_data['path']} (caption: {img_data['caption'][:50]}...)")
                except FileNotFoundError:
                    print(f"Warning: Image file not found at {img_data['path']}. Skipping.")
                except Exception as e:
                    print(f"Error loading image {img_data['path']}: {e}. Skipping.")

        print(f"\n--- LLM Call ---")
        print(f"Prompt (first 200 chars): {prompt[:200]}...")

        try:
            response = self.llm.generate_content(contents)
            llm_response_text = response.text
        except Exception as e:
            print(f"LLM API error: {e}")
            llm_response_text = "ERROR: Could not get a response from the LLM."

        print(f"LLM Response (first 200 chars): {llm_response_text[:200]}...")
        return llm_response_text

    def plan_flight(self, user_query: str):
        """
        Main agentic loop for flight planning.
        Incorporates reasoning, RAG, and multi-modal handling.
        """
        print(f"\n--- Agent Starting: Processing query '{user_query}' ---")

        for attempt in range(AgentConfig.MAX_AGENT_RETRIES):
            print(f"\n--- Attempt {attempt + 1}/{AgentConfig.MAX_AGENT_RETRIES} ---")

            initial_prompt = f"""
            You are an AI flight planning assistant using Gemini 2.5 Flash. Your goal is to provide accurate, detailed, and hallucination-free flight plans.
            The user has provided the following query: "{user_query}"

            First, analyze the query to determine what information is needed and what tools (retrieval from knowledge base, external APIs) might be useful.
            Consider if multi-modal information (e.g., airport maps, weather charts) would be beneficial.
            Formulate a detailed plan to gather necessary information and then synthesize it into a comprehensive flight plan.
            Your response should be a plan of action, not the final flight plan yet.
            """
            agent_plan = self._call_llm(initial_prompt)
            print(f"Agent's Initial Plan: {agent_plan}")

            retrieval_query_text = f"Flight regulations, schedules, and airport information for {user_query}."
            retrieved_text = self.knowledge_base.retrieve_text(retrieval_query_text)
            print(f"Retrieved Text: {retrieved_text}")

            retrieval_query_image = f"Airport maps or relevant weather charts for {user_query}."
            retrieved_images = self.knowledge_base.retrieve_images(retrieval_query_image)
            print(f"Retrieved Images (Captions): {[img['caption'] for img in retrieved_images]}")

            retrieved_text_formatted = '\n- '.join(retrieved_text)
            retrieved_images_formatted = '\n- '.join([img['caption'] for img in retrieved_images]) if retrieved_images else "No relevant images found."

            reasoning_prompt = f"""
            Based on the user query: "{user_query}"
            And the following retrieved text information:
            - {retrieved_text_formatted}
            And the following retrieved visual information (from image captions and the images themselves, if provided):
            - {retrieved_images_formatted}

            Please synthesize all this information.
            Formulate a comprehensive flight plan or a detailed answer to the user's query.
            Crucially, ensure ALL claims are strictly grounded in the provided retrieved data. DO NOT introduce any information not present in the retrieved text or images.
            If you cannot fully answer or if information is contradictory, state that clearly and explain why.
            """
            final_response = self._call_llm(reasoning_prompt, image_inputs=retrieved_images)

            retrieved_text_for_verification = '\n- '.join(retrieved_text)
            retrieved_images_for_verification = '\n- '.join([img['caption'] for img in retrieved_images]) if retrieved_images else "No relevant images found."


            verification_prompt = f"""
            Review the following proposed flight plan/response:
            "{final_response}"

            And compare it strictly against the retrieved information provided earlier:
            Retrieved Text:
            - {retrieved_text_for_verification}
            Retrieved Image Descriptions:
            - {retrieved_images_for_verification}

            Does this proposed response strictly adhere to the retrieved information?
            Are there any unsupported claims, details that seem fabricated, or inconsistencies?
            Provide a "VERIFICATION STATUS: OK" if it's perfectly grounded, or "VERIFICATION STATUS: NEEDS REVISION" followed by specific points of discrepancy and suggestions for correction.
            Be very critical and explicit about any potential hallucinations or ungrounded statements.
            """
            verification_result = self._call_llm(verification_prompt)
            print(f"\n--- Verification Result: {verification_result} ---")

            if "VERIFICATION STATUS: OK" in verification_result:
                print("\nFlight plan verified. Ready to present.")
                return final_response
            else:
                print("\nWARNING: Hallucination detected or potential inaccuracy. Agent is attempting to re-evaluate and refine.")
                user_query = f"Refine the flight plan for: '{user_query}' based on this feedback: {verification_result}"
                final_response = "Refinement in progress..."
                if attempt == AgentConfig.MAX_AGENT_RETRIES - 1:
                    print(f"\nMax retries reached. Final (potentially unverified) response:")
                    return final_response + f"\n\nNote: The agent could not fully verify this response due to: {verification_result}"
        return "Failed to generate a verified flight plan after multiple retries."


# --- Main Execution ---
if __name__ == "__main__":
    # Ensure google.generativeai is imported
    import google.generativeai as genai

    # Create a dummy knowledge base directory and files for demonstration
    os.makedirs(KNOWLEDGE_BASE_DIR, exist_ok=True)
    with open(os.path.join(KNOWLEDGE_BASE_DIR, "flight_regulations.txt"), "w") as f:
        f.write("Standard flight regulations: Pilots must have valid licenses. Weather conditions must be VFR or IFR compliant. Fuel reserves are mandatory. Airspace classifications dictate specific procedures.")
    with open(os.path.join(KNOWLEDGE_BASE_DIR, "airport_schedules.txt"), "w") as f:
        f.write("Montreal (YUL) operates 24/7. Toronto (YYZ) has peak hours from 0600-0900 and 1700-2000 local time. New York (JFK) has special noise abatement procedures.")

    # Explicitly create ONLY the yul_airport_map.png as previously agreed.
    yul_map_path = os.path.join(KNOWLEDGE_BASE_DIR, 'yul_airport_map.png')
    try:
        from PIL import Image
        from PIL import ImageDraw
        img = Image.new('RGB', (600, 400), color = 'lightblue')
        draw = ImageDraw.Draw(img)
        draw.ellipse((100, 100, 200, 200), fill='red', outline='red') # Mock runway
        draw.rectangle((300, 150, 400, 250), fill='gray', outline='black') # Mock terminal
        img.save(yul_map_path)
        print(f"Created dummy image: {yul_map_path}")
    except ImportError:
        print("Pillow not installed. Cannot create dummy image. Image retrieval will be less illustrative.")


    kb = MultimodalKnowledgeBase(VECTOR_DB_PATH)
    kb.load_documents(KNOWLEDGE_BASE_DIR)

    agent = FlightPlanningAgent(kb)

    user_query_1 = "Plan a flight from Montreal to Toronto tomorrow, considering weather and airspace."
    plan_1 = agent.plan_flight(user_query_1)
    print(f"\nFinal Flight Plan 1: {plan_1}")

    user_query_2 = "Tell me about the historical average rainfall in Paris in 1850 for flight planning purposes."
    plan_2 = agent.plan_flight(user_query_2)
    print(f"\nFinal Flight Plan 2: {plan_2}")
# Out:
# Google Generative AI configured successfully using Colab Secrets.
# Gemini API configured with model: gemini-2.5-flash
# Created dummy image: knowledge_base_documents/yul_airport_map.png
# Loaded 2 text documents and 1 image documents.
#
# --- Agent Starting: Processing query 'Plan a flight from Montreal to Toronto tomorrow, considering weather and airspace.' ---
#
# --- Attempt 1/2 ---
#
# --- LLM Call ---
# Prompt (first 200 chars):
#             You are an AI flight planning assistant using Gemini 2.5 Flash. Your goal is to provide accurate, detailed, and hallucination-free flight plans.
#             The user has provided the foll...
# LLM Response (first 200 chars): The user requires a flight plan from Montreal to Toronto for "tomorrow," incorporating weather and airspace considerations. This involves gathering dynamic, real-time aviation data and applying a stru...
# Agent's Initial Plan: The user requires a flight plan from Montreal to Toronto for "tomorrow," incorporating weather and airspace considerations. This involves gathering dynamic, real-time aviation data and applying a structured planning process.
#
# Here's a detailed plan of action to gather the necessary information and synthesize it into a comprehensive flight plan:
#
# **1. Query Analysis & Initial Setup:**
#
# *   **Origin:** Montreal (Likely CYUL - Montreal-Trudeau International Airport). I will assume CYUL.
# *   **Destination:** Toronto (Likely CYYZ - Toronto Pearson International Airport). I will assume CYYZ.
# *   **Date/Time:** "Tomorrow." This requires determining the specific date and a reasonable estimated time of departure (ETD) to fetch accurate forecasts and NOTAMs. I will assume a morning departure (e.g., 10:00 AM local time tomorrow) for planning purposes.
# *   **Key Considerations:** Weather and Airspace. This mandates retrieving real-time meteorological and aeronautical information.
#
# **2. Information Gathering Plan:**
#
# To ensure accuracy and comprehensive coverage, I will virtually access and process data from the following categories, simulating API calls and knowledge base lookups:
#
#     *   **Tool/Method:** Retrieval from Aviation Weather APIs, NOTAM databases, Aeronautical Information Publications (AIPs), and charting services. Multi-modal information (e.g., weather charts, airport diagrams, en-route charts) will be crucial.
#
#     **Phase 1: Determine Date and Time of Interest**
#     *   Confirm "tomorrow's" specific date.
#     *   Establish a reasonable estimated time of departure (ETD) for planning purposes (e.g., 10:00 AM local time). This ETD will define the validity period for weather forecasts and NOTAMs.
#
#     **Phase 2: Airport and Airspace Information Retrieval**
#     *   **A. Aerodrome Information (CYUL & CYYZ):**
#         *   **ICAO Codes:** Confirm CYUL (Montreal-Trudeau) and CYYZ (Toronto Pearson).
#         *   **Airport Diagrams:** Retrieve multi-modal visual data (charts) for taxiways, runways, and parking areas for both airports.
#         *   **Available Approaches/Departures:** Identify common Instrument Departure Procedures (SIDs) for CYUL and Standard Terminal Arrival Routes (STARs) for CYYZ. (Knowledge base + chart retrieval).
#         *   **Typical Runways in Use:** Assess prevailing winds for typical runway configurations at both airports based on historical data, and cross-reference with forecast winds.
#     *   **B. En-route Airspace:**
#         *   **Canadian Airspace Structure:** Understand the Flight Information Region (FIR) boundaries and major air routes (Victor Airways, Jet Routes) between Montreal and Toronto.
#         *   **Preferred Routes:** Check for any published preferred IFR routes between CYUL and CYYZ. (Knowledge base + AIP retrieval).
#         *   **Waypoint Data:** Retrieve coordinates for key navigational waypoints along potential routes.
#
#     **Phase 3: Weather Information Retrieval (Crucial for "Tomorrow")**
#     *   **A. Current Conditions (For Context & Trend Analysis):**
#         *   **METARs:** Retrieve current Meteorological Aerodrome Reports for CYUL, CYYZ, and potential alternate airports.
#         *   **PIREPs:** Check for any recent Pilot Reports along the route.
#     *   **B. Forecast Conditions (Primary Focus for "Tomorrow"):**
#         *   **TAFs (Terminal Aerodrome Forecasts):** Retrieve TAFs for CYUL and CYYZ valid for "tomorrow's" flight window (approx. 2 hours before ETD to 2 hours after ETA). This includes wind, visibility, cloud layers, and significant weather.
#         *   **Winds Aloft Forecast (FD):** Retrieve forecast winds and temperatures at various altitudes (e.g., 3,000, 6,000, 9,000, 12,000, 18,000, 24,000, 30,000, 34,000 feet) along the route, for optimum altitude selection and fuel planning.
#         *   **Area Forecasts / Graphical Forecasts for Aviation (GFA):** Retrieve broader weather patterns, including fronts, pressure systems, icing, turbulence, and mountain obscuration along the entire route. (Multi-modal retrieval for visual charts).
#         *   **SIGMETs (Significant Meteorological Information):** Check for forecasts of severe weather phenomena (thunderstorms, severe turbulence, severe icing, widespread dust/sandstorms, volcanic ash) affecting the route.
#         *   **AIRMETs (Airmen's Meteorological Information):** Check for forecasts of less severe but potentially hazardous weather (moderate icing, moderate turbulence, widespread instrument meteorological conditions, strong surface winds).
#     *   **C. Alternate Airport Weather:** Identify at least one suitable alternate airport (e.g., Ottawa - CYOW, Syracuse - KSYR if crossing border) and retrieve its TAF for the flight window + 1 hour. This is a regulatory requirement for IFR flights.
#
#     **Phase 4: NOTAM Retrieval (Notices to Airmen)**
#     *   **A. Aerodrome NOTAMs:** Retrieve all active NOTAMs for CYUL and CYYZ, including:
#         *   Runway/taxiway closures or restrictions.
#         *   NAV-AID unserviceability.
#         *   Airport lighting issues.
#         *   Special procedures.
#     *   **B. En-route NOTAMs:** Retrieve NOTAMs for the FIRs covering the route (e.g., Montreal FIR, Toronto FIR), including:
#         *   Temporary Flight Restrictions (TFRs).
#         *   Active military operating areas (MOAs).
#         *   Unserviceable NAV-AIDs along the route.
#         *   Airspace restrictions.
#
# **3. Synthesis and Analysis Plan (Leading to the Flight Plan):**
#
# Once all information is gathered, I will synthesize it systematically:
#
#     *   **A. Route Selection:**
#         *   Based on preferred routes, SIDs from CYUL, STARs into CYYZ, and current/forecast winds, determine the most efficient and safe en-route segment (e.g., via airways or direct waypoints).
#         *   Consider weather avoidance (e.g., thunderstorms, strong headwinds/tailwinds).
#         *   Check for any NOTAMs impacting selected route segments (e.g., unserviceable NAVAIDs).
#     *   **B. Altitude Selection:**
#         *   Analyze Winds Aloft forecasts to select the most favorable cruising altitude for fuel efficiency (tailwinds) or turbulence avoidance.
#         *   Consider minimum en-route altitudes (MEAs) and maximum authorized altitudes for selected airways.
#         *   Account for terrain clearance.
#     *   **C. Performance Considerations (General):**
#         *   Estimate flight time based on typical commercial jet speeds and the chosen route/altitude. (If an aircraft type were specified, I would simulate performance calculations more precisely).
#         *   Roughly estimate fuel requirements for the primary route, holding, and diversion to an alternate.
#     *   **D. Alternate Airport Determination:**
#         *   Based on TAFs for destination and potential alternates, select a suitable alternate airport that meets IFR alternate weather minimums for the estimated arrival time.
#     *   **E. Risk Assessment:**
#         *   Identify any significant weather hazards (icing, turbulence, thunderstorms) that could impact the flight.
#         *   Identify any operational restrictions from NOTAMs that might require route or procedure changes.
#         *   Formulate contingency plans (e.g., holding procedures, diversion points).
#
# **4. Final Flight Plan Formulation (Content of the eventual output):**
#
# The final output, once the above steps are completed, would include:
#
# *   **Header:** Flight details (origin, destination, date, estimated ETD/ETA).
# *   **Route:** Detailed sequence of SIDs, waypoints, airways, and STARs.
# *   **Altitude & Speed:** Recommended cruising altitude(s) and estimated ground speed/true airspeed.
# *   **Weather Summary:** Concise summary of METARs, TAFs (for departure, en-route, destination, alternate), Winds Aloft, and any relevant SIGMETs/AIRMETs or GFA insights (e.g., clear skies, light chop, potential for isolated showers).
# *   **NOTAM Summary:** Key operational NOTAMs affecting aerodromes or en-route airspace.
# *   **Estimated Flight Time:** Block time and airborne time.
# *   **Fuel Estimate:** Required fuel for destination, reserve, and alternate.
# *   **Alternate Airport:** Designated alternate airport with brief weather outlook.
# *   **Remarks/Contingencies:** Any specific instructions, warnings, or alternative plans based on analysis.
#
# By following this detailed plan, I can ensure a robust, accurate, and comprehensive flight planning process, minimizing the risk of hallucinations by relying on specific data retrieval and structured analysis.
# Retrieving text for query: 'Flight regulations, schedules, and airport information for Plan a flight from Montreal to Toronto tomorrow, considering weather and airspace..'
# Retrieved Text: ["Relevant text chunk 1 for 'Flight regulations, schedules, and airport information for Plan a flight from Montreal to Toronto tomorrow, considering weather and airspace..' (from regulations.txt - Pilots must have valid licenses. Weather conditions must be VFR or IFR compliant. Fuel reserves are mandatory. Airspace classifications dictate specific procedures.)", "Relevant text chunk 2 for 'Flight regulations, schedules, and airport information for Plan a flight from Montreal to Toronto tomorrow, considering weather and airspace..' (from schedules.txt - Montreal (YUL) operates 24/7. Toronto (YYZ) has peak hours from 0600-0900 and 1700-2000 local time.)"]
# Retrieving images for query: 'Airport maps or relevant weather charts for Plan a flight from Montreal to Toronto tomorrow, considering weather and airspace..'
# Retrieved Images (Captions): ['A map of Montreal Trudeau International Airport (YUL), showing runways, terminals, and taxiways, with a red circular marker and a gray rectangular building.']
# Adding image: knowledge_base_documents/yul_airport_map.png (caption: A map of Montreal Trudeau International Airport (Y...)
#
# --- LLM Call ---
# Prompt (first 200 chars):
#             Based on the user query: "Plan a flight from Montreal to Toronto tomorrow, considering weather and airspace."
#             And the following retrieved text information:
#             - Relev...
# LLM Response (first 200 chars): To plan a flight from Montreal (YUL) to Toronto (YYZ) for tomorrow, based on the provided information, here's a detailed approach:
#
# **1. Departure Airport (Montreal Trudeau International Airport - YUL...
#
# --- LLM Call ---
# Prompt (first 200 chars):
#             Review the following proposed flight plan/response:
#             "To plan a flight from Montreal (YUL) to Toronto (YYZ) for tomorrow, based on the provided information, here's a detailed a...
# LLM Response (first 200 chars): VERIFICATION STATUS: NEEDS REVISION
#
# The proposed response largely adheres to the retrieved information, accurately extracting and summarizing facts about airport operations, peak hours, and regulator...
#
# --- Verification Result: VERIFICATION STATUS: NEEDS REVISION
#
# The proposed response largely adheres to the retrieved information, accurately extracting and summarizing facts about airport operations, peak hours, and regulatory requirements. It also correctly identifies information that is *not* available from the provided text, such as weather forecasts or specific airspace details.
#
# However, there is a significant discrepancy regarding the handling of the retrieved image description:
#
# **Specific Points of Discrepancy and Suggestions for Correction:**
#
# 1.  **Unsupported Claim about Image Content:**
#     *   **Proposed Response states:** "The provided visual information is described as 'A map of Montreal Trudeau International Airport (YUL), showing runways, terminals, and taxiways, with a red circular marker and a gray rectangular building.' However, the actual image displayed consists only of a red circle and a gray rectangular building on a blue background, and does not visually depict runways, terminals, or taxiways. Therefore, specific details about YUL's layout (runways, terminals, taxiways) cannot be derived from the image itself, despite its caption."
#     *   **Proposed Response also states in "Limitations":** "Any details about specific runways, taxiways, or terminals at YUL that are visually present in the image, despite the image caption's description."
#     *   **Discrepancy:** The retrieved information *only* provided the *textual description* of the image ("A map of Montreal Trudeau International Airport (YUL), showing runways, terminals, and taxiways, with a red circular marker and a gray rectangular building."). It did *not* provide the actual image itself, nor any information that contradicts this description. The response makes an unsupported claim about the *visual content* of the non-provided image, stating it "consists only of a red circle and a gray rectangular building on a blue background" and "does not visually depict runways, terminals, or taxiways." This is a fabrication of details regarding the image's actual content and directly contradicts the provided *description* of the image, which *is* part of the retrieved information. The prompt specifically asks to compare *strictly against the retrieved information*.
#
#     *   **Suggestion for Correction:** The response should strictly adhere to the provided information. Since only the image *description* was provided, the response should acknowledge that description without fabricating details about the image's actual visual content or contradicting the description.
#         *   **Revised wording for Departure Airport section:** "The provided visual information is described as 'A map of Montreal Trudeau International Airport (YUL), showing runways, terminals, and taxiways, with a red circular marker and a gray rectangular building.' Based on this description, relevant layout details like runways, terminals, and taxiways are indicated to be present, although specific analysis of these visual details is beyond the scope of a text-based plan."
#         *   **Revised wording for Limitations section:** "Any specific details or features from the image of YUL, beyond what is explicitly stated in its description." (Or simply remove the point if the image description is addressed adequately in the main body by accepting its stated content.) The key is to avoid claiming the image *doesn't* show what its description says it does. ---
#
# WARNING: Hallucination detected or potential inaccuracy. Agent is attempting to re-evaluate and refine.
#
# --- Attempt 2/2 ---
#
# --- LLM Call ---
# Prompt (first 200 chars):
#             You are an AI flight planning assistant using Gemini 2.5 Flash. Your goal is to provide accurate, detailed, and hallucination-free flight plans.
#             The user has provided the foll...
# LLM Response (first 200 chars): Here's the plan of action to refine the flight plan based on the provided feedback:
#
# 1.  **Analyze the User Query and Feedback:**
#     *   The original query is to plan a flight from Montreal to Toront...
# Agent's Initial Plan: Here's the plan of action to refine the flight plan based on the provided feedback:
#
# 1.  **Analyze the User Query and Feedback:**
#     *   The original query is to plan a flight from Montreal to Toronto tomorrow, considering weather and airspace.
#     *   The feedback indicates that the previous response was largely accurate, *except* for a significant discrepancy in handling the retrieved image *description*.
#     *   **Specific Issue:** The previous response fabricated details about the visual content of an image that was *only described* (not provided visually). It incorrectly stated the image "consists only of a red circle and a gray rectangular building on a blue background, and does not visually depict runways, terminals, or taxiways," directly contradicting the provided *textual description* which stated it was "A map of Montreal Trudeau International Airport (YUL), showing runways, terminals, and taxiways, with a red circular marker and a gray rectangular building."
#     *   **Core Goal:** Adhere strictly to the retrieved information. Since only the image *description* was retrieved, the refined plan must accept this description as fact about what the image *purports to show*, without fabricating details about the actual (unseen) visual content.
#
# 2.  **Identify Specific Sections for Revision:**
#     *   The "Departure Airport: Montreal Trudeau International Airport (YUL)" section.
#     *   The "Limitations of this Plan" section.
#
# 3.  **Formulate Corrected Wording (based directly on feedback suggestions):**
#
#     *   **For the "Departure Airport" section (YUL):**
#         *   **Current Issue (Implied from feedback):** Contradicting the image description.
#         *   **Proposed Correction:** "The provided visual information is described as 'A map of Montreal Trudeau International Airport (YUL), showing runways, terminals, and taxiways, with a red circular marker and a gray rectangular building.' Based on this description, relevant layout details like runways, terminals, and taxiways are indicated to be present, although specific analysis of these visual details is beyond the scope of a text-based plan."
#
#     *   **For the "Limitations" section:**
#         *   **Current Issue (Implied from feedback):** Repeating the unsupported claim about the image's content.
#         *   **Proposed Correction:** "Any specific details or features from the image of YUL, beyond what is explicitly stated in its description." (This phrasing correctly implies that while the description exists, deeper analysis of the visual elements themselves is not possible from text alone).
#
# 4.  **Outline Steps for Generating the Refined Flight Plan:**
#
#     *   **Step 1: Re-extract All Relevant Information:**
#         *   Review the original prompt for core flight details (Montreal to Toronto, tomorrow, considering weather and airspace).
#         *   Re-access all previously retrieved information, including facts about airport operations, peak hours, regulatory requirements, and especially the *full textual description* of the YUL image.
#         *   Confirm that information *not* available (like real-time weather forecasts or specific airspace details like NOTAMs/TFRs) is still correctly identified as such.
#
#     *   **Step 2: Apply Image Description Correction to "Departure Airport" Section:**
#         *   In the section detailing Montreal Trudeau International Airport (YUL), integrate the refined wording formulated in point 3, acknowledging the image description without fabricating visual content.
#
#     *   **Step 3: Apply Image Description Correction to "Limitations" Section:**
#         *   In the section outlining the limitations of the plan, integrate the refined wording formulated in point 3, ensuring it accurately reflects the scope of what can be derived from the provided image description.
#
#     *   **Step 4: Verify and Maintain Other Sections:**
#         *   Ensure all other parts of the original flight plan that were deemed accurate by the feedback (e.g., details about Toronto airports, general route considerations, weather and airspace disclaimers, regulatory requirements) remain intact and correct. The feedback focused solely on the image handling, so no other significant changes should be required for these sections.
#
#     *   **Step 5: Final Review for Accuracy and Adherence:**
#         *   Before presenting the final refined flight plan, conduct a thorough review to ensure:
#             *   All aspects of the feedback have been directly addressed.
#             *   The plan strictly adheres to the provided textual information and avoids any form of hallucination or fabrication, particularly regarding the image content.
#             *   The language is clear, concise, and professional.
#
# This plan focuses directly on correcting the identified discrepancy while preserving the accurate elements of the previous response, ensuring the final output is precise and hallucination-free.
# Retrieving text for query: 'Flight regulations, schedules, and airport information for Refine the flight plan for: 'Plan a flight from Montreal to Toronto tomorrow, considering weather and airspace.' based on this feedback: VERIFICATION STATUS: NEEDS REVISION
#
# The proposed response largely adheres to the retrieved information, accurately extracting and summarizing facts about airport operations, peak hours, and regulatory requirements. It also correctly identifies information that is *not* available from the provided text, such as weather forecasts or specific airspace details.
#
# However, there is a significant discrepancy regarding the handling of the retrieved image description:
#
# **Specific Points of Discrepancy and Suggestions for Correction:**
#
# 1.  **Unsupported Claim about Image Content:**
#     *   **Proposed Response states:** "The provided visual information is described as 'A map of Montreal Trudeau International Airport (YUL), showing runways, terminals, and taxiways, with a red circular marker and a gray rectangular building.' However, the actual image displayed consists only of a red circle and a gray rectangular building on a blue background, and does not visually depict runways, terminals, or taxiways. Therefore, specific details about YUL's layout (runways, terminals, taxiways) cannot be derived from the image itself, despite its caption."
#     *   **Proposed Response also states in "Limitations":** "Any details about specific runways, taxiways, or terminals at YUL that are visually present in the image, despite the image caption's description."
#     *   **Discrepancy:** The retrieved information *only* provided the *textual description* of the image ("A map of Montreal Trudeau International Airport (YUL), showing runways, terminals, and taxiways, with a red circular marker and a gray rectangular building."). It did *not* provide the actual image itself, nor any information that contradicts this description. The response makes an unsupported claim about the *visual content* of the non-provided image, stating it "consists only of a red circle and a gray rectangular building on a blue background" and "does not visually depict runways, terminals, or taxiways." This is a fabrication of details regarding the image's actual content and directly contradicts the provided *description* of the image, which *is* part of the retrieved information. The prompt specifically asks to compare *strictly against the retrieved information*.
#
#     *   **Suggestion for Correction:** The response should strictly adhere to the provided information. Since only the image *description* was provided, the response should acknowledge that description without fabricating details about the image's actual visual content or contradicting the description.
#         *   **Revised wording for Departure Airport section:** "The provided visual information is described as 'A map of Montreal Trudeau International Airport (YUL), showing runways, terminals, and taxiways, with a red circular marker and a gray rectangular building.' Based on this description, relevant layout details like runways, terminals, and taxiways are indicated to be present, although specific analysis of these visual details is beyond the scope of a text-based plan."
#         *   **Revised wording for Limitations section:** "Any specific details or features from the image of YUL, beyond what is explicitly stated in its description." (Or simply remove the point if the image description is addressed adequately in the main body by accepting its stated content.) The key is to avoid claiming the image *doesn't* show what its description says it does..'
# Retrieved Text: ['Relevant text chunk 1 for \'Flight regulations, schedules, and airport information for Refine the flight plan for: \'Plan a flight from Montreal to Toronto tomorrow, considering weather and airspace.\' based on this feedback: VERIFICATION STATUS: NEEDS REVISION\n\nThe proposed response largely adheres to the retrieved information, accurately extracting and summarizing facts about airport operations, peak hours, and regulatory requirements. It also correctly identifies information that is *not* available from the provided text, such as weather forecasts or specific airspace details.\n\nHowever, there is a significant discrepancy regarding the handling of the retrieved image description:\n\n**Specific Points of Discrepancy and Suggestions for Correction:**\n\n1.  **Unsupported Claim about Image Content:**\n    *   **Proposed Response states:** "The provided visual information is described as \'A map of Montreal Trudeau International Airport (YUL), showing runways, terminals, and taxiways, with a red circular marker and a gray rectangular building.\' However, the actual image displayed consists only of a red circle and a gray rectangular building on a blue background, and does not visually depict runways, terminals, or taxiways. Therefore, specific details about YUL\'s layout (runways, terminals, taxiways) cannot be derived from the image itself, despite its caption."\n    *   **Proposed Response also states in "Limitations":** "Any details about specific runways, taxiways, or terminals at YUL that are visually present in the image, despite the image caption\'s description."\n    *   **Discrepancy:** The retrieved information *only* provided the *textual description* of the image ("A map of Montreal Trudeau International Airport (YUL), showing runways, terminals, and taxiways, with a red circular marker and a gray rectangular building."). It did *not* provide the actual image itself, nor any information that contradicts this description. The response makes an unsupported claim about the *visual content* of the non-provided image, stating it "consists only of a red circle and a gray rectangular building on a blue background" and "does not visually depict runways, terminals, or taxiways." This is a fabrication of details regarding the image\'s actual content and directly contradicts the provided *description* of the image, which *is* part of the retrieved information. The prompt specifically asks to compare *strictly against the retrieved information*.\n\n    *   **Suggestion for Correction:** The response should strictly adhere to the provided information. Since only the image *description* was provided, the response should acknowledge that description without fabricating details about the image\'s actual visual content or contradicting the description.\n        *   **Revised wording for Departure Airport section:** "The provided visual information is described as \'A map of Montreal Trudeau International Airport (YUL), showing runways, terminals, and taxiways, with a red circular marker and a gray rectangular building.\' Based on this description, relevant layout details like runways, terminals, and taxiways are indicated to be present, although specific analysis of these visual details is beyond the scope of a text-based plan."\n        *   **Revised wording for Limitations section:** "Any specific details or features from the image of YUL, beyond what is explicitly stated in its description." (Or simply remove the point if the image description is addressed adequately in the main body by accepting its stated content.) The key is to avoid claiming the image *doesn\'t* show what its description says it does..\' (from regulations.txt - Pilots must have valid licenses. Weather conditions must be VFR or IFR compliant. Fuel reserves are mandatory. Airspace classifications dictate specific procedures.)', 'Relevant text chunk 2 for \'Flight regulations, schedules, and airport information for Refine the flight plan for ...
# Retrieving images for query: 'Airport maps or relevant weather charts for Refine the flight plan for: 'Plan a flight from Montreal to Toronto tomorrow, considering weather and airspace.' based on this feedback: VERIFICATION STATUS: NEEDS REVISION
#
# The proposed response largely adheres to the retrieved information, accurately extracting and summarizing facts about airport operations, peak hours, and regulatory requirements. It also correctly identifies information that is *not* available from the provided text, such as weather forecasts or specific airspace details.
#
# However, there is a significant discrepancy regarding the handling of the retrieved image description:
#
# **Specific Points of Discrepancy and Suggestions for Correction:**
#
# 1.  **Unsupported Claim about Image Content:**
#     *   **Proposed Response states:** "The provided visual information is described as 'A map of Montreal Trudeau International Airport (YUL), showing runways, terminals, and taxiways, with a red circular marker and a gray rectangular building.' However, the actual image displayed consists only of a red circle and a gray rectangular building on a blue background, and does not visually depict runways, terminals, or taxiways. Therefore, specific details about YUL's layout (runways, terminals, taxiways) cannot be derived from the image itself, despite its caption."
#     *   **Proposed Response also states in "Limitations":** "Any details about specific runways, taxiways, or terminals at YUL that are visually present in the image, despite the image caption's description."
#     *   **Discrepancy:** The retrieved information *only* provided the *textual description* of the image ("A map of Montreal Trudeau International Airport (YUL), showing runways, terminals, and taxiways, with a red circular marker and a gray rectangular building."). It did *not* provide the actual image itself, nor any information that contradicts this description. The response makes an unsupported claim about the *visual content* of the non-provided image, stating it "consists only of a red circle and a gray rectangular building on a blue background" and "does not visually depict runways, terminals, or taxiways." This is a fabrication of details regarding the image's actual content and directly contradicts the provided *description* of the image, which *is* part of the retrieved information. The prompt specifically asks to compare *strictly against the retrieved information*.
#
#     *   **Suggestion for Correction:** The response should strictly adhere to the provided information. Since only the image *description* was provided, the response should acknowledge that description without fabricating details about the image's actual visual content or contradicting the description.
#         *   **Revised wording for Departure Airport section:** "The provided visual information is described as 'A map of Montreal Trudeau International Airport (YUL), showing runways, terminals, and taxiways, with a red circular marker and a gray rectangular building.' Based on this description, relevant layout details like runways, terminals, and taxiways are indicated to be present, although specific analysis of these visual details is beyond the scope of a text-based plan."
#         *   **Revised wording for Limitations section:** "Any specific details or features from the image of YUL, beyond what is explicitly stated in its description." (Or simply remove the point if the image description is addressed adequately in the main body by accepting its stated content.) The key is to avoid claiming the image *doesn't* show what its description says it does..'
# Retrieved Images (Captions): ['A map of Montreal Trudeau International Airport (YUL), showing runways, terminals, and taxiways, with a red circular marker and a gray rectangular building.']
# Adding image: knowledge_base_documents/yul_airport_map.png (caption: A map of Montreal Trudeau International Airport (Y...)
#
# --- LLM Call ---
# Prompt (first 200 chars):
#             Based on the user query: "Refine the flight plan for: 'Plan a flight from Montreal to Toronto tomorrow, considering weather and airspace.' based on this feedback: VERIFICATION STATUS: NEE...
# LLM Response (first 200 chars): Based on the retrieved information and the provided feedback, here is a refined flight plan for a flight from Montreal to Toronto tomorrow:
#
# ### Refined Flight Plan: Montreal (YUL) to Toronto (YYZ) - ...
#
# --- LLM Call ---
# Prompt (first 200 chars):
#             Review the following proposed flight plan/response:
#             "Based on the retrieved information and the provided feedback, here is a refined flight plan for a flight from Montreal to ...
# LLM Response (first 200 chars): VERIFICATION STATUS: OK
#
# The proposed flight plan strictly adheres to the retrieved information. It has successfully incorporated all the required facts from the "regulations.txt" and "schedules.txt" ...
#
# --- Verification Result: VERIFICATION STATUS: OK
#
# The proposed flight plan strictly adheres to the retrieved information. It has successfully incorporated all the required facts from the "regulations.txt" and "schedules.txt" (as indicated by the summary in the retrieved text) and, crucially, it has implemented the specific corrections suggested in the retrieved information regarding the handling of the image description.
#
# Specifically:
# *   The sections on **Pre-Flight Regulatory Requirements** (Pilot Licensing, Weather Compliance, Fuel Reserves) accurately reflect the details mentioned in the retrieved text's summary of regulations.
# *   The **Departure Airport** section correctly states Montreal (YUL) operates 24/7 and accurately uses the provided image description without fabricating visual details or contradicting the description. The wording for the "Airport Layout (from Visual Description)" section precisely matches the "Revised wording for Departure Airport section" suggested in the retrieved information.
# *   The **En-Route Airspace Considerations** correctly note that specific procedures are dictated by airspace classifications and that details were not provided, consistent with the retrieved information.
# *   The **Arrival Airport** section correctly identifies Toronto (YYZ) peak hours as per the retrieved information.
# *   The **Limitations and Information Not Available** section correctly lists missing weather and detailed airspace information. Importantly, the point "Specific Details from YUL Image" accurately reflects the "Revised wording for Limitations section" suggested in the retrieved information, indicating that the plan correctly avoids deriving details beyond what is explicitly stated in the image's *description*.
#
# There are no unsupported claims, fabricated details, or inconsistencies when compared strictly against the provided retrieved information. The previous "NEEDS REVISION" status (from the retrieved text itself) was due to the image handling error, which this refined plan has effectively corrected. ---
#
# Flight plan verified. Ready to present.
#
# Final Flight Plan 1: Based on the retrieved information and the provided feedback, here is a refined flight plan for a flight from Montreal to Toronto tomorrow:
#
# ### Refined Flight Plan: Montreal (YUL) to Toronto (YYZ) - Tomorrow
#
# This plan synthesizes available information regarding airport operations, regulations, and the provided visual description, while explicitly noting limitations due to the absence of real-time weather and specific airspace data.
#
# **1. Pre-Flight Regulatory Requirements:**
# *   **Pilot Licensing:** The pilot must possess a valid license for the planned flight.
# *   **Weather Compliance:** The flight must adhere to either Visual Flight Rules (VFR) or Instrument Flight Rules (IFR) weather conditions. This requires obtaining an accurate weather forecast for tomorrow for both departure, en-route, and arrival phases, which is not available in the provided data.
# *   **Fuel Reserves:** Mandatory fuel reserves must be carried as per regulations.
#
# **2. Departure Airport (Montreal Trudeau International Airport - YUL):**
# *   **Operating Hours:** Montreal (YUL) operates 24/7, providing flexibility for departure time.
# *   **Airport Layout (from Visual Description):** The provided visual information is described as 'A map of Montreal Trudeau International Airport (YUL), showing runways, terminals, and taxiways, with a red circular marker and a gray rectangular building.' Based on this description, relevant layout details like runways, terminals, and taxiways are indicated to be present, although specific analysis of these visual details is beyond the scope of a text-based plan. The red circular marker and gray rectangular building are noted as present on the map.
#
# **3. En-Route Airspace Considerations:**
# *   **Airspace Classifications:** Specific procedures are dictated by airspace classifications along the route from Montreal to Toronto. A detailed understanding of these classifications is essential for flight planning, but specific details were not provided in the retrieved information.
#
# **4. Arrival Airport (Toronto Pearson International Airport - YYZ):**
# *   **Peak Hours:** Toronto (YYZ) experiences peak operating hours from 0600-0900 and 1700-2000 local time. Pilots should consider avoiding these periods if possible to potentially reduce delays and congestion.
#
# **5. Limitations and Information Not Available:**
# *   **Specific Weather Forecast:** The retrieved information does not include tomorrow's specific weather forecast for Montreal, Toronto, or the en-route path, which is critical for determining VFR/IFR compliance and overall flight safety.
# *   **Detailed Airspace Information:** Precise airspace classifications, entry/exit procedures, and specific routes for the Montreal-Toronto corridor are not provided.
# *   **Exact Flight Schedule/ETA:** This plan does not specify an exact departure or arrival time, as it depends on external factors like weather and pilot preference outside of peak hours.
# *   **Specific Details from YUL Image:** Any specific details or features from the image of YUL, beyond what is explicitly stated in its description, cannot be derived or analyzed from the provided data.
#
# --- Agent Starting: Processing query 'Tell me about the historical average rainfall in Paris in 1850 for flight planning purposes.' ---
#
# --- Attempt 1/2 ---
#
# --- LLM Call ---
# Prompt (first 200 chars):
#             You are an AI flight planning assistant using Gemini 2.5 Flash. Your goal is to provide accurate, detailed, and hallucination-free flight plans.
#             The user has provided the foll...
# LLM Response (first 200 chars): The user is asking for "historical average rainfall in Paris in 1850 for flight planning purposes."
#
# **Analysis of the Query:**
#
# 1.  **Core Information Needed:** Average rainfall data for Paris for th...
# Agent's Initial Plan: The user is asking for "historical average rainfall in Paris in 1850 for flight planning purposes."
#
# **Analysis of the Query:**
#
# 1.  **Core Information Needed:** Average rainfall data for Paris for the specific year 1850.
# 2.  **Context:** For "flight planning purposes."
#
# **Critical Considerations and Challenges:**
#
# *   **Data Availability (1850):** Obtaining precise, digitized, and comprehensive "average rainfall" data for a specific city like Paris for the entire year 1850 is highly improbable using standard digital knowledge bases or external APIs. Meteorological record-keeping was not as standardized, extensive, or digitally cataloged in the mid-19th century as it is today. Records, if they exist, would likely be sparse, localized, and in analog format, not conducive to generating a reliable annual average for modern flight planning.
# *   **Relevance for Flight Planning:** Weather data from 1850 is **completely irrelevant** for modern flight planning.
#     *   **Temporal Discrepancy:** Weather patterns, climate, and local microclimates change significantly over 170+ years.
#     *   **Predictive Value:** Historical data from such a distant past has zero predictive value for current or near-future flight conditions.
#     *   **Operational Requirements:** Modern flight planning relies on real-time observations (METARs), short-term forecasts (TAFs), en-route forecasts (Winds Aloft, Significant Weather Charts), and very recent climatological data (e.g., 30-year averages from the past few decades) for long-term route analysis, not data from the 19th century.
#
# **Tools and Modalities:**
#
# *   **Knowledge Base Retrieval:** Unlikely to yield the specific 1850 data required. Our internal knowledge base is primarily focused on general aviation knowledge, current weather principles, and modern climatology, not granular historical weather records from the 1800s.
# *   **External APIs:** No modern weather API (e.g., for forecasts, current conditions, or recent historical data) would provide information from 1850.
# *   **Multi-modal information:** Airport maps or weather charts are used for current or forecasted conditions and have no applicability to historical data from 1850.
#
# **Plan of Action:**
#
# Given the unsuitability and irrelevance of the requested data for flight planning, the plan must involve explaining this to the user while also guiding them towards what information *is* relevant and how it would be obtained.
#
# **Step-by-step Plan:**
#
# 1.  **Acknowledge and Address the Specific Request (1850 Rainfall):**
#     *   State clearly that retrieving accurate, comprehensive, and digitally available "average rainfall" data for Paris specifically for the year 1850 is not feasible through standard aviation weather data sources or historical climate databases relevant for modern flight planning.
#     *   Explain that meteorological record-keeping in 1850 was rudimentary compared to today, making detailed, annual averages difficult or impossible to reconstruct reliably for operational purposes.
#
# 2.  **Crucially Explain the Irrelevance of 1850 Data for Modern Flight Planning:**
#     *   Emphasize that weather patterns and climate have changed considerably over the last 170+ years.
#     *   Clearly state that historical weather data from such a distant past holds no predictive value for current or future flight operations. Modern aviation safety and efficiency depend on current observations and short-term forecasts.
#
# 3.  **Educate on What Weather Information *Is* Relevant for Flight Planning:**
#     *   **Timeframe:** Explain that flight planning relies on real-time observations, short-range (0-24 hours) and medium-range (up to 7 days) forecasts, and recent climatological averages (e.g., 30-year averages for 1991-2020) for general route planning or seasonal considerations.
#     *   **Key Parameters:** List the essential weather parameters required for flight planning:
#         *   Wind speed and direction (surface and aloft)
#         *   Temperature (surface and aloft)
#         *   Visibility (horizontal and vertical)
#         *   Cloud cover and ceiling
#         *   Precipitation type and intensity
#         *   Atmospheric pressure (for altimeter settings)
#         *   Significant weather phenomena (thunderstorms, turbulence, icing, fog, dust storms, volcanic ash).
#     *   **Data Sources (General):** Mention types of sources: METARs (current observations), TAFs (terminal forecasts), SIGMETs/AIRMETs (en-route significant weather), Winds Aloft Forecasts, Weather Charts (e.g., Significant Weather Charts, Convective Outlooks), NOTAMs (for weather-related operational impacts).
#
# 4.  **Propose a Constructive Alternative/Clarification:**
#     *   Ask the user to specify the *actual* date, time, and specific airport(s) in Paris (e.g., Charles de Gaulle - LFPG, Orly - LFPO) for which they need weather information.
#     *   Explain that with this current/future information, a detailed and relevant flight weather briefing can be provided.
#
# 5.  **Outline the Process for Gathering *Relevant* Weather Data (assuming a current/future date is provided):**
#     *   **Identify Airport ICAO Codes:** Determine the specific airport(s) in Paris (e.g., LFPG, LFPO).
#     *   **Determine Flight Period:** Define the exact departure, en-route, and arrival times.
#     *   **Retrieve Real-time Observations:** Query for current METARs for the departure, destination, and alternate airports.
#     *   **Retrieve Terminal Forecasts:** Query for TAFs for the departure, destination, and alternate airports covering the flight window.
#     *   **Retrieve En-route Forecasts:**
#         *   Winds and Temperatures Aloft (using global models, e.g., GFS, based on flight altitude).
#         *   Significant Weather Charts (for potential turbulence, icing, thunderstorms, widespread precipitation along the route).
#         *   Upper Air Charts (Jet Stream, Pressure Systems).
#     *   **Retrieve Area Forecasts/SIGMETs/AIRMETs:** Check for any hazardous weather advisories along the planned route.
#     *   **Check NOTAMs:** Review for any weather-related operational restrictions (e.g., runway closures due to ice, reduced visibility procedures).
#     *   **Synthesize:** Compile all relevant data into a comprehensive weather brief for the specific flight.
#
# This plan focuses on being accurate, detailed, and non-hallucinatory by explaining why the direct query cannot be met and redirecting the user to relevant and actionable information.
# Retrieving text for query: 'Flight regulations, schedules, and airport information for Tell me about the historical average rainfall in Paris in 1850 for flight planning purposes..'
# Retrieved Text: ["Relevant text chunk 1 for 'Flight regulations, schedules, and airport information for Tell me about the historical average rainfall in Paris in 1850 for flight planning purposes..' (from regulations.txt - Pilots must have valid licenses. Weather conditions must be VFR or IFR compliant. Fuel reserves are mandatory. Airspace classifications dictate specific procedures.)", "Relevant text chunk 2 for 'Flight regulations, schedules, and airport information for Tell me about the historical average rainfall in Paris in 1850 for flight planning purposes..' (from schedules.txt - Montreal (YUL) operates 24/7. Toronto (YYZ) has peak hours from 0600-0900 and 1700-2000 local time.)"]
# Retrieving images for query: 'Airport maps or relevant weather charts for Tell me about the historical average rainfall in Paris in 1850 for flight planning purposes..'
# Retrieved Images (Captions): ['A map of Montreal Trudeau International Airport (YUL), showing runways, terminals, and taxiways, with a red circular marker and a gray rectangular building.']
# Adding image: knowledge_base_documents/yul_airport_map.png (caption: A map of Montreal Trudeau International Airport (Y...)
#
# --- LLM Call ---
# Prompt (first 200 chars):
#             Based on the user query: "Tell me about the historical average rainfall in Paris in 1850 for flight planning purposes."
#             And the following retrieved text information:
#          ...
# LLM Response (first 200 chars): I cannot provide information about the historical average rainfall in Paris in 1850 based on the provided retrieved data.
#
# The retrieved text information focuses on general flight regulations (pilot l...
#
# --- LLM Call ---
# Prompt (first 200 chars):
#             Review the following proposed flight plan/response:
#             "I cannot provide information about the historical average rainfall in Paris in 1850 based on the provided retrieved data.
# ...
# LLM Response (first 200 chars): VERIFICATION STATUS: OK
#
# The proposed response strictly adheres to the retrieved information. Every statement made in the response is directly supported by or is a correct inference from the provided ...
#
# --- Verification Result: VERIFICATION STATUS: OK
#
# The proposed response strictly adheres to the retrieved information. Every statement made in the response is directly supported by or is a correct inference from the provided text chunks and image description:
#
# *   **"I cannot provide information about the historical average rainfall in Paris in 1850 based on the provided retrieved data."** This is accurate because the retrieved data *does not* contain any information about historical rainfall, Paris, or the year 1850.
# *   **"The retrieved text information focuses on general flight regulations (pilot licenses, VFR/IFR weather conditions, fuel reserves, airspace classifications) and airport operating hours for Montreal (YUL) and Toronto (YYZ)."** This is a precise and accurate summary of the two provided text chunks.
#     *   Chunk 1: "Pilots must have valid licenses. Weather conditions must be VFR or IFR compliant. Fuel reserves are mandatory. Airspace classifications dictate specific procedures." (Matches flight regulations)
#     *   Chunk 2: "Montreal (YUL) operates 24/7. Toronto (YYZ) has peak hours from 0600-0900 and 1700-2000 local time." (Matches airport operating hours for YUL and YYZ)
# *   **"The visual information is a map of Montreal Trudeau International Airport (YUL)."** This directly corresponds to the "Retrieved Image Descriptions" provided.
# *   **"None of this information contains any details about historical weather data for Paris or any specific year like 1850."** This is a correct concluding statement based on the content (or lack thereof) of all the provided retrieved information.
#
# There are no unsupported claims, fabricated details, inconsistencies, or hallucinations. ---
#
# Flight plan verified. Ready to present.
#
# Final Flight Plan 2: I cannot provide information about the historical average rainfall in Paris in 1850 based on the provided retrieved data.
#
# The retrieved text information focuses on general flight regulations (pilot licenses, VFR/IFR weather conditions, fuel reserves, airspace classifications) and airport operating hours for Montreal (YUL) and Toronto (YYZ). The visual information is a map of Montreal Trudeau International Airport (YUL).
#
# None of this information contains any details about historical weather data for Paris or any specific year like 1850.
